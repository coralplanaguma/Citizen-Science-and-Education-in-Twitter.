# %% [markdown]
# # Analysis of CATALAN  Twitter data

# %% [markdown]
# Imports

# %%
import json
import pandas as pd
import numpy as np
from math import isnan
import pymongo
from pymongo import MongoClient
import json

# %% [markdown]
# ### Read data from MongoDB database

# %%
class Scraper:
    def __init__(self):
        
        #Mongodb connection
        self.conn = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                                #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')

        #Mongodb database and repository
        db = self.conn.Stucom

        #Collections
        self.CAT =  db.CAT 
    
    def visualize_values(self): 

        # take the values
        values = self.CAT.find() 
        
        # go through the values of the object "pymongo"
        for i in values: 
            print(i)



if __name__ == "__main__":

    scraper = Scraper()
    scraper.visualize_values()

# %%
# Get the database
client = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                            
                     #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true")

db = client["CAT"]
col = db["ciencia ciutadana"]
data = pd.DataFrame(list(col.find()))

# %% [markdown]
# Visualization of the data

# %%
data
# Out:
#                           _id                      created_at  \
# 0    6037cc67ee0a6e2f74656259  Thu Feb 25 08:36:50 +0000 2021
# 1    6037cc67ee0a6e2f7465625a  Thu Feb 25 05:50:37 +0000 2021
# 2    6037cc67ee0a6e2f7465625b  Wed Feb 24 21:47:06 +0000 2021
# 3    6037cc67ee0a6e2f7465625c  Wed Feb 24 20:49:38 +0000 2021
# 4    6037cc67ee0a6e2f7465625d  Wed Feb 24 13:31:46 +0000 2021
# ..                        ...                             ...
# 439  608873033c972623d0aa691b  Tue Apr 27 14:16:01 +0000 2021
# 440  608873033c972623d0aa691d  Tue Apr 27 14:05:24 +0000 2021
# 441  608873033c972623d0aa6922  Thu Apr 22 07:32:42 +0000 2021
# 442  608873033c972623d0aa691e  Sun Apr 25 21:03:32 +0000 2021
# 443  608873033c972623d0aa6917  Tue Apr 27 14:43:27 +0000 2021
#
#                       id               id_str  \
# 0    1364856872923242498  1364856872923242498
# 1    1364815041854332929  1364815041854332929
# 2    1364693361253318659  1364693361253318659
# 3    1364678897112145928  1364678897112145928
# 4    1364568703745077254  1364568703745077254
# ..                   ...                  ...
# 439  1387047889969451009  1387047889969451009
# 440  1387045218516553731  1387045218516553731
# 441  1385134451026444288  1385134451026444288
# 442  1386425666631987201  1386425666631987201
# 443  1387054791726149634  1387054791726149634
#
#                                              full_text  truncated  \
# 0    Lectura de dijous: Ornitho i la ciència ciutad...      False
# 1    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# 2    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# 3    RT @Leni_ElenaF: Disfrutar mentre fas ciencia ...      False
# 4    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# ..                                                 ...        ...
# 439  Gracias por ayudarnos en la difusión de la pla...      False
# 440  The European citizen science platform @EUCitSc...      False
# 441  RT @Ecsite: Happy #EarthDay2021! Every year, a...      False
# 442  RT @CitSciMonth: @EUCitSciProject @marziuk Lat...      False
# 443  RT @CitieSHealthEU: The European citizen scien...      False
#
#     display_text_range                                           entities  \
# 0             [0, 257]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3             [0, 118]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                 ...                                                ...
# 439           [0, 102]  {'hashtags': [{'text': 'cienciaciudadana', 'in...
# 440           [0, 127]  {'hashtags': [{'text': 'CitSci', 'indices': [1...
# 441           [0, 140]  {'hashtags': [{'text': 'EarthDay2021', 'indice...
# 442           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 443           [0, 140]  {'hashtags': [{'text': 'CitSci', 'indices': [1...
#
#                                               metadata  \
# 0    {'result_type': 'recent', 'iso_language_code':...
# 1    {'result_type': 'recent', 'iso_language_code':...
# 2    {'result_type': 'recent', 'iso_language_code':...
# 3    {'result_type': 'recent', 'iso_language_code':...
# 4    {'result_type': 'recent', 'iso_language_code':...
# ..                                                 ...
# 439  {'iso_language_code': 'es', 'result_type': 're...
# 440  {'iso_language_code': 'en', 'result_type': 're...
# 441  {'iso_language_code': 'en', 'result_type': 're...
# 442  {'iso_language_code': 'en', 'result_type': 're...
# 443  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                 source  ... favorite_count  \
# 0    <a href="https://mobile.twitter.com" rel="nofo...  ...              2
# 1    <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 2    <a href="http://twitter.com/download/android" ...  ...              0
# 3    <a href="http://twitter.com/download/android" ...  ...              0
# 4    <a href="https://www.hootsuite.com" rel="nofol...  ...              0
# ..                                                 ...  ...            ...
# 439  <a href="https://mobile.twitter.com" rel="nofo...  ...              4
# 440  <a href="https://mobile.twitter.com" rel="nofo...  ...              9
# 441  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 442  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 443  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
#
#     favorited retweeted possibly_sensitive lang  \
# 0       False     False              False   ca
# 1       False     False              False   ca
# 2       False     False              False   ca
# 3       False     False              False   ca
# 4       False     False              False   ca
# ..        ...       ...                ...  ...
# 439     False     False              False   es
# 440     False     False              False   en
# 441     False     False                NaN   en
# 442     False     False                NaN   en
# 443     False     False              False   en
#
#                                       retweeted_status  \
# 0                                                  NaN
# 1    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# 2    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# 3    {'created_at': 'Mon Feb 22 20:54:18 +0000 2021...
# 4    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# ..                                                 ...
# 439                                                NaN
# 440                                                NaN
# 441  {'created_at': 'Thu Apr 22 07:00:08 +0000 2021...
# 442  {'created_at': 'Wed Jan 22 22:20:25 +0000 2020...
# 443  {'created_at': 'Tue Apr 27 14:05:24 +0000 2021...
#
#                                      extended_entities     quoted_status_id  \
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3    {'media': [{'id': '1363955294989123586', 'id_s...                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 439                                                NaN  1387045218516553731
# 440  {'media': [{'id': '1387045099775750162', 'id_s...                  NaN
# 441                                                NaN                  NaN
# 442                                                NaN                  NaN
# 443                                                NaN                  NaN
#
#     quoted_status_id_str                                      quoted_status
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ..                   ...                                                ...
# 439  1387045218516553731  {'created_at': 'Tue Apr 27 14:05:24 +0000 2021...
# 440                  NaN                                                NaN
# 441                  NaN                                                NaN
# 442                  NaN                                                NaN
# 443                  NaN                                                NaN
#
# [444 rows x 32 columns]

# %% [markdown]
# ### Quit outliers

# %% [markdown]
# Delete repeated tweets.

# %%
data = data.drop_duplicates(subset=['id'])
data = data.reset_index(drop=True)
data
# Out:
#                           _id                      created_at  \
# 0    6037cc67ee0a6e2f74656259  Thu Feb 25 08:36:50 +0000 2021
# 1    6037cc67ee0a6e2f7465625a  Thu Feb 25 05:50:37 +0000 2021
# 2    6037cc67ee0a6e2f7465625b  Wed Feb 24 21:47:06 +0000 2021
# 3    6037cc67ee0a6e2f7465625c  Wed Feb 24 20:49:38 +0000 2021
# 4    6037cc67ee0a6e2f7465625d  Wed Feb 24 13:31:46 +0000 2021
# ..                        ...                             ...
# 328  608873033c972623d0aa691b  Tue Apr 27 14:16:01 +0000 2021
# 329  608873033c972623d0aa691d  Tue Apr 27 14:05:24 +0000 2021
# 330  608873033c972623d0aa6922  Thu Apr 22 07:32:42 +0000 2021
# 331  608873033c972623d0aa691e  Sun Apr 25 21:03:32 +0000 2021
# 332  608873033c972623d0aa6917  Tue Apr 27 14:43:27 +0000 2021
#
#                       id               id_str  \
# 0    1364856872923242498  1364856872923242498
# 1    1364815041854332929  1364815041854332929
# 2    1364693361253318659  1364693361253318659
# 3    1364678897112145928  1364678897112145928
# 4    1364568703745077254  1364568703745077254
# ..                   ...                  ...
# 328  1387047889969451009  1387047889969451009
# 329  1387045218516553731  1387045218516553731
# 330  1385134451026444288  1385134451026444288
# 331  1386425666631987201  1386425666631987201
# 332  1387054791726149634  1387054791726149634
#
#                                              full_text  truncated  \
# 0    Lectura de dijous: Ornitho i la ciència ciutad...      False
# 1    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# 2    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# 3    RT @Leni_ElenaF: Disfrutar mentre fas ciencia ...      False
# 4    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# ..                                                 ...        ...
# 328  Gracias por ayudarnos en la difusión de la pla...      False
# 329  The European citizen science platform @EUCitSc...      False
# 330  RT @Ecsite: Happy #EarthDay2021! Every year, a...      False
# 331  RT @CitSciMonth: @EUCitSciProject @marziuk Lat...      False
# 332  RT @CitieSHealthEU: The European citizen scien...      False
#
#     display_text_range                                           entities  \
# 0             [0, 257]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3             [0, 118]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                 ...                                                ...
# 328           [0, 102]  {'hashtags': [{'text': 'cienciaciudadana', 'in...
# 329           [0, 127]  {'hashtags': [{'text': 'CitSci', 'indices': [1...
# 330           [0, 140]  {'hashtags': [{'text': 'EarthDay2021', 'indice...
# 331           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 332           [0, 140]  {'hashtags': [{'text': 'CitSci', 'indices': [1...
#
#                                               metadata  \
# 0    {'result_type': 'recent', 'iso_language_code':...
# 1    {'result_type': 'recent', 'iso_language_code':...
# 2    {'result_type': 'recent', 'iso_language_code':...
# 3    {'result_type': 'recent', 'iso_language_code':...
# 4    {'result_type': 'recent', 'iso_language_code':...
# ..                                                 ...
# 328  {'iso_language_code': 'es', 'result_type': 're...
# 329  {'iso_language_code': 'en', 'result_type': 're...
# 330  {'iso_language_code': 'en', 'result_type': 're...
# 331  {'iso_language_code': 'en', 'result_type': 're...
# 332  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                 source  ... favorite_count  \
# 0    <a href="https://mobile.twitter.com" rel="nofo...  ...              2
# 1    <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 2    <a href="http://twitter.com/download/android" ...  ...              0
# 3    <a href="http://twitter.com/download/android" ...  ...              0
# 4    <a href="https://www.hootsuite.com" rel="nofol...  ...              0
# ..                                                 ...  ...            ...
# 328  <a href="https://mobile.twitter.com" rel="nofo...  ...              4
# 329  <a href="https://mobile.twitter.com" rel="nofo...  ...              9
# 330  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 331  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 332  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
#
#     favorited retweeted possibly_sensitive lang  \
# 0       False     False              False   ca
# 1       False     False              False   ca
# 2       False     False              False   ca
# 3       False     False              False   ca
# 4       False     False              False   ca
# ..        ...       ...                ...  ...
# 328     False     False              False   es
# 329     False     False              False   en
# 330     False     False                NaN   en
# 331     False     False                NaN   en
# 332     False     False              False   en
#
#                                       retweeted_status  \
# 0                                                  NaN
# 1    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# 2    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# 3    {'created_at': 'Mon Feb 22 20:54:18 +0000 2021...
# 4    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# ..                                                 ...
# 328                                                NaN
# 329                                                NaN
# 330  {'created_at': 'Thu Apr 22 07:00:08 +0000 2021...
# 331  {'created_at': 'Wed Jan 22 22:20:25 +0000 2020...
# 332  {'created_at': 'Tue Apr 27 14:05:24 +0000 2021...
#
#                                      extended_entities     quoted_status_id  \
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3    {'media': [{'id': '1363955294989123586', 'id_s...                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 328                                                NaN  1387045218516553731
# 329  {'media': [{'id': '1387045099775750162', 'id_s...                  NaN
# 330                                                NaN                  NaN
# 331                                                NaN                  NaN
# 332                                                NaN                  NaN
#
#     quoted_status_id_str                                      quoted_status
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ..                   ...                                                ...
# 328  1387045218516553731  {'created_at': 'Tue Apr 27 14:05:24 +0000 2021...
# 329                  NaN                                                NaN
# 330                  NaN                                                NaN
# 331                  NaN                                                NaN
# 332                  NaN                                                NaN
#
# [333 rows x 32 columns]

# %% [markdown]
# Check that all tweets are in Catalan

# %%
data = data[data['lang'] == 'ca']

# %% [markdown]
# Delete tweets that are outside the desired range of dates

# %%
for i in range(0, len(data)):   
    item = data.iloc[i]
    
    if(int(item['created_at'][-4:])) < int(2021):
        data.drop([i],  inplace = True)

# %% [markdown]
# ### Treat the data to extract conclusions

# %% [markdown]
# Store for each tweet in the database: the text, the user, the number of retweets, the number of likes and the date.

# %%
tweets = []     # array for the text
users = []      # array for the user data
retweets = []   # array for the number of retweets
likes = []      # array for the number of likes
dates = []      # array for the dates of the tweets

for i in range(0, len(data)):
    
    item = data.iloc[i]    # store JSON object

    text =item['full_text']
    tweets.append(text.split())
    
    user = item['user']
    users.append(user)
        
    retweet = item['retweet_count']
    retweets.append(retweet)
    
    like = item['favorite_count']
    likes.append(like)
    
    date = item['created_at']
    dates.append(date)

# %%
# Fucntion to convert from the written month to the month in numbers
def convert_month(month):
    if month == 'Jan':
        month = 1
    elif month == 'Feb':
        month = 2
    elif month == 'Mar':
        month = 3
    elif month == 'Apr':
        month = 4
    elif month == 'May':
        month = 5
    elif month == 'Jun':
        month = 6
    elif month == 'Jul':
        month = 7
    elif month == 'Aug':
        month = 8
    elif month == 'Sep':
        month = 9
    elif month == 'Oct':
        month = 10
    elif month == 'Nov':
        month = 11
    elif month == 'Dec':
        month = 12
    return month

# %% [markdown]
# Search for the date of the first tweet and the last tweet published in our database.

# %%
find_date = []
for date in dates:
    year = date[-4:]
    month = date[4:7]
    month = convert_month(str(month))
    day = date[8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    find_date.append(pd.Timestamp(date))
    
max_date = max(find_date)
min_date = min(find_date)

print("The first tweet was published at ", min_date)
print("The last tweet was published at ", max_date)
# Out:
# The first tweet was published at  2021-02-17 00:00:00
# The last tweet was published at  2021-04-27 00:00:00

# %% [markdown]
# Number of tweets in the database.

# %%
print("From", min_date, " untill", max_date, len(data),"tweets have been published.")
# Out:
# From 2021-02-17 00:00:00  untill 2021-04-27 00:00:00 300 tweets have been published.

# %% [markdown]
# Most common words between the tweets.

# %%
tweets_arr = []
words_arr = []
non_interesting_words = ["A", "de", "i", "RT", "a", "que", "el", "la", "en", "ja", "Ja", "del", "al", "ciència", "Ciència", 
                         "molts", "vosaltres", "heu", "Us", "ciutadana", "els", "es", "les", "un", "través", "s'està", "El", 
                         "on", "estem", "us", "és", "I", "amb", "aquest", "per", "ciutadana,", "par…", ",", "una", "La",'ha', 
                         'han', 'Es', "-", "Si", "et", "des", "dels", "uns"]

for t in tweets:
    for i in t:
        tweets_arr.append(i)
        if (i.startswith(('#','@')) == False):
            words_arr.append(i)

for word in non_interesting_words:
    words_arr = [val for val in words_arr if val != word]

from collections import Counter 
Counter = Counter(words_arr) 
  
most_occur = Counter.most_common(100) 

print("The most common words are: \n", most_occur)
# Out:
# The most common words are:
#  [('projecte', 85), ('?', 44), ('iniciem', 35), ('Pateixes', 34), ('vol', 34), ('buscar', 34), ('solucion…', 33), ('sobre', 28), ('competició', 28), ('projectes', 24), ('acaba', 20), ('promoure', 19), ('mà', 19), ('la…', 19), ('pesca', 19), ('esportiva', 19), ('https://t.co/phMqlUb0FL', 18), ('***Resultats', 18), ('Ciutadana***', 18), ('2021', 18), ('començat…', 17), ('👉', 16), ('Projecte', 16), ('com', 14), ('més', 14), ('suport', 14), ('molt', 13), ('🐦📢Tenim', 13), ('notícies!', 13), ('📢🐦', 13), ('informem', 13), ('començant', 13), ('gestar', 13), ("l'Atles", 13), ("d'Ocells", 13), ('Nidificants', 13), ('Maresme', 13), ('(2021-2024),', 13), ('Grup', 13), ('Natura', 13), ('Freixe', 13), ('presenta', 13), ("'Ciència", 13), ('són', 13), ('Aquesta', 12), ('crear', 12), ('Saps', 12), ('planàries', 12), ('considerades', 12), ('Són', 12), ('cucs', 12), ('aplanats', 12), ('països', 12), ('tropicals', 12), ('arriben', 12), ('Com', 11), ('d…', 11), ('setmana', 11), ('➡️2do', 11), ('día', 11), ('28/04', 11), ('🟢Ponència', 11), ("ApS'", 11), ('Membre', 11), ('🟠Experiencias', 11), ('recomanem', 10), ('descobrir', 10), ('amistosa', 10), ('Després', 10), ('tres', 10), ('cursos,', 10), ('oficialment', 10), ('on,', 10), ("d'@ISGLOBALorg", 10), ('I…', 10), ('Aquest', 9), ('fer', 9), ('✅', 9), ('Vols', 9), ('comença', 9), ('marina', 9), ('participen', 8), ('Estem', 8), ('contentes', 8), ('d’impulsar', 8), ('pilot', 8), ('costat', 8), ('vam', 8), ('participació', 7), ('”EXPLORA', 7), ('líquens”,', 7), ('marc', 7), ('BOSC', 7), ('sostenibilitat.', 7), ('Podràs', 7), ('Gràcies', 7), ("l'app", 7), ('📲', 7), ('➕', 7), ('|#TerresdelEbre', 7)]

# %% [markdown]
# Extract the number of occurrences of each word in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Word', 'Number of occurrences'])
df_most_occur.to_csv("words_CAT.csv")

# %% [markdown]
# Most common hashtags mentioned between the tweets.

# %%
hashtags = []
for word in tweets_arr:
    if word[0] == '#':
        hashtags.append(word)

from collections import Counter
Counter = Counter(hashtags)   
most_occur = Counter.most_common(40) 

print("The most common hashtags are: \n",most_occur)
# Out:
# The most common hashtags are:
#  [('#endometriosi', 42), ('#TRANSFORM', 34), ('#CiènciaCiutadana', 16), ('#EspècieInvasora?', 12), ('#CitizenScience:', 12), ('#ProjecteAtenció', 11), ('#VITrobadaApS', 11), ('#cienciaciutadana', 10), ('#RecorregutOCC', 9), ('#BioMARató🐙🌊,', 9), ('#biodiversitat', 9), ('#CienciaCiutadana', 8), ('#cucadellum', 7), ('#CiènciaCiutadana.', 7), ('#Barcelona', 6), ('#RiuNet', 6), ('#RiuNet,', 6), ('#SantJordi', 5), ('#líquens', 4), ('#Barcelona.', 4), ('#CiènciaCiutadana,', 4), ('#Didàctica', 4), ('#EpidemiologiaAmbiental!', 4), ('#ParcdelaCiència', 4), ('#LH,', 4), ('#olors', 4), ('#Biomarató', 4), ('#CitizenScience', 3), ('#ciènciaciutadana', 3), ('#PescadorsDePlàstic!', 3), ('#VigilantesdelAire', 3), ('#bibliolab,', 2), ('#ISC2bibliolab', 2), ('#BiblioLabXBM', 2), ('#educacio', 2), ('#Flix', 2), ('#TerresdelEbre', 2), ('#CiènciaCiut…', 2), ('#SetmanaSenseSoroll,', 2), ('#contaminació', 2)]

# %% [markdown]
# Extract the number of occurrences of each hashtag in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Hashtag', 'Number of mentions'])
df_most_occur.to_csv("hashtags_CAT.csv")

# %% [markdown]
# Most common accounts mentioned between the tweets.

# %%
accounts = []
for word in tweets_arr:
    if word[0] == '@':
        accounts.append(word)

from collections import Counter
Counter = Counter(accounts)
most_occur = Counter.most_common(40) 

print("The most common mentioned accounts are: \n",most_occur)
# Out:
# The most common mentioned accounts are:
#  [('@CCiutadana:', 36), ('@HospitalSantPau', 34), ('@DonaSantpau:', 33), ('@Ratpenats_Cat:', 20), ('@Nat_MonT_:', 13), ('@apscatalunya', 12), ('@Maribeldelact', 11), ('@mediambientcat:', 11), ('@RecerCaixa', 10), ('@apsCValenciana:', 10), ('@SciencefChange:', 10), ('@CrecimUab:', 9), ('@ACUPcat…', 9), ('@gnfreixe', 9), ('@AjuntamentFlix', 9), ('@CREAF_ecologia:', 8), ('@TRANSFORM_eu', 8), ('@la_UPC', 7), ('@mapagob', 7), ('@agriculturacat', 7), ('@territoricat', 7), ('@LifeInvasaqua', 7), ('@BIOTRAM_', 7), ('@pde', 7), ('@ch_ebro', 7), ('@ISGLOBALorg', 7), ('@CuquesdeLlumCat', 7), ('@Do…', 7), ('@ExploratoriRN:', 6), ('@CCiutadana', 6), ('@FEHMlab!', 6), ('@Adenc1982:', 6), ('@OpenSystemsUB', 6), ('@Leni_ElenaF:', 4), ('@liquensbcn,', 4), ('@CREAF_ecologia', 4), ('@Fundesplai', 4), ('@superguillemet', 4), ('@birdcatalunya', 4), ('@WebOryx', 4)]

# %% [markdown]
# Extract the number of occurrences of each account in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Account', 'Number of mentions'])
df_most_occur.to_csv("accounts_CAT.csv")

# %% [markdown]
# Find the average and the maximum number of likes and retweets between the tweets.

# %%
print("The maximum number of retweets is: ", max(retweets))
print("The average number of retweets is: ", int(np.mean(retweets)))
print("\nThe maximum number of likes is: ", max(likes))
print("The average number of likes is: ", int(np.mean(likes)))
# Out:
# The maximum number of retweets is:  34
# The average number of retweets is:  8
#
# The maximum number of likes is:  42
# The average number of likes is:  1

# %% [markdown]
# Most retweeted tweets

# %%
print("The most retweeted tweets are: \n")
data.nlargest(20, ['retweet_count'])['full_text']
# Out:
# The most retweeted tweets are:
# 115    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 148    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 153    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 156    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 157    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 160    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 165    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 176    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 177    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 178    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 179    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 182    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 186    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 187    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 188    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 190    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 192    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 193    Pateixes #endometriosi ?\nA @HospitalSantPau i...
# 195    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# 196    RT @DonaSantpau: Pateixes #endometriosi ?\nA @...
# Name: full_text, dtype: object

# %% [markdown]
# Most common source types.

# %%
src_data = data[data['extended_entities'].notna() == True]

src_type = []
for i in src_data.index:
    num_src = len(src_data.loc[i]['extended_entities']['media'])
    for n in range(0, num_src):
        src_type.append(src_data.loc[i]['extended_entities']['media'][n]['type'])

from collections import Counter 
Counter = Counter(src_type)   
most_occur = Counter.most_common(20) 

print("The most common source types are: \n", most_occur)
# Out:
# The most common source types are:
#  [('photo', 51), ('animated_gif', 3), ('video', 1)]

# %% [markdown]
# Extract the number of occurrences of each source type in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Source', 'Number of occurrences'])
df_most_occur.to_csv("sources_CAT.csv")

# %% [markdown]
# ## Analysis of the users interacting in Twitter about CS

# %% [markdown]
# Number of users interacting in CS.

# %%
user_ids = []
for u in users:
    if u['id'] not in user_ids:
        user_ids.append(u['id'])
print("There are ", len(user_ids), "active users.")
# Out:
# There are  232 active users.

# %% [markdown]
# Most active users between the tweets.

# %%
user_names = []
for u in users:
    user_names.append(u['screen_name'])

from collections import Counter
Counter = Counter(user_names)   
most_occur = Counter.most_common(20) 
    
print("The most active users are: \n", most_occur)
# Out:
# The most active users are:
#  [('CCiutadana', 5), ('SetmanariEbre', 5), ('XavierRomeraC', 4), ('Mosquito_Alert', 4), ('gnfreixe', 4), ('UDivulga', 4), ('SciencefChange', 4), ('CenmaIEA', 3), ('Ratpenats_Cat', 3), ('_carlosrodero', 3), ('fundesplai', 3), ('obsdelmar', 3), ('montse_llasat', 3), ('PlanctonDivulga', 3), ('ACCC_', 3), ('raultoran', 3), ('Ideas_4_Change', 3), ('territoricat', 2), ('bibcerdanyola', 2), ('mediambientcat', 2)]

# %% [markdown]
# Extract the number of times each user interacts in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['User', 'Number of interactions'])
df_most_occur.to_csv("users_CAT.csv")

# %% [markdown]
# Location, number of followers, number of statuses and number of likes of users

# %%
user_locations = []
user_followers = []
user_status = []
user_favorites = []
for u in users:
    user_locations.append(u['location'])
    user_followers.append([u['screen_name'],u['followers_count']])
    user_status.append([u['screen_name'],u['statuses_count']])
    user_favorites.append([u['screen_name'],u['favourites_count']])

# %% [markdown]
# Most common locations of published tweets

# %%
user_locations = filter(None, user_locations)
from collections import Counter
Counter = Counter(user_locations)   
most_occur = Counter.most_common(20) 

# Compute the total number of active users
total = 0
for i in range(0,20):
    total += most_occur[i][1]

# Percentages are added to each active users
for i in range(0,20):
    most_occur[i]= most_occur[i]+((most_occur[i][1]*100/total),)
    
print("The most common user's locations are: \n", most_occur)
# Out:
# The most common user's locations are:
#  [('Barcelona', 44, 34.92063492063492), ('Catalunya', 11, 8.73015873015873), ('Barcelona, Spain', 9, 7.142857142857143), ('Barcelona, Espanya', 9, 7.142857142857143), ('Granollers, Espanya', 6, 4.761904761904762), ('Vic', 6, 4.761904761904762), ('Barcelona, Catalunya', 5, 3.9682539682539684), ('Tortosa, Spain', 5, 3.9682539682539684), ('Tordera. Catalunya', 4, 3.1746031746031744), ('CREAF, Bellaterra', 4, 3.1746031746031744), ('Sant Julià de Lòria - ANDORRA', 3, 2.380952380952381), ("L'Ametlla de Mar", 3, 2.380952380952381), ('Barcelona, España', 3, 2.380952380952381), ('Cerdanyola del Vallès', 2, 1.5873015873015872), ('Pineda de Mar, Espanya', 2, 1.5873015873015872), ('Badalona', 2, 1.5873015873015872), ('República Catalana', 2, 1.5873015873015872), ('Montnegre i la Tordera', 2, 1.5873015873015872), ('Cornellà de Llobregat', 2, 1.5873015873015872), ('Blanes (Girona)', 2, 1.5873015873015872)]

# %% [markdown]
# Extract the number of tweets for each localization in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Localitzation', '# users active', '%'])
df_most_occur.to_csv("localitzations_CAT.csv")

# %%
print("The users with more followers are: \n", sorted(user_followers,key = lambda x: x[1])[::-1])
# Out:
# The users with more followers are:
#  [['salutcat', 144573], ['mediambientcat', 34607], ['territoricat', 34302], ['mediambientcat', 34163], ['territoricat', 33881], ['BibliotequesBCN', 26290], ['EstelSole', 15962], ['EstelSole', 15962], ['CREAF_ecologia', 15935], ['PDE', 13971], ['HospitalSantPau', 12204], ['ACCC_', 11451], ['ACCC_', 11451], ['ACCC_', 11451], ['Laia_Serra_', 9030], ['dissenyhub', 8628], ['canalte', 8538], ['canalte', 8538], ['buscaciencia', 8512], ['buscaciencia', 8512], ['marfanta', 8312], ['Revista_Metode', 8095], ['UManresa', 7965], ['MarcSerraSole', 7252], ['raultoran', 7022], ['raultoran', 7022], ['raultoran', 7022], ['Canal21Ebre', 6953], ['fundesplai', 6924], ['fundesplai', 6924], ['fundesplai', 6924], ['javicreus', 6195], ['TafallaMarta', 6181], ['Josep_Trigo', 6035], ['Ideas_4_Change', 5842], ['Ideas_4_Change', 5842], ['Ideas_4_Change', 5842], ['VolAmbiental', 5781], ['CoopSciScoop', 5703], ['AjuntamentBerga', 5449], ['birdcatalunya', 5370], ['birdcatalunya', 5370], ['apscatalunya', 5192], ['Mosquito_Alert', 5030], ['Mosquito_Alert', 5029], ['Mosquito_Alert', 5029], ['Mosquito_Alert', 5029], ['obsdelmar', 4974], ['obsdelmar', 4974], ['obsdelmar', 4924], ['GVA_Cefire', 4695], ['ACUPcatalunya', 4496], ['jdomenechca', 4352], ['UDivulga', 4107], ['UDivulga', 4107], ['UDivulga', 4107], ['UDivulga', 4107], ['Muntsamar', 4034], ['WebOryx', 3848], ['ceabcsic', 3586], ['ACCUCatalunya', 3582], ['ceabcsic', 3575], ['BeyondBCN', 3515], ['macmeck_cat', 3497], ['ebredigitalcat', 3442], ['ebredigitalcat', 3442], ['infosalut', 3345], ['PlanctonDivulga', 2940], ['PlanctonDivulga', 2940], ['PlanctonDivulga', 2940], ['burguillosmf', 2890], ['victorlopezsbd', 2851], ['CanodromBCN', 2710], ['bibliotequesgr', 2610], ['bibliotequesgr', 2610], ['SmartCitizenKit', 2536], ['idisbaib', 2517], ['sferrebenedicto', 2499], ['sferrebenedicto', 2499], ['asolepascual', 2463], ['CCiutadana', 2401], ['CCiutadana', 2401], ['CCiutadana', 2401], ['CCiutadana', 2401], ['EsEndometriosis', 2398], ['CCiutadana', 2360], ['iramunt', 2297], ['mcngranollers', 2214], ['VilaUrania', 2169], ['VilaUrania', 2169], ['jsolerga91', 2164], ['BETA_TechCenter', 2149], ['OpenSciTalk', 2040], ['conresortes', 1984], ['CEFIREambitCTEM', 1948], ['fundacioemys', 1897], ['DigitalixMx', 1894], ['SetmanariEbre', 1810], ['SetmanariEbre', 1810], ['SetmanariEbre', 1810], ['SetmanariEbre', 1810], ['SetmanariEbre', 1810], ['BHumanitatsUAB', 1797], ['REDAPS1', 1796], ['MuseuAigues', 1684], ['MuseuAigues', 1684], ['s_valls', 1669], ['s_valls', 1669], ['DonaSantpau', 1661], ['DonaSantpau', 1661], ['fundterra', 1623], ['bibolesa', 1622], ['gnfreixe', 1606], ['gnfreixe', 1606], ['gnfreixe', 1606], ['gnfreixe', 1606], ['ApSExtremadura', 1605], ['ACAFssc', 1603], ['Adenc1982', 1535], ['RosaAriasAlv', 1526], ['CrecimUab', 1519], ['tere1982_', 1472], ['CitieSHealthEU', 1458], ['CitieSHealthEU', 1458], ['XavierRomeraC', 1417], ['XavierRomeraC', 1364], ['XavierRomeraC', 1364], ['bibcerdanyola', 1364], ['XavierRomeraC', 1364], ['bibcerdanyola', 1364], ['MoyaFrancesc', 1353], ['csmontseny', 1340], ['ICEUPC', 1325], ['bcn_pedagogica', 1324], ['felip_lorenzo', 1271], ['CenmaIEA', 1262], ['GNOsonaICHN', 1253], ['CenmaIEA', 1227], ['CenmaIEA', 1227], ['kumar_ranjeet', 1155], ['jmaurir', 1128], ['jmaurir', 1128], ['Xatrac_org', 1098], ['Xatrac_org', 1098], ['rosa_bayot', 1072], ['conceagusti', 1071], ['FEHMlab', 1007], ['tarressolar', 974], ['RCO_journal', 968], ['shalmodovar', 955], ['elibroglio', 902], ['elibroglio', 902], ['Cos4Cloud', 895], ['quiquevergara', 851], ['UPCdivulga', 848], ['Kirtash80', 820], ['greenfrombarce1', 818], ['apsCValenciana', 811], ['jorditb', 805], ['Arleccino1', 796], ['ExploratoriRN', 759], ['Noe_Ona', 757], ['peptomas', 746], ['illasat', 743], ['inspuigvert', 741], ['mferrafarre', 737], ['inspuigvert', 737], ['illasat', 734], ['Nat_MonT_', 730], ['Nat_MonT_', 730], ['SciencefChange', 726], ['SciencefChange', 726], ['SciencefChange', 726], ['SciencefChange', 726], ['rafa_kuhl', 714], ['CarlesXifr ...

# %%
print("The users with more statuses are: \n", sorted(user_status,key = lambda x: x[1])[::-1])
# Out:
# The users with more statuses are:
#  [['s_valls', 266484], ['s_valls', 266484], ['DigitalixMx', 214491], ['kumar_ranjeet', 194814], ['tarressolar', 172887], ['TafallaMarta', 159158], ['asolepascual', 135752], ['Muntsamar', 106910], ['martiserrano', 95848], ['canalte', 80342], ['canalte', 80342], ['mahinka03', 79101], ['SmartCitizenKit', 76937], ['Nuvolari78', 60460], ['infosalut', 56345], ['Kirtash80', 54359], ['OpenSciTalk', 54335], ['monmas3', 52725], ['SetmanariEbre', 50175], ['SetmanariEbre', 50175], ['SetmanariEbre', 50175], ['SetmanariEbre', 50175], ['SetmanariEbre', 50175], ['Canal21Ebre', 47042], ['marfanta', 45866], ['UManresa', 42672], ['ebredigitalcat', 41120], ['ebredigitalcat', 41120], ['raultoran', 40596], ['raultoran', 40596], ['raultoran', 40596], ['sferrebenedicto', 40447], ['sferrebenedicto', 40447], ['mediambientcat', 39195], ['BeyondBCN', 38870], ['mediambientcat', 38766], ['tere1982_', 38746], ['fundesplai', 37711], ['fundesplai', 37711], ['fundesplai', 37711], ['comaposadajordi', 37100], ['XavierRomeraC', 36389], ['XavierRomeraC', 35141], ['XavierRomeraC', 35141], ['XavierRomeraC', 35141], ['PDE', 34523], ['BibliotequesBCN', 32032], ['UDivulga', 31905], ['UDivulga', 31905], ['UDivulga', 31905], ['UDivulga', 31905], ['Josep_Trigo', 30781], ['territoricat', 29704], ['ACCUCatalunya', 29468], ['territoricat', 29120], ['buscaciencia', 29003], ['buscaciencia', 29003], ['macmeck_cat', 28719], ['CoopSciScoop', 27224], ['conceagusti', 26849], ['rosa_bayot', 25537], ['salutcat', 25166], ['ACCC_', 19375], ['ACCC_', 19375], ['ACCC_', 19375], ['MarcSerraSole', 18951], ['iramunt', 17626], ['annabet67', 17511], ['CREAF_ecologia', 17134], ['VolAmbiental', 16610], ['SanzAgell', 15471], ['talp_13', 15378], ['EstelSole', 15129], ['EstelSole', 15129], ['jmaurir', 14804], ['jmaurir', 14804], ['jdomenechca', 14336], ['elcargoldelona', 13585], ['Arleccino1', 13412], ['birdcatalunya', 12820], ['birdcatalunya', 12820], ['StixAluco', 12650], ['AjuntamentBerga', 11898], ['Laia_Serra_', 11716], ['felip_lorenzo', 11512], ['pepinvaldes', 11322], ['AHEGalicia', 11263], ['MCarmeJF74', 10340], ['HospitalSantPau', 10221], ['rafa_kuhl', 10181], ['crisserradell', 10000], ['ACUPcatalunya', 9923], ['MontseRom73', 9913], ['Revista_Metode', 9793], ['Mosquito_Alert', 9687], ['javicreus', 9611], ['Mosquito_Alert', 9591], ['Mosquito_Alert', 9591], ['Mosquito_Alert', 9591], ['apscatalunya', 9392], ['MoyaFrancesc', 9375], ['idisbaib', 9323], ['quelandries', 9274], ['victorlopezsbd', 9244], ['burguillosmf', 9243], ['Noe_Ona', 8926], ['dissenyhub', 8905], ['jorditb', 8657], ['BHumanitatsUAB', 8587], ['alexrollan', 8504], ['VilaUrania', 8262], ['VilaUrania', 8262], ['greenfrombarce1', 8211], ['ExploratoriRN', 8060], ['illasat', 7912], ['illasat', 7856], ['EsEndometriosis', 7854], ['conxita10741575', 7254], ['jpujolco', 6927], ['SaraGutierrezEn', 6811], ['jsolerga91', 6756], ['PlanctonDivulga', 6750], ['PlanctonDivulga', 6750], ['PlanctonDivulga', 6750], ['shalmodovar', 6694], ['S_Morgenstern', 6675], ['CristinaBotaCos', 6481], ['desongles10', 6284], ['TxeliTic', 6282], ['ICEUPC', 6173], ['CEFIREambitCTEM', 6122], ['bibliotequesgr', 6116], ['bibliotequesgr', 6116], ['marcjimenezt', 5949], ['WebOryx', 5861], ['bibolesa', 5752], ['lopezvilaj', 5512], ['carlesvin', 5483], ['rcrcugat11', 5443], ['CarlesXifra', 5411], ['trinitat_s', 5193], ['EspinetPere', 5139], ['ApSExtremadura', 5096], ['bibcerdanyola', 5064], ['bibcerdanyola', 5064], ['ceabcsic', 5038], ['ceabcsic', 4946], ['conresortes', 4939], ['MuseuAigues', 4811], ['MuseuAigues', 4811], ['obsdelmar', 4756], ['obsdelmar', 4756], ['pm10no2', 4627], ['obsdelmar', 4596], ['GVA_Cefire', 4502], ['CanodromBCN', 4253], ['quiquevergara', 4200], ['Ideas_4_Change', 3932], ['Ideas_4_Change', 3932], ['Ideas_4_Change', 3932], ['Xabedo', 3922], ['CitieSHealthEU', 3846], ['CitieSHealthEU', 3846], ['RosaAriasAlv', 3779], ['5gRevol', 3674], ['bcn_pedagogica', 3562], ['Jordi_Iranzo', 3467], ['mferrafarre', 3291], ['DVilasisBoix', 3209], ['JordiRofesFlix', ...

# %%
print("The users with more likes are: \n", sorted(user_favorites,key = lambda x: x[1])[::-1])
# Out:
# The users with more likes are:
#  [['Muntsamar', 318787], ['TafallaMarta', 108995], ['tere1982_', 100078], ['s_valls', 95183], ['s_valls', 95183], ['BeyondBCN', 88772], ['raultoran', 80875], ['raultoran', 80875], ['raultoran', 80875], ['annabet67', 69261], ['Josep_Trigo', 55219], ['conxita10741575', 52604], ['UDivulga', 49577], ['UDivulga', 49577], ['UDivulga', 49577], ['UDivulga', 49577], ['EspinetPere', 43366], ['jmaurir', 37118], ['jmaurir', 37118], ['elcargoldelona', 36135], ['Kirtash80', 34637], ['monmas3', 34453], ['Nuvolari78', 33327], ['rosa_bayot', 32880], ['EstelSole', 32803], ['EstelSole', 32803], ['martiserrano', 29830], ['BibliotequesBCN', 29629], ['Arleccino1', 27795], ['burguillosmf', 27673], ['birdcatalunya', 26314], ['birdcatalunya', 26314], ['rafa_kuhl', 23073], ['SanzAgell', 22875], ['macmeck_cat', 22525], ['HospitalSantPau', 22347], ['MarcSerraSole', 20117], ['5gRevol', 18286], ['VolAmbiental', 18211], ['felip_lorenzo', 17812], ['victorlopezsbd', 17530], ['SaraGutierrezEn', 16175], ['ACCUCatalunya', 16033], ['piratadebanyera', 15574], ['MCarmeJF74', 15246], ['ACCC_', 15176], ['ACCC_', 15176], ['ACCC_', 15176], ['MontseRom73', 15162], ['jsolerga91', 14807], ['CristinaCR82', 14586], ['mahinka03', 14352], ['XavierRomeraC', 14050], ['quelandries', 13492], ['greenfrombarce1', 13216], ['XavierRomeraC', 13058], ['XavierRomeraC', 13058], ['XavierRomeraC', 13058], ['StixAluco', 12931], ['jdomenechca', 12903], ['alexrollan', 12528], ['illasat', 12209], ['illasat', 12054], ['desongles10', 11859], ['EsEndometriosis', 10751], ['VilaUrania', 10556], ['VilaUrania', 10556], ['CREAF_ecologia', 10297], ['fundesplai', 10104], ['fundesplai', 10104], ['fundesplai', 10104], ['jorditb', 10080], ['rcrcugat11', 10059], ['tarressolar', 9714], ['ACUPcatalunya', 9692], ['obsdelmar', 9678], ['obsdelmar', 9678], ['crisserradell', 9530], ['obsdelmar', 9527], ['DVilasisBoix', 8958], ['dissenyhub', 8956], ['Jordi_Iranzo', 8883], ['CoopSciScoop', 8783], ['quiquevergara', 8332], ['shalmodovar', 7824], ['conceagusti', 7795], ['pm10no2', 7739], ['apscatalunya', 7733], ['carmonaalcolea', 7170], ['bibolesa', 7128], ['Mosquito_Alert', 7068], ['Mosquito_Alert', 6993], ['Mosquito_Alert', 6993], ['Mosquito_Alert', 6993], ['CanodromBCN', 6941], ['montse_llasat', 6823], ['bibliotequesgr', 6806], ['bibliotequesgr', 6806], ['montse_llasat', 6763], ['montse_llasat', 6763], ['ICEUPC', 6621], ['PochSantiago', 6583], ['idisbaib', 6402], ['elibroglio', 5945], ['elibroglio', 5945], ['talp_13', 5944], ['ApSExtremadura', 5894], ['julianvicens', 5745], ['julianvicens', 5745], ['CitieSHealthEU', 5731], ['CitieSHealthEU', 5731], ['PlanctonDivulga', 5662], ['PlanctonDivulga', 5662], ['PlanctonDivulga', 5662], ['pepinvaldes', 5614], ['canalte', 5577], ['canalte', 5577], ['Noe_Ona', 5527], ['mediambientcat', 5499], ['UManresa', 5356], ['mediambientcat', 5332], ['GSBioblitz', 5237], ['CEFIREambitCTEM', 5173], ['ceabcsic', 4942], ['buscaciencia', 4848], ['buscaciencia', 4848], ['ceabcsic', 4828], ['MartonaAlvarez', 4680], ['MartonaAlvarez', 4680], ['MoyaFrancesc', 4609], ['marfanta', 4440], ['jesus7348', 4401], ['CarlesXifra', 4284], ['GVA_Cefire', 4271], ['marcjimenezt', 4267], ['territoricat', 4251], ['territoricat', 4196], ['jpujolco', 4181], ['bibcerdanyola', 4114], ['bibcerdanyola', 4114], ['mferrafarre', 4100], ['JordiRofesFlix', 3998], ['javicreus', 3785], ['WildestWanderer', 3696], ['RosaAriasAlv', 3681], ['comaposadajordi', 3657], ['salutcat', 3575], ['antoni_colom', 3527], ['trinitat_s', 3457], ['conresortes', 3360], ['carlesvin', 3287], ['WebOryx', 3252], ['pia_jo', 3211], ['oscaraleman_m', 3205], ['ExploratoriRN', 3181], ['lollop78', 3166], ['MuseuAigues', 3162], ['MuseuAigues', 3162], ['Ideas_4_Change', 3160], ['Ideas_4_Change', 3160], ['Ideas_4_Change', 3160], ['BETA_TechCenter', 3013], ['fundacioemys', 2994], ['peptomas', 2969], ['Xabedo', 2943], ['ACAFssc', 2928], ['Cos4Cloud', 2749], ['BHumanitatsUAB', 2632], ['Ratpenats_Cat', 2547], ['Ratpenats_Cat', 2547], ['Ratpenats_Cat', 2547], [ ...

# %% [markdown]
# ### Check data before and after COVID-19

# %% [markdown]
# Division of the database in before COVID-19 and after COVID-19

# %%
from datetime import datetime
before_covid = pd.DataFrame()
after_covid = pd.DataFrame()
for i in range(0, len(data)):
    item = data.iloc[i]

    year = item['created_at'][-4:]
    month = item['created_at'][4:7]
    month = convert_month(str(month))
    day = item['created_at'][8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    date =  pd.Timestamp(date)

    if(date < pd.Timestamp('2020-3-14')):
        before_covid.append(item)
    else:
        after_covid = after_covid.append(item)

after_covid
# Out:
#                           _id contributors coordinates  \
# 0    6037cc67ee0a6e2f74656259         None        None
# 1    6037cc67ee0a6e2f7465625a         None        None
# 2    6037cc67ee0a6e2f7465625b         None        None
# 3    6037cc67ee0a6e2f7465625c         None        None
# 4    6037cc67ee0a6e2f7465625d         None        None
# ..                        ...          ...         ...
# 308  608872fe3c972623d0aa6904         None        None
# 310  608872fe3c972623d0aa68fc         None        None
# 311  608872fe3c972623d0aa68ff         None        None
# 312  608872fe3c972623d0aa6903         None        None
# 313  608872fe3c972623d0aa6900         None        None
#
#                          created_at display_text_range  \
# 0    Thu Feb 25 08:36:50 +0000 2021           [0, 257]
# 1    Thu Feb 25 05:50:37 +0000 2021           [0, 140]
# 2    Wed Feb 24 21:47:06 +0000 2021           [0, 140]
# 3    Wed Feb 24 20:49:38 +0000 2021           [0, 118]
# 4    Wed Feb 24 13:31:46 +0000 2021           [0, 140]
# ..                              ...                ...
# 308  Mon Apr 26 14:29:04 +0000 2021           [0, 140]
# 310  Tue Apr 27 15:22:14 +0000 2021           [0, 140]
# 311  Tue Apr 27 12:51:20 +0000 2021           [0, 140]
# 312  Mon Apr 26 15:45:57 +0000 2021           [0, 140]
# 313  Tue Apr 27 12:37:29 +0000 2021           [0, 140]
#
#                                               entities  \
# 0    {'hashtags': [], 'symbols': [], 'user_mentions...
# 1    {'hashtags': [], 'symbols': [], 'user_mentions...
# 2    {'hashtags': [], 'symbols': [], 'user_mentions...
# 3    {'hashtags': [], 'symbols': [], 'user_mentions...
# 4    {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                                                 ...
# 308  {'hashtags': [], 'symbols': [], 'user_mentions...
# 310  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 311  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 312  {'hashtags': [], 'symbols': [], 'user_mentions...
# 313  {'hashtags': [{'text': 'CitizenScience', 'indi...
#
#                                      extended_entities  favorite_count  \
# 0                                                  NaN             2.0
# 1                                                  NaN             0.0
# 2                                                  NaN             0.0
# 3    {'media': [{'id': '1363955294989123586', 'id_s...             0.0
# 4                                                  NaN             0.0
# ..                                                 ...             ...
# 308                                                NaN             0.0
# 310                                                NaN             0.0
# 311                                                NaN             0.0
# 312                                                NaN             0.0
# 313                                                NaN             0.0
#
#      favorited                                          full_text  ...  \
# 0          0.0  Lectura de dijous: Ornitho i la ciència ciutad...  ...
# 1          0.0  RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...  ...
# 2          0.0  RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...  ...
# 3          0.0  RT @Leni_ElenaF: Disfrutar mentre fas ciencia ...  ...
# 4          0.0  RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...  ...
# ..         ...                                                ...  ...
# 308        0.0  RT @CCiutadana: 🌊 Mostreig i 🔎 anàlisi de la r...  ...
# 310        0.0  RT @CCiutadana: 👉 @OpenSystemsUB acaba de publ...  ...
# 311        0.0  RT @CCiutadana: 👉 @OpenSystemsUB acaba de publ...  ...
# 312        0.0  RT @CCiutadana: 🌊 Mostreig i 🔎 anàlisi de la r...  ...
# 313        0.0  RT @CCiutadana: 👉 @OpenSystemsUB acaba de publ...  ...
#
#     possibly_sensitive quoted_status     quoted_status_id  \
# 0                  0.0           NaN                  NaN
# 1                  0.0           NaN                  NaN
# 2                  0.0           NaN                  NaN
# 3                  0.0           NaN                  NaN
# 4                  0.0           NaN                  NaN
# ..                 ...           ...                  ...
# 308                NaN           NaN                  NaN
# 310                NaN           NaN  1384880502134480906
# 311                NaN           NaN  1384880502134480906
# 312                NaN           NaN                  NaN
# 313                NaN           NaN  1384880502134480906
#
#     quoted_status_id_str retweet_count retweeted  \
# 0                    NaN           0.0       0.0
# 1                    NaN          17.0       0.0
# 2                    NaN          17.0       0.0
# 3                    NaN           4.0       0.0
# 4                    NaN          17.0       0.0
# ..                   ...           ...       ...
# 308                  NaN           2.0       0.0
# 310  1384880502134480906           6.0       0.0
# 311  1384880502134480906           6.0       0.0
# 312                  NaN           2.0       0.0
# 313  1384880502134480906           6.0       0.0
#
#                                       retweeted_status  \
# 0                                                  NaN
# 1    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# 2    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# 3    {'created_at': 'Mon Feb 22 20:54:18 +0000 2021...
# 4    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# ..                                                 ...
# 308  {'created_at': 'Mon Apr 26 14:24:00 +0000 2021...
# 310  {'created_at': 'Tue Apr 27 11:25:22 +0000 2021...
# 311  {'created_at': 'Tue Apr 27 11:25:22 +0000 2021...
# 312  {'created_at': 'Mon Apr 26 14:24:00 +0000 2021...
# 313  {'created_at': 'Tue Apr 27 11:25:22 +0000 2021...
#
#                                                 source  truncated  \
# 0    <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 1    <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 2    <a href="http://twitter.com/download/android" ...        0.0
# 3    <a href="http://twitter.com/download/android" ...        0.0
# 4    <a href="https://www.hootsuite.com" rel="nofol...        0.0
# ..                                                 ...        ...
# 308  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 310  <a href="http://twitter.com/download/iphone" r...        0.0
# 311  <a href="http://twitter.com/download/android" ...        0.0
# 312  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 313  <a href="https://mobile.twitter.com" rel="nofo...        0.0
#
#                                                   user
# 0    {'id': 2829700163, 'id_str': '2829700163', 'na...
# 1    {'id': '1119291975168077827', 'id_str': '11192...
# 2    {'id': '1047928531865522176', 'id_str': '10479...
# 3    {'id': 890804618, 'id_str': '890804618', 'name...
# 4    {'id': 110405142, 'id_str': '110405142', 'name...
# ..                                                 ...
# 308  {'id': '1053197332840411136', 'id_str': '10531...
# 310  {'id': 307255715, 'id_str': '307255715', 'name...
# 311  {'id': 1516529982, 'id_str': '1516529982', 'na...
# 312  {'id': 2320865671, 'id_str': '2320865671', 'na...
# 313  {'id': 14902471, 'id_str': '14902471', 'name':...
#
# [300 rows x 32 columns]
