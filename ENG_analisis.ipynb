# %% [markdown]
# # Analysis of ENGLISH  Twitter data

# %% [markdown]
# Imports

# %%
import json
import pandas as pd
import numpy as np
from math import isnan
import pymongo
from pymongo import MongoClient
import json

# %% [markdown]
# ### Read data from MongoDB database

# %%
class Scraper:
    def __init__(self):
        
        #Mongodb connection
        self.conn = MongoClient('mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')

        #Mongodb database and repository
        db = self.conn.Stucom

        #Collections
        self.CAT =  db.CAT 
    
    def visualize_values(self): 

        # take the values
        values = self.CAT.find() 
        
        # go through the values of the object "pymongo"
        for i in values: 
            print(i)



if __name__ == "__main__":

    scraper = Scraper()
    scraper.visualize_values()

# %%
# Get the database
client = MongoClient("mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true")

db = client["ENG"]
col = db["CS"]
data = pd.DataFrame(list(col.find()))

# %% [markdown]
# Visualization of the data

# %%
data
# Out:
#                             _id                      created_at  \
# 0      606dc3064e60b42720327dfb  Wed Apr 07 14:32:35 +0000 2021
# 1      606dc3064e60b42720327dfc  Wed Apr 07 14:27:40 +0000 2021
# 2      606dc3064e60b42720327dfd  Wed Apr 07 14:27:01 +0000 2021
# 3      606dc3064e60b42720327dfe  Wed Apr 07 14:26:24 +0000 2021
# 4      606dc3064e60b42720327dff  Wed Apr 07 14:24:58 +0000 2021
# ...                         ...                             ...
# 30057  609914bb00d62321fcefa439  Mon May 03 16:05:08 +0000 2021
# 30058  609914bb00d62321fcefa422  Tue May 04 03:13:11 +0000 2021
# 30059  609914bb00d62321fcefa42e  Mon May 03 17:28:32 +0000 2021
# 30060  609914bb00d62321fcefa419  Tue May 04 10:28:52 +0000 2021
# 30061  609914bb00d62321fcefa430  Mon May 03 16:53:33 +0000 2021
#
#                         id               id_str  \
# 0      1379804302890373121  1379804302890373121
# 1      1379803063398105100  1379803063398105100
# 2      1379802901355319404  1379802901355319404
# 3      1379802742739202048  1379802742739202048
# 4      1379802385694912513  1379802385694912513
# ...                    ...                  ...
# 30057  1389249675497250821  1389249675497250821
# 30058  1389417796367372288  1389417796367372288
# 30059  1389270663333097476  1389270663333097476
# 30060  1389527441949921280  1389527441949921280
# 30061  1389261859484684292  1389261859484684292
#
#                                                full_text  truncated  \
# 0      RT @pkhardy: Looking for forward to my panel w...      False
# 1      RT @AmPhilSociety: #CitSciAPS today is all abo...      False
# 2      RT @BristolZooGdns: We're working with @Offici...      False
# 3      RT @Unistellar: Millions of asteroids exist in...      False
# 4      RT @RAOastronomy: Explore your dark sky. The R...      False
# ...                                                  ...        ...
# 30057  #CitSciVirtual is starting now! @CitSciAssoc h...      False
# 30058  RT @SciStarter: Meet the scientists behind NAS...      False
# 30059  RT @FieldKitOrg: Catch a few of our friends an...      False
# 30060  RT @Cos4Cloud: Are you attending the #CitSciVi...      False
# 30061  "We're all in the same boat as it comes to add...      False
#
#       display_text_range                                           entities  \
# 0               [0, 148]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1               [0, 140]  {'hashtags': [{'text': 'CitSciAPS', 'indices':...
# 2               [0, 144]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3               [0, 140]  {'hashtags': [{'text': 'planets', 'indices': [...
# 4               [0, 144]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                  ...                                                ...
# 30057            [0, 44]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 30058           [0, 143]  {'hashtags': [{'text': 'NASACitSciCon', 'indic...
# 30059           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 30060           [0, 139]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 30061           [0, 275]  {'hashtags': [{'text': 'CitSciVitural', 'indic...
#
#                                                 metadata  \
# 0      {'iso_language_code': 'en', 'result_type': 're...
# 1      {'iso_language_code': 'en', 'result_type': 're...
# 2      {'iso_language_code': 'en', 'result_type': 're...
# 3      {'iso_language_code': 'en', 'result_type': 're...
# 4      {'iso_language_code': 'en', 'result_type': 're...
# ...                                                  ...
# 30057  {'iso_language_code': 'en', 'result_type': 're...
# 30058  {'iso_language_code': 'en', 'result_type': 're...
# 30059  {'iso_language_code': 'en', 'result_type': 're...
# 30060  {'iso_language_code': 'en', 'result_type': 're...
# 30061  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                   source  ...  \
# 0      <a href="http://twitter.com/download/android" ...  ...
# 1      <a href="https://mobile.twitter.com" rel="nofo...  ...
# 2      <a href="http://twitter.com/download/iphone" r...  ...
# 3      <a href="https://mobile.twitter.com" rel="nofo...  ...
# 4      <a href="https://mobile.twitter.com" rel="nofo...  ...
# ...                                                  ...  ...
# 30057  <a href="https://mobile.twitter.com" rel="nofo...  ...
# 30058  <a href="http://twitter.com/download/android" ...  ...
# 30059  <a href="http://twitter.com/download/android" ...  ...
# 30060  <a href="http://twitter.com/download/android" ...  ...
# 30061  <a href="https://mobile.twitter.com" rel="nofo...  ...
#
#           quoted_status_id quoted_status_id_str retweet_count favorite_count  \
# 0      1379793795034849283  1379793795034849283             1              0
# 1                      NaN                  NaN             1              0
# 2                      NaN                  NaN             6              0
# 3                      NaN                  NaN             2              0
# 4                      NaN                  NaN             9              0
# ...                    ...                  ...           ...            ...
# 30057                  NaN                  NaN             1              2
# 30058                  NaN                  NaN            17              0
# 30059                  NaN                  NaN             6              0
# 30060                  NaN                  NaN             4              0
# 30061                  NaN                  NaN             0              5
#
#       favorited retweeted lang quoted_status possibly_sensitive  \
# 0         False     False   en           NaN                NaN
# 1         False     False   en           NaN                NaN
# 2         False     False   en           NaN                NaN
# 3         False     False   en           NaN                NaN
# 4         False     False   en           NaN                NaN
# ...         ...       ...  ...           ...                ...
# 30057     False     False   en           NaN              False
# 30058     False     False   en           NaN                NaN
# 30059     False     False   en           NaN                NaN
# 30060     False     False   en           NaN                NaN
# 30061     False     False   en           NaN                NaN
#
#                                        extended_entities
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30057  {'media': [{'id': '1389249670917021696', 'id_s...
# 30058                                                NaN
# 30059                                                NaN
# 30060                                                NaN
# 30061                                                NaN
#
# [30062 rows x 32 columns]

# %% [markdown]
# ### Quit outliers

# %% [markdown]
# Delete repeated tweets.

# %%
data = data.drop_duplicates(subset=['id'])
data = data.reset_index(drop=True)
data
# Out:
#                             _id                      created_at  \
# 0      606dc3064e60b42720327dfb  Wed Apr 07 14:32:35 +0000 2021
# 1      606dc3064e60b42720327dfc  Wed Apr 07 14:27:40 +0000 2021
# 2      606dc3064e60b42720327dfd  Wed Apr 07 14:27:01 +0000 2021
# 3      606dc3064e60b42720327dfe  Wed Apr 07 14:26:24 +0000 2021
# 4      606dc3064e60b42720327dff  Wed Apr 07 14:24:58 +0000 2021
# ...                         ...                             ...
# 24614  609914bb00d62321fcefa43f  Sun May 02 18:34:01 +0000 2021
# 24615  609914bb00d62321fcefa41a  Tue May 04 10:21:11 +0000 2021
# 24616  609914bb00d62321fcefa439  Mon May 03 16:05:08 +0000 2021
# 24617  609914bb00d62321fcefa419  Tue May 04 10:28:52 +0000 2021
# 24618  609914bb00d62321fcefa430  Mon May 03 16:53:33 +0000 2021
#
#                         id               id_str  \
# 0      1379804302890373121  1379804302890373121
# 1      1379803063398105100  1379803063398105100
# 2      1379802901355319404  1379802901355319404
# 3      1379802742739202048  1379802742739202048
# 4      1379802385694912513  1379802385694912513
# ...                    ...                  ...
# 24614  1388924755890290700  1388924755890290700
# 24615  1389525507750842372  1389525507750842372
# 24616  1389249675497250821  1389249675497250821
# 24617  1389527441949921280  1389527441949921280
# 24618  1389261859484684292  1389261859484684292
#
#                                                full_text  truncated  \
# 0      RT @pkhardy: Looking for forward to my panel w...      False
# 1      RT @AmPhilSociety: #CitSciAPS today is all abo...      False
# 2      RT @BristolZooGdns: We're working with @Offici...      False
# 3      RT @Unistellar: Millions of asteroids exist in...      False
# 4      RT @RAOastronomy: Explore your dark sky. The R...      False
# ...                                                  ...        ...
# 24614  Save the date! We'll be presenting at #CitSciV...      False
# 24615  Are you attending the #CitSciVirtual, organize...      False
# 24616  #CitSciVirtual is starting now! @CitSciAssoc h...      False
# 24617  RT @Cos4Cloud: Are you attending the #CitSciVi...      False
# 24618  "We're all in the same boat as it comes to add...      False
#
#       display_text_range                                           entities  \
# 0               [0, 148]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1               [0, 140]  {'hashtags': [{'text': 'CitSciAPS', 'indices':...
# 2               [0, 144]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3               [0, 140]  {'hashtags': [{'text': 'planets', 'indices': [...
# 4               [0, 144]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                  ...                                                ...
# 24614           [0, 236]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 24615           [0, 266]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 24616            [0, 44]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 24617           [0, 139]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 24618           [0, 275]  {'hashtags': [{'text': 'CitSciVitural', 'indic...
#
#                                                 metadata  \
# 0      {'iso_language_code': 'en', 'result_type': 're...
# 1      {'iso_language_code': 'en', 'result_type': 're...
# 2      {'iso_language_code': 'en', 'result_type': 're...
# 3      {'iso_language_code': 'en', 'result_type': 're...
# 4      {'iso_language_code': 'en', 'result_type': 're...
# ...                                                  ...
# 24614  {'iso_language_code': 'en', 'result_type': 're...
# 24615  {'iso_language_code': 'en', 'result_type': 're...
# 24616  {'iso_language_code': 'en', 'result_type': 're...
# 24617  {'iso_language_code': 'en', 'result_type': 're...
# 24618  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                   source  ...  \
# 0      <a href="http://twitter.com/download/android" ...  ...
# 1      <a href="https://mobile.twitter.com" rel="nofo...  ...
# 2      <a href="http://twitter.com/download/iphone" r...  ...
# 3      <a href="https://mobile.twitter.com" rel="nofo...  ...
# 4      <a href="https://mobile.twitter.com" rel="nofo...  ...
# ...                                                  ...  ...
# 24614  <a href="https://buffer.com" rel="nofollow">Bu...  ...
# 24615  <a href="https://mobile.twitter.com" rel="nofo...  ...
# 24616  <a href="https://mobile.twitter.com" rel="nofo...  ...
# 24617  <a href="http://twitter.com/download/android" ...  ...
# 24618  <a href="https://mobile.twitter.com" rel="nofo...  ...
#
#           quoted_status_id quoted_status_id_str retweet_count favorite_count  \
# 0      1379793795034849283  1379793795034849283             1              0
# 1                      NaN                  NaN             1              0
# 2                      NaN                  NaN             6              0
# 3                      NaN                  NaN             2              0
# 4                      NaN                  NaN             9              0
# ...                    ...                  ...           ...            ...
# 24614                  NaN                  NaN             0              3
# 24615                  NaN                  NaN             4              7
# 24616                  NaN                  NaN             1              2
# 24617                  NaN                  NaN             4              0
# 24618                  NaN                  NaN             0              5
#
#       favorited retweeted lang quoted_status possibly_sensitive  \
# 0         False     False   en           NaN                NaN
# 1         False     False   en           NaN                NaN
# 2         False     False   en           NaN                NaN
# 3         False     False   en           NaN                NaN
# 4         False     False   en           NaN                NaN
# ...         ...       ...  ...           ...                ...
# 24614     False     False   en           NaN              False
# 24615     False     False   en           NaN              False
# 24616     False     False   en           NaN              False
# 24617     False     False   en           NaN                NaN
# 24618     False     False   en           NaN                NaN
#
#                                        extended_entities
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 24614                                                NaN
# 24615  {'media': [{'id': '1389524696769650688', 'id_s...
# 24616  {'media': [{'id': '1389249670917021696', 'id_s...
# 24617                                                NaN
# 24618                                                NaN
#
# [24619 rows x 32 columns]

# %% [markdown]
# Check that all tweets are in English

# %%
data = data[data['lang'] == 'en']

# %% [markdown]
# Delete tweets that are outside the desired range of dates

# %%
for i in range(0, len(data)):   
    item = data.iloc[i]
    
    if(int(item['created_at'][-4:])) < int(2021):
        data.drop([i],  inplace = True)

# %% [markdown]
# ### Treat the data to extract conclusions

# %% [markdown]
# Store for each tweet in the database: the text, the user, the number of retweets, the number of likes and the date.

# %%
tweets = []     # array for the text
users = []      # array for the user data
retweets = []   # array for the number of retweets
likes = []      # array for the number of likes
dates = []      # array for the dates of the tweets

for i in range(0, len(data)):
    
    item = data.iloc[i]    # store JSON object

    text =item['full_text']
    tweets.append(text.split())
    
    user = item['user']
    users.append(user)
        
    retweet = item['retweet_count']
    retweets.append(retweet)
    
    like = item['favorite_count']
    likes.append(like)
    
    date = item['created_at']
    dates.append(date)

# %%
# Fucntion to convert from the written month to the month in numbers
def convert_month(month):
    if month == 'Jan':
        month = 1
    elif month == 'Feb':
        month = 2
    elif month == 'Mar':
        month = 3
    elif month == 'Apr':
        month = 4
    elif month == 'May':
        month = 5
    elif month == 'Jun':
        month = 6
    elif month == 'Jul':
        month = 7
    elif month == 'Aug':
        month = 8
    elif month == 'Sep':
        month = 9
    elif month == 'Oct':
        month = 10
    elif month == 'Nov':
        month = 11
    elif month == 'Dec':
        month = 12
    return month

# %% [markdown]
# Search for the date of the first tweet and the last tweet published in our database.

# %%
find_date = []
for date in dates:
    year = date[-4:]
    month = date[4:7]
    month = convert_month(str(month))
    day = date[8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    find_date.append(pd.Timestamp(date))
    
max_date = max(find_date)
min_date = min(find_date)

print("The first tweet was published at ", min_date)
print("The last tweet was published at ", max_date)
# Out:
# The first tweet was published at  2021-03-30 00:00:00
# The last tweet was published at  2021-05-10 00:00:00

# %% [markdown]
# Number of tweets in the database.

# %%
print("From", min_date, " untill", max_date, len(data),"tweets have been published.")
# Out:
# From 2021-03-30 00:00:00  untill 2021-05-10 00:00:00 23010 tweets have been published.

# %% [markdown]
# Most common words between the tweets.

# %%
tweets_arr = []
words_arr = []
non_interesting_words = ["in", "and", "RT", "a", "of", "what", "is", "he", "she", "already", "yet", "no", "science", "Science", 
                         "yes", "lot", "you", "Us", "citizen", "the", "are", "one", "to", "in", "Citizen", "for", "our", "on", 
                         "with", "this", "from", "can", "#CitizenScience", "that", "your", "about", "The", "-", "science.", 
                         "have", "we", "I", "has", "We", "at", "as", "be", "by", "not", "It’s", "out", "an", "us", "will", 
                         "get", "all", "it", "A", "In", "This", "do", "or", "how", "They", "but", "they", "my", "into", "So",
                         "If", "their", "Our", "up", "That's", "so", "now"]
for t in tweets:
    for i in t:
        tweets_arr.append(i)
        if (i.startswith(('#','@')) == False):
            words_arr.append(i)

for word in non_interesting_words:
    words_arr = [val for val in words_arr if val != word]

from collections import Counter 
Counter = Counter(words_arr) 
  
most_occur = Counter.most_common(100) 

print("The most common words are: \n", most_occur)
# Out:
# The most common words are:
#  [('announce', 3291), ('"If', 3270), ('Investigation', 3267), ('Illusory', 3259), ('Fits', 3256), ('Sits:', 3255), ('Contour', 3254), ('pleased', 3243), ('paper,', 3236), ('Susceptibil…', 3235), ('level', 2748), ('project', 1980), ('&amp;', 1828), ('Dust', 1730), ('world', 1709), ('Just', 1680), ('Do', 1678), ('US', 1652), ('Would', 1617), ('is:', 1613), ('President', 1601), ('1.', 1600), ('brain', 1598), ('as…', 1596), ('Things', 1593), ('drain', 1590), ('(not', 1588), ('Aggressively', 1588), ('weaponize', 1588), ('immigration.', 1588), ('boring)', 1587), ('like', 1264), ('make', 1196), ('more', 1113), ('Wind', 1078), ('direction', 1073), ('C.', 1071), ('ugr/m3.', 1070), ('Temperature', 1070), ('students', 1068), ('data', 1042), ('ways', 996), ('below', 979), ('difference', 913), ('Join', 912), ('Recycle', 856), ('Earth:', 855), ('♻️Reduce,', 855), ('Reuse,', 855), ('🔬@DoNASAScience', 855), ('Tips', 854), ('contrib…', 852), ('project?', 849), ('fits', 843), ('best', 831), ('pandemic', 817), ('help', 809), ('Cats', 809), ('sit', 788), ("'If", 784), ('Winner', 782), ("sits'.", 781), ('enclosed', 781), ('spaces,', 781), ('tre…', 780), ('great,', 729), ('new', 694), ('10', 691), ('scientists', 614), ('time', 565), ('projects', 556), ('April', 553), ('some', 499), ('Check', 493), ('part', 490), ('research', 474), ('least', 437), ('through', 432), ('been', 429), ('5', 418), ('join', 415), ('air', 388), ('know', 382), ('just', 372), ('people', 371), ('20', 370), ('learn', 360), ('involved', 357), ('great', 352), ('above', 351), ('today', 338), ("It's", 332), ('UTC', 319), ('first', 318), ('who', 316), ('work', 314), ('Great', 312), ('day', 312), ('May', 311), ('New', 301)]

# %% [markdown]
# Extract the number of occurrences of each word in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Word', 'Number of occurrences'])
df_most_occur.to_csv("words_ENG.csv")

# %% [markdown]
# Most common hashtags mentioned between the tweets.

# %%
hashtags = []
for word in tweets_arr:
    if word[0] == '#':
        hashtags.append(word)

from collections import Counter
Counter = Counter(hashtags)   
most_occur = Counter.most_common(40) 

print("The most common hashtags are: \n",most_occur)
# Out:
# The most common hashtags are:
#  [('#CitizenScience', 3154), ('#citizenscience', 860), ('#PM10', 846), ('#PM2.5', 765), ('#luftdaten', 763), ('#Fijnstof', 762), ('#Airpollution', 762), ('#Waalre', 762), ('#EarthDay', 404), ('#earthquake', 375), ('#CitSci', 237), ('#citsci', 193), ('#AI', 159), ('#CitizenScienceMonth', 150), ('#DataScience', 148), ('#EarthDay2021', 141), ('#…', 135), ('#2DegreesC', 130), ('#WSTC7', 117), ('#CityNatureChallenge', 106), ('#biodiversity', 100), ('#CitSciMonth', 98), ('#ArtificialIntelligence', 98), ('#CitSciVirtual', 96), ('#EarthDay,', 93), ('#CitizenScienceMonth!', 91), ('#MachineLearning', 91), ('#science', 82), ('#AQAW2021', 79), ('#datascience', 72), ('#seismograph', 72), ('#Python', 68), ('#DigSesh2', 68), ('#BigData', 65), ('#ClimateChangeIsReal', 65), ('#RaspberryShake', 57), ('#CitizenScience!', 57), ("#Nuku'Alofa,", 57), ('#CitizenScience,', 56), ('#ClimateC…', 55)]

# %% [markdown]
# Extract the number of occurrences of each hashtag in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Hashtag', 'Number of mentions'])
df_most_occur.to_csv("hashtags_ENG.csv")

# %% [markdown]
# Most common accounts mentioned between the tweets.

# %%
accounts = []
for word in tweets_arr:
    if word[0] == '@':
        accounts.append(word)

from collections import Counter
Counter = Counter(accounts)
most_occur = Counter.most_common(40) 

print("The most common mentioned accounts are: \n",most_occur)
# Out:
# The most common mentioned accounts are:
#  [('@Explanimals:', 3237), ('@seconds_0:', 1586), ('@NASA:', 960), ('@NASA_Astronauts', 855), ('@lauraakelley:', 780), ('@SciStarter:', 376), ('@Aalst_Waalre:', 308), ('@raspishake', 268), ('@raspishakEQ:', 227), ('@SciStarter', 181), ('@jljcolorado:', 175), ('@c_degrees:', 174), ('@HughHarrop:', 155), ('@outdoor_ed:', 143), ('@inaturalist', 130), ('@NOAAeducation:', 119), ('@CitSciOZ', 118), ('@NASAEarth', 117), ('@CitSciMonth', 112), ('@Explanimals', 90), ('@GLOBEProgram:', 85), ('@brittney_beck:', 83), ('@CitSciAssoc', 79), ('@qikipedia:', 79), ('@cstrackproject:', 76), ('@UN', 75), ('@thembauk:', 74), ('@NASASTEM:', 73), ('@NatureMapr:', 71), ('@Public_Citizen', 70), ('@NASAEarth:', 68), ('@PenguiNacho:', 66), ('@NWS:', 63), ('@BioDataCentre:', 61), ('@NOAA', 61), ('@NASA', 59), ('@Doxyaxone:', 57), ('@TechNative:', 55), ('@Space_Station', 54), ('@_EBCC:', 53)]

# %% [markdown]
# Extract the number of occurrences of each account in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Account', 'Number of mentions'])
df_most_occur.to_csv("accounts_ENG.csv")

# %% [markdown]
# Find the average and the maximum number of likes and retweets between the tweets.

# %%
print("The maximum number of retweets is: ", max(retweets))
print("The average number of retweets is: ", int(np.mean(retweets)))
print("\nThe maximum number of likes is: ", max(likes))
print("The average number of likes is: ", int(np.mean(likes)))
# Out:
# The maximum number of retweets is:  21231
# The average number of retweets is:  714
#
# The maximum number of likes is:  15514
# The average number of likes is:  2

# %% [markdown]
# Most retweeted tweets

# %%
print("The most retweeted tweets are: \n")
data.nlargest(20, ['retweet_count'])['full_text']
# Out:
# The most retweeted tweets are:
# 5863     RT @POTUS: This Earth Day, I’m proud to say sc...
# 15415    RT @nytimes: A 10-story, 23-ton piece of a Chi...
# 8840     RT @govkristinoem: I've signed an Executive Or...
# 2731     RT @VikSoho: Cuba has FOUR vaccine candidates....
# 13742    RT @Explanimals: So pleased to announce that m...
# 13755    RT @Explanimals: So pleased to announce that m...
# 13768    RT @Explanimals: So pleased to announce that m...
# 13788    RT @Explanimals: So pleased to announce that m...
# 13800    RT @Explanimals: So pleased to announce that m...
# 13801    RT @Explanimals: So pleased to announce that m...
# 13802    RT @Explanimals: So pleased to announce that m...
# 13809    RT @Explanimals: So pleased to announce that m...
# 13820    RT @Explanimals: So pleased to announce that m...
# 13825    RT @Explanimals: So pleased to announce that m...
# 13833    RT @Explanimals: So pleased to announce that m...
# 13881    RT @Explanimals: So pleased to announce that m...
# 13883    RT @Explanimals: So pleased to announce that m...
# 13889    RT @Explanimals: So pleased to announce that m...
# 13891    RT @Explanimals: So pleased to announce that m...
# 13906    RT @Explanimals: So pleased to announce that m...
# Name: full_text, dtype: object

# %% [markdown]
# Most common source types.

# %%
src_data = data[data['extended_entities'].notna() == True]

src_type = []
for i in src_data.index:
    num_src = len(src_data.loc[i]['extended_entities']['media'])
    for n in range(0, num_src):
        src_type.append(src_data.loc[i]['extended_entities']['media'][n]['type'])

from collections import Counter 
Counter = Counter(src_type)   
most_occur = Counter.most_common(20) 

print("The most common source types are: \n", most_occur)
# Out:
# The most common source types are:
#  [('photo', 2234), ('video', 91), ('animated_gif', 56)]

# %% [markdown]
# Extract the number of occurrences of each source type in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Source', 'Number of occurrences'])
df_most_occur.to_csv("sources_ENG.csv")

# %% [markdown]
# ## Analysis of the users interacting in Twitter about CS

# %% [markdown]
# Number of users interacting in CS.

# %%
user_ids = []
for u in users:
    if u['id'] not in user_ids:
        user_ids.append(u['id'])
print("There are ", len(user_ids), "active users.")
# Out:
# There are  16041 active users.

# %% [markdown]
# Most active users between the tweets.

# %%
user_names = []
for u in users:
    user_names.append(u['screen_name'])

from collections import Counter
Counter = Counter(user_names)   
most_occur = Counter.most_common(20) 
    
print("The most active users are: \n", most_occur)
# Out:
# The most active users are:
#  [('Aalst_Waalre', 762), ('globalhealthbot', 308), ('SciStarter', 274), ('FFFBot1', 136), ('CitSciMonth', 104), ('jillfnugent', 94), ('scicheer', 83), ('CitSciOZ', 81), ('VolcanoWatching', 72), ('raspishakEQ', 72), ('CitieSHealthEU', 57), ('SustainTrends', 47), ('OpenSciTalk', 43), ('brittney_beck', 42), ('OpenLitterMap', 41), ('Rosario_Strano', 41), ('CitSci_Geek', 37), ('llThingsCitizen', 36), ('SeismicFox1', 35), ('GetEcohappiness', 32)]

# %% [markdown]
# Extract the number of times each user interacts in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['User', 'Number of interactions'])
df_most_occur.to_csv("users_ENG.csv")

# %% [markdown]
# Location, number of followers, number of statuses and number of likes of users

# %%
user_locations = []
user_followers = []
user_status = []
user_favorites = []
for u in users:
    user_locations.append(u['location'])
    user_followers.append([u['screen_name'],u['followers_count']])
    user_status.append([u['screen_name'],u['statuses_count']])
    user_favorites.append([u['screen_name'],u['favourites_count']])

# %% [markdown]
# Most common locations of published tweets

# %%
user_locations = filter(None, user_locations)
from collections import Counter
Counter = Counter(user_locations)   
most_occur = Counter.most_common(20) 

# Compute the total number of active users
total = 0
for i in range(0,20):
    total += most_occur[i][1]

# Percentages are added to each active users
for i in range(0,20):
    most_occur[i]= most_occur[i]+((most_occur[i][1]*100/total),)
    
print("The most common user's locations are: \n", most_occur)
# Out:
# The most common user's locations are:
#  [('Aalst waalre', 762, 24.321736354931375), ('Global', 329, 10.50111714012129), ('Washington, DC', 220, 7.022023619533993), ('Australia', 174, 5.553782317267794), ('Earth', 171, 5.458027449728695), ('United States', 154, 4.915416533673795), ('Philadelphia, PA', 129, 4.1174593041812955), ('United Kingdom', 128, 4.085541015001596), ('London', 108, 3.4471752314075967), ('London, England', 107, 3.4152569422278964), ('USA', 106, 3.3833386530481966), ('Boquete, Panama', 96, 3.064155761251197), ('North Texas, USA', 94, 3.000319182891797), ('UK', 91, 2.904564315352697), ('North Carolina, USA', 88, 2.808809447813597), ('New York, NY', 79, 2.5215448451962974), ('Canada', 78, 2.4896265560165975), ('San Francisco, CA', 76, 2.4257899776571974), ('Brighton & Hove, UK', 73, 2.330035110118098), ('Seattle, WA', 70, 2.234280242578998)]

# %% [markdown]
# Extract the number of tweets for each localization in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Localitzation', '# users active', '%'])
df_most_occur.to_csv("localitzations_ENG.csv")

# %%
print("The users with more followers are: \n", sorted(user_followers,key = lambda x: x[1])[::-1])
# Out:
# The users with more followers are:
#  [['NASA', 46048899], ['ABC', 16614338], ['ABC', 16614338], ['NatGeoTravel', 7693634], ['business', 7312594], ['CNNnews18', 4589636], ['wef', 4015324], ['ScienceNews', 3863526], ['NWS', 3007108], ['NWS', 3007108], ['NWS', 3007108], ['NWS', 3007074], ['NHM_London', 2341881], ['NHM_London', 2341880], ['NHM_London', 2341234], ['NASAEarth', 2163502], ['NASAEarth', 2133293], ['NASAEarth', 2133291], ['NASAEarth', 2133291], ['VICE', 2047356], ['Slate', 1798343], ['Slate', 1798343], ['Slate', 1798343], ['Slate', 1798343], ['Slate', 1798343], ['staronline', 1676016], ['NOAASatellites', 1555387], ['qikipedia', 1301690], ['librarycongress', 1224341], ['NSF', 1217418], ['DiscoverMag', 1204986], ['ntvuganda', 1183941], ['Nightline', 1175572], ['NASA_Astronauts', 1147255], ['NOAA', 1131238], ['NOAA', 1130791], ['NOAA', 1130791], ['NOAA', 1130791], ['NOAA', 1130791], ['NOAA', 1129324], ['UNEP', 1102705], ['deborahvanessa7', 1075131], ['thewire_in', 1051652], ['nature_org', 990380], ['brainpicker', 948446], ['brainpicker', 948446], ['USGS', 787833], ['scifri', 763092], ['scifri', 763092], ['scifri', 762120], ['scifri', 762120], ['khanacademy', 746936], ['devduttmyth', 741271], ['devduttmyth', 741271], ['SETIInstitute', 705820], ['SETIInstitute', 705276], ['SETIInstitute', 705275], ['SETIInstitute', 704556], ['teddyboylocsin', 673760], ['ChrisGPackham', 462305], ['NationalZoo', 457603], ['NationalZoo', 457446], ['Seeker', 452874], ['Seeker', 452874], ['Seeker', 452874], ['Public_Citizen', 446128], ['Public_Citizen', 439174], ['Public_Citizen', 439174], ['Public_Citizen', 439174], ['CommerceGov', 404524], ['CommerceGov', 404186], ['CommerceGov', 404186], ['CommerceGov', 403415], ['AstroKatie', 394942], ['Natures_Voice', 389172], ['NASA_Langley', 382578], ['SierraClub', 380299], ['wanlov', 359789], ['wanlov', 359789], ['eartheats', 357706], ['NASAClimate', 338608], ['NASASTEM', 324202], ['NASASTEM', 324202], ['NASASTEM', 322009], ['NASASTEM', 322009], ['WIONews', 316035], ['steve_hofmeyr', 291073], ['indystar', 272482], ['calacademy', 272173], ['IBMWatson', 269425], ['NewstalkFM', 265320], ['NMNH', 252317], ['sfchronicle', 251398], ['NASA_Wallops', 251075], ['sfchronicle', 250967], ['CityLab', 243180], ['LibraryJournal', 242761], ['LibraryJournal', 242624], ['make', 237335], ['AstronomyMag', 233517], ['jodrellbank', 209280], ['GlobalCalgary', 202896], ['IBMData', 202660], ['The_RHS', 197124], ['The_RHS', 196762], ['The_RHS', 196001], ['CanalRiverTrust', 193641], ['RobGMacfarlane', 190047], ['noaaocean', 188465], ['noaaocean', 188465], ['noaaocean', 187996], ['noaaocean', 187995], ['noaaocean', 187995], ['noaaocean', 187995], ['Seasaver', 187777], ['LastQuake', 183495], ['NatGeoEducation', 182271], ['LastQuake', 181797], ['NatGeoEducation', 181693], ['NatGeoEducation', 181037], ['NatGeoEducation', 181037], ['iste', 180301], ['iste', 179934], ['iste', 179934], ['iste', 179934], ['iste', 179934], ['iste', 179934], ['MITMuseum', 175951], ['TheCitizen_News', 173128], ['TheCitizen_News', 173128], ['TheCitizen_News', 171611], ['TheCitizen_News', 171611], ['TheCitizen_News', 171611], ['MichaelEMann', 170611], ['MichaelEMann', 170611], ['NIHDirector', 168791], ['macfound', 168074], ['Readygov', 162864], ['news18dotcom', 151774], ['news18dotcom', 151774], ['coldtusker', 149348], ['StarChild_2001', 142327], ['EU_H2020', 138864], ['MissionBlue', 134807], ['MissionBlue', 134807], ['aaas', 132172], ['aaas', 131697], ['PADI', 121523], ['PADI', 121340], ['TrackingSM', 120389], ['NextCityOrg', 119421], ['NextCityOrg', 119421], ['NextCityOrg', 119421], ['DailyMendesLife', 118267], ['IainLJBrown', 118203], ['Team4Nature', 116668], ['Team4Nature', 116246], ['thegrugq', 116138], ['EU_ENV', 113787], ['EU_ENV', 113787], ['cochranecollab', 112310], ['cochranecollab', 112310], ['ShawnMendesBRA', 110832], ['QueenofCr8tvty', 108094], ['CSIRO', 107424], ['CSIRO', 107424], ['_BTO', 103989], ['_BTO', 103989], ['EPAresearch', 103417], ['EPAresearch', 103417], ['EPAresearch',  ...

# %%
print("The users with more statuses are: \n", sorted(user_status,key = lambda x: x[1])[::-1])
# Out:
# The users with more statuses are:
#  [['missb62', 2829530], ['sectest9', 2275428], ['Oldlady12345', 2271210], ['robinsnewswire', 1737671], ['robinsnewswire', 1723290], ['zyiteblog', 1644489], ['zyiteblog', 1631618], ['3novices', 1503984], ['ZyiteGadgets', 1498128], ['ZyiteGadgets', 1486666], ['chidambara09', 1473602], ['chidambara09', 1473602], ['chidambara09', 1473602], ['chidambara09', 1473602], ['chidambara09', 1473602], ['chidambara09', 1473602], ['chidambara09', 1420683], ['chidambara09', 1420683], ['falconhamada_90', 1398676], ['as_sakimori', 1356842], ['RobRe62', 1319501], ['RobRe62', 1319501], ['RobRe62', 1319501], ['RobRe62', 1319501], ['RobRe62', 1319501], ['RobRe62', 1319501], ['RobRe62', 1319501], ['RobRe62', 1319501], ['RobRe62', 1319501], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['RobRe62', 1317984], ['Solutioneer72', 1252822], ['Ez4u2say_Janis', 1228985], ['Kat4Obama', 1220670], ['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['SerendipitySays', 1063717], ['SerendipitySays', 1054914], ['SerendipitySays', 1054914], ['_RedFrog', 1049959], ['xaelbot', 1016029], ['xaelbot', 1016029], ['xaelbot', 1016029], ['xaelbot', 1016029], ['AndreasAndy3131', 973370], ['washumom', 956952], ['DebDarkPetal', 953078], ['PCKJ3627', 940309], ['john1966olsen', 933564], ['wQQn', 918292], ['SaraGomezAranci', 913115], ['SaraGomezAranci', 911634], ['DanCas2', 911504], ['SaraGomezAranci', 907003], ['SaraGomezAranci', 907003], ['D_Plius', 876397], ['Silvi_ta', 875031], ['Rosenchild', 871892], ['Rosenchild', 871892], ['Rosenchild', 871892], ['CNNnews18', 871112], ['Rosenchild', 856028], ['Rosenchild', 856028], ['givemepie360', 840544], ['3wombats', 838782], ['b1e56df9ce6549f', 836017], ['johnjoechad', 824962], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['bexxmodd', 808588], ['aldoceccarelli', 794790], ['aldoceccarelli', 794790], ['aldoceccarelli', 794790], ['CoderNotesBot', 793167], ['KarlaCamilaLove', 789717], ['scheerenberger', 785259], ['EasyWorldNews', 774539], ['ecclesias', 763923], ['alizardx', 756732], ['Asher_Wolf', 749994], ['Gus_802', 746515], ['CyberSecurityN8', 741675], ['unlewis', 735874], ['FrecklesXX20', 735521], ['FrecklesXX20', 735521], ['FrecklesXX20', 735521], ['ruisaldanha', 717715], ['ruisaldanha', 715137], ['ruisaldanha', 715137], ['ruisaldanha', 715137], ['ruisaldanha', 715137], ['ruisaldanha', 715137], ['GovSherazKhan', 710671], ['TudorTweep', 708002], ['TheDeveloperBot', 696686], ['TheDeveloperBot', 696686], ['TheDeveloperBot', 696686], ['TheDeveloperBot', 696686], ['TheDeveloperBot', 696686], ['TheDeveloperBot', 696686], ['TheDeveloperBot', 696686], ['TheDeveloperBot', 696686], ['FamousPixs', 696327], ['Astraea_Styx', 695454], ['69NiceBot69', 694147], ['kimvie', 689825], ['business', 679201], ['kulturbolschewi', 678708], ['MastaOfMp3s', 673138], ['wadakashiho', 662147], ['wadakashiho', 662147], ['AminDuim_', 653625], ['Radlein', 650874], ['wadakashiho', 650004], ['wadakashiho', 650004], ['itsWanda', 648637], ['MechWarriorNY', 644122], ['sexygirl798', 631321], ['BlackPhysicists', 619227], ['roripierpont1', 618214], [ ...

# %%
print("The users with more likes are: \n", sorted(user_favorites,key = lambda x: x[1])[::-1])
# Out:
# The users with more likes are:
#  [['MechWarriorNY', 1341706], ['kulturbolschewi', 1226676], ['Solutioneer72', 1209856], ['PCKJ3627', 1187646], ['den6mix', 1102961], ['haylesatan', 1095379], ['SerendipitySays', 1084788], ['SerendipitySays', 1075660], ['SerendipitySays', 1075660], ['Cathi_Bea', 1072759], ['bdragon74', 1044620], ['Roger_Xanth_Day', 1003011], ['Radlein', 986201], ['ecclesias', 976505], ['mky_rinco', 894965], ['Ez4u2say_Janis', 890313], ['MelissaJPeltier', 880365], ['roripierpont1', 867654], ['Pharniel', 853730], ['DebDarkPetal', 853691], ['sapphixy', 843825], ['Rosenchild', 842220], ['Rosenchild', 842220], ['Rosenchild', 842220], ['AndreasAndy3131', 839767], ['_the_shnall_', 838609], ['Rosenchild', 823926], ['Rosenchild', 823926], ['s_derrickson', 821910], ['Tagsitqaf', 812369], ['sexygirl798', 774824], ['justAfanDavid', 773889], ['FrecklesXX20', 769030], ['FrecklesXX20', 769030], ['FrecklesXX20', 769030], ['JaredGonia', 755640], ['washumom', 743862], ['7leaguebootdisk', 743658], ['aurora_f', 738010], ['round', 717221], ['ThirstyForGaga', 711192], ['BrianTRice', 701912], ['RhapsodysBIues', 698667], ['3wombats', 696246], ['BrianTRice', 695597], ['lauraapollo', 679151], ['itsWanda', 670583], ['LaPorres', 659517], ['varda_friedman', 652568], ['zaichishka', 642566], ['foxgrrl', 640491], ['Agent_Snark', 640117], ['Rusty595', 638844], ['gahlotshagufta', 637790], ['ERN_Malleyscrub', 636773], ['Jrlvr88', 634861], ['Birder_Katie', 626093], ['Silvi_ta', 622777], ['M5B1tch', 620628], ['Jinxthelynx', 611605], ['Skajolly', 609109], ['Skajolly', 609109], ['rhcm123', 605910], ['LorettaBower3', 605070], ['suziday123', 603647], ['MadelineAndraia', 602422], ['pda3olives', 601234], ['unlewis', 600889], ['QofTU', 600511], ['givemepie360', 599444], ['fintechna', 597345], ['BarbiturateCat', 597134], ['D_Plius', 585665], ['Gert001badger', 581980], ['nonstandardrep', 579400], ['nuyorican_21', 577029], ['kirkmurphy', 574035], ['Noratoriou5', 572984], ['_Everbright_', 569191], ['LizDolphinfluff', 567453], ['davidaquinley', 563152], ['Cosmic_Wyrm', 563101], ['EsserZed', 554533], ['bonnystill', 549082], ['LauraBergerol', 548698], ['margymaclibrary', 547744], ['alvarez_nimer', 546545], ['b1e56df9ce6549f', 544377], ['TudorTweep', 543484], ['NiddrieNinja', 543267], ['Anderhardt', 540561], ['KarlaCamilaLove', 537665], ['pvdork', 534026], ['briab_briar', 529995], ['isamai12', 523962], ['billyarnie', 523547], ['billyarnie', 523547], ['FamousPixs', 521151], ['MajorMassSpec', 517538], ['SomeRandomHackr', 507786], ['Deadly_Laser', 506108], ['Dalchico', 505026], ['heather_c_c', 502645], ['inflatabletrex', 498068], ['scheerenberger', 494501], ['Cuartodemila', 493685], ['LelHulagirl101', 492759], ['Cbp8Cindy', 491516], ['ElliXO2', 489157], ['hbdchick', 487918], ['meznokto', 485712], ['sondy', 484544], ['Bjorkian15', 482207], ['MartinG8177', 481730], ['antumbral', 480546], ['FUERZAS76', 477513], ['PanthPnk', 477505], ['JohnChivall', 475795], ['CarolinneNasci2', 473633], ['cookiekk456', 473513], ['WendyShamblin', 469695], ['johnjoechad', 469558], ['JChrisPires', 463499], ['Yoymiskosas', 460872], ['siberianpine', 459780], ['Allikuja', 457932], ['deepvard', 455109], ['shinunao2', 450084], ['poppy_haze', 447437], ['Blodeuweddmoon', 444606], ['unIDedTypingObj', 444488], ['douglaschongys', 443941], ['davidhillgm', 438329], ['davidhillgm', 438329], ['ThatVDOVault', 437439], ['Kli_Nev', 435432], ['birdwriter7', 427873], ['AbbeyScott16', 427134], ['addamschloe', 426934], ['dancingkelsey', 426521], ['whethervane', 424563], ['Eurocentrique', 424135], ['JohnnyDee62', 424092], ['JohnnyDee62', 424092], ['ReneeLascala', 423504], ['MYMIMISTHEBEST', 423108], ['CattyFae', 423045], ['KainYusanagi', 422979], ['JackHockett1', 421472], ['LucillaGiannot1', 420961], ['Eurocentrique', 418927], ['MYMIMISTHEBEST', 418895], ['FFRREEmarkets', 417502], ['camilasjonas', 417298], ['PMPAfterdark', 413476], ['MarieColemanAO', 412935], ['MarieColemanAO', 412935], ['evilgrrl', 411701], ['Naramaruru', 411655], ['berserkx3 ...
