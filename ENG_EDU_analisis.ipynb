# %% [markdown]
# # Analysis of ENGLISH  Twitter data

# %% [markdown]
# Imports

# %%
import json
import pandas as pd
import numpy as np
from math import isnan
import pymongo
from pymongo import MongoClient
import json

# %% [markdown]
# ### Read data from MongoDB database

# %%
class Scraper:
    def __init__(self):
        
        #Mongodb connection
        self.conn = MongoClient('mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')

        #Mongodb database and repository
        db = self.conn.Stucom

        #Collections
        self.CAT =  db.CAT 
    
    def visualize_values(self): 

        # take the values
        values = self.CAT.find() 
        
        # go through the values of the object "pymongo"
        for i in values: 
            print(i)



if __name__ == "__main__":

    scraper = Scraper()
    scraper.visualize_values()

# %%
# Get the database
client = MongoClient("mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true")

db = client["ENG"]
col = db["CS"]
data = pd.DataFrame(list(col.find()))

# %% [markdown]
# Visualization of the data

# %%
data
# Out:
#                             _id                      created_at  \
# 0      606dc3064e60b42720327dfb  Wed Apr 07 14:32:35 +0000 2021
# 1      606dc3064e60b42720327dfc  Wed Apr 07 14:27:40 +0000 2021
# 2      606dc3064e60b42720327dfd  Wed Apr 07 14:27:01 +0000 2021
# 3      606dc3064e60b42720327dfe  Wed Apr 07 14:26:24 +0000 2021
# 4      606dc3064e60b42720327dff  Wed Apr 07 14:24:58 +0000 2021
# ...                         ...                             ...
# 30057  609914bb00d62321fcefa439  Mon May 03 16:05:08 +0000 2021
# 30058  609914bb00d62321fcefa422  Tue May 04 03:13:11 +0000 2021
# 30059  609914bb00d62321fcefa42e  Mon May 03 17:28:32 +0000 2021
# 30060  609914bb00d62321fcefa419  Tue May 04 10:28:52 +0000 2021
# 30061  609914bb00d62321fcefa430  Mon May 03 16:53:33 +0000 2021
#
#                         id               id_str  \
# 0      1379804302890373121  1379804302890373121
# 1      1379803063398105100  1379803063398105100
# 2      1379802901355319404  1379802901355319404
# 3      1379802742739202048  1379802742739202048
# 4      1379802385694912513  1379802385694912513
# ...                    ...                  ...
# 30057  1389249675497250821  1389249675497250821
# 30058  1389417796367372288  1389417796367372288
# 30059  1389270663333097476  1389270663333097476
# 30060  1389527441949921280  1389527441949921280
# 30061  1389261859484684292  1389261859484684292
#
#                                                full_text  truncated  \
# 0      RT @pkhardy: Looking for forward to my panel w...      False
# 1      RT @AmPhilSociety: #CitSciAPS today is all abo...      False
# 2      RT @BristolZooGdns: We're working with @Offici...      False
# 3      RT @Unistellar: Millions of asteroids exist in...      False
# 4      RT @RAOastronomy: Explore your dark sky. The R...      False
# ...                                                  ...        ...
# 30057  #CitSciVirtual is starting now! @CitSciAssoc h...      False
# 30058  RT @SciStarter: Meet the scientists behind NAS...      False
# 30059  RT @FieldKitOrg: Catch a few of our friends an...      False
# 30060  RT @Cos4Cloud: Are you attending the #CitSciVi...      False
# 30061  "We're all in the same boat as it comes to add...      False
#
#       display_text_range                                           entities  \
# 0               [0, 148]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1               [0, 140]  {'hashtags': [{'text': 'CitSciAPS', 'indices':...
# 2               [0, 144]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3               [0, 140]  {'hashtags': [{'text': 'planets', 'indices': [...
# 4               [0, 144]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                  ...                                                ...
# 30057            [0, 44]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 30058           [0, 143]  {'hashtags': [{'text': 'NASACitSciCon', 'indic...
# 30059           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 30060           [0, 139]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 30061           [0, 275]  {'hashtags': [{'text': 'CitSciVitural', 'indic...
#
#                                                 metadata  \
# 0      {'iso_language_code': 'en', 'result_type': 're...
# 1      {'iso_language_code': 'en', 'result_type': 're...
# 2      {'iso_language_code': 'en', 'result_type': 're...
# 3      {'iso_language_code': 'en', 'result_type': 're...
# 4      {'iso_language_code': 'en', 'result_type': 're...
# ...                                                  ...
# 30057  {'iso_language_code': 'en', 'result_type': 're...
# 30058  {'iso_language_code': 'en', 'result_type': 're...
# 30059  {'iso_language_code': 'en', 'result_type': 're...
# 30060  {'iso_language_code': 'en', 'result_type': 're...
# 30061  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                   source  ...  \
# 0      <a href="http://twitter.com/download/android" ...  ...
# 1      <a href="https://mobile.twitter.com" rel="nofo...  ...
# 2      <a href="http://twitter.com/download/iphone" r...  ...
# 3      <a href="https://mobile.twitter.com" rel="nofo...  ...
# 4      <a href="https://mobile.twitter.com" rel="nofo...  ...
# ...                                                  ...  ...
# 30057  <a href="https://mobile.twitter.com" rel="nofo...  ...
# 30058  <a href="http://twitter.com/download/android" ...  ...
# 30059  <a href="http://twitter.com/download/android" ...  ...
# 30060  <a href="http://twitter.com/download/android" ...  ...
# 30061  <a href="https://mobile.twitter.com" rel="nofo...  ...
#
#           quoted_status_id quoted_status_id_str retweet_count favorite_count  \
# 0      1379793795034849283  1379793795034849283             1              0
# 1                      NaN                  NaN             1              0
# 2                      NaN                  NaN             6              0
# 3                      NaN                  NaN             2              0
# 4                      NaN                  NaN             9              0
# ...                    ...                  ...           ...            ...
# 30057                  NaN                  NaN             1              2
# 30058                  NaN                  NaN            17              0
# 30059                  NaN                  NaN             6              0
# 30060                  NaN                  NaN             4              0
# 30061                  NaN                  NaN             0              5
#
#       favorited retweeted lang quoted_status possibly_sensitive  \
# 0         False     False   en           NaN                NaN
# 1         False     False   en           NaN                NaN
# 2         False     False   en           NaN                NaN
# 3         False     False   en           NaN                NaN
# 4         False     False   en           NaN                NaN
# ...         ...       ...  ...           ...                ...
# 30057     False     False   en           NaN              False
# 30058     False     False   en           NaN                NaN
# 30059     False     False   en           NaN                NaN
# 30060     False     False   en           NaN                NaN
# 30061     False     False   en           NaN                NaN
#
#                                        extended_entities
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30057  {'media': [{'id': '1389249670917021696', 'id_s...
# 30058                                                NaN
# 30059                                                NaN
# 30060                                                NaN
# 30061                                                NaN
#
# [30062 rows x 32 columns]

# %% [markdown]
# ### Filter Education Tweets

# %%
edu_words = ['Read', 'reading', 'read','#CitizenScienceandEducation','Education', 'STEM', 'STEAM', 'school', 'schools', 
             'School', 'Schools', 'ESO', 'institut' , 'student', 'students', 'university', 'University', 'universitats', 
             'Universities', 'Teach', 'teach', 'educate', 'teacher', 'teachers', 'professor', 'professors', 
             'educational resources', 'didactic guide', 'teaching guide','didactic unit', 'guide', 'guides']
drop_arr = []
for i in range(0, len(data)):

    item = data.iloc[i]
    text =item['full_text']

    words = 0
    for word in edu_words:
        if word in text.split():
            words = words + 1
    if words == 0:
        drop_arr.append(i)

data = data.drop(drop_arr)  
    
data.reset_index(drop=True)

data
# Out:
#                             _id                      created_at  \
# 6      606dc3064e60b42720327e01  Wed Apr 07 14:21:38 +0000 2021
# 10     606dc3064e60b42720327e05  Wed Apr 07 14:14:37 +0000 2021
# 16     606dc3064e60b42720327e0b  Wed Apr 07 13:58:33 +0000 2021
# 30     606dc3064e60b42720327e19  Wed Apr 07 13:36:49 +0000 2021
# 34     606dc3064e60b42720327e1d  Wed Apr 07 13:31:26 +0000 2021
# ...                         ...                             ...
# 29879  609914a700d62321fcefa393  Tue May 04 12:19:31 +0000 2021
# 29880  609914a700d62321fcefa36d  Fri May 07 09:16:45 +0000 2021
# 29896  609914a700d62321fcefa36b  Fri May 07 19:50:54 +0000 2021
# 29934  609914b000d62321fcefa3c4  Mon May 03 07:53:24 +0000 2021
# 29991  609914bb00d62321fcefa416  Tue May 04 11:18:00 +0000 2021
#
#                         id               id_str  \
# 6      1379801545206857728  1379801545206857728
# 10     1379799778385530881  1379799778385530881
# 16     1379795736754331649  1379795736754331649
# 30     1379790268145229826  1379790268145229826
# 34     1379788910910312450  1379788910910312450
# ...                    ...                  ...
# 29879  1389555284385964037  1389555284385964037
# 29880  1390596456734765059  1390596456734765059
# 29896  1390756045744660487  1390756045744660487
# 29934  1389125929415368707  1389125929415368707
# 29991  1389539803700547589  1389539803700547589
#
#                                                full_text  truncated  \
# 6      RT @cstrackproject: Read this article to find ...      False
# 10     RT @rescueareef: Citizen science at work 🚧 \nO...      False
# 16     Our April newsletter went out last week!  Chec...      False
# 30     RT @cstrackproject: Read this article to find ...      False
# 34     @katefickas @NASA_Landsat @LadiesOfLandsat @US...      False
# ...                                                  ...        ...
# 29879  RT @EuCitSci: If you aren't (yet) a subscriber...      False
# 29880  RT @Cos4Cloud: 📩Haven't you read the last @EuC...      False
# 29896  RT @Cos4Cloud: 📩Haven't you read the last @EuC...      False
# 29934  RT @nektarios_f: 📣 The #STEM-HLE21 is inviting...      False
# 29991  Our @OrsolyaRMolnar will present"#SciArt-build...      False
#
#       display_text_range                                           entities  \
# 6               [0, 140]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 10              [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 16              [0, 271]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 30              [0, 140]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 34             [64, 304]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                  ...                                                ...
# 29879           [0, 140]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 29880           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 29896           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 29934           [0, 142]  {'hashtags': [{'text': 'STEM', 'indices': [23,...
# 29991           [0, 284]  {'hashtags': [{'text': 'SciArt', 'indices': [3...
#
#                                                 metadata  \
# 6      {'iso_language_code': 'en', 'result_type': 're...
# 10     {'iso_language_code': 'en', 'result_type': 're...
# 16     {'iso_language_code': 'en', 'result_type': 're...
# 30     {'iso_language_code': 'en', 'result_type': 're...
# 34     {'iso_language_code': 'en', 'result_type': 're...
# ...                                                  ...
# 29879  {'iso_language_code': 'en', 'result_type': 're...
# 29880  {'iso_language_code': 'en', 'result_type': 're...
# 29896  {'iso_language_code': 'en', 'result_type': 're...
# 29934  {'iso_language_code': 'en', 'result_type': 're...
# 29991  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                   source  ...  \
# 6      <a href="https://mobile.twitter.com" rel="nofo...  ...
# 10     <a href="http://twitter.com/download/iphone" r...  ...
# 16     <a href="https://mobile.twitter.com" rel="nofo...  ...
# 30     <a href="https://about.twitter.com/products/tw...  ...
# 34     <a href="https://mobile.twitter.com" rel="nofo...  ...
# ...                                                  ...  ...
# 29879  <a href="http://twitter.com/download/android" ...  ...
# 29880  <a href="https://mobile.twitter.com" rel="nofo...  ...
# 29896  <a href="http://twitter.com/download/android" ...  ...
# 29934  <a href="https://mobile.twitter.com" rel="nofo...  ...
# 29991  <a href="https://mobile.twitter.com" rel="nofo...  ...
#
#       quoted_status_id quoted_status_id_str retweet_count favorite_count  \
# 6                  NaN                  NaN             4              0
# 10                 NaN                  NaN             1              0
# 16                 NaN                  NaN             0              0
# 30                 NaN                  NaN             4              0
# 34                 NaN                  NaN             0              1
# ...                ...                  ...           ...            ...
# 29879              NaN                  NaN             5              0
# 29880              NaN                  NaN             3              0
# 29896              NaN                  NaN             3              0
# 29934              NaN                  NaN             5              0
# 29991              NaN                  NaN             2              6
#
#       favorited retweeted lang quoted_status possibly_sensitive  \
# 6         False     False   en           NaN                NaN
# 10        False     False   en           NaN                NaN
# 16        False     False   en           NaN              False
# 30        False     False   en           NaN                NaN
# 34        False     False   en           NaN                NaN
# ...         ...       ...  ...           ...                ...
# 29879     False     False   en           NaN              False
# 29880     False     False   en           NaN                NaN
# 29896     False     False   en           NaN                NaN
# 29934     False     False   en           NaN                NaN
# 29991     False     False   en           NaN              False
#
#                                        extended_entities
# 6                                                    NaN
# 10                                                   NaN
# 16                                                   NaN
# 30                                                   NaN
# 34                                                   NaN
# ...                                                  ...
# 29879                                                NaN
# 29880                                                NaN
# 29896                                                NaN
# 29934                                                NaN
# 29991  {'media': [{'id': '1389174159939309571', 'id_s...
#
# [2147 rows x 32 columns]

# %% [markdown]
# ### Quit outliers

# %% [markdown]
# Delete repeated tweets.

# %%
data = data.drop_duplicates(subset=['id'])
data = data.reset_index(drop=True)
data
# Out:
#                            _id                      created_at  \
# 0     606dc3064e60b42720327e01  Wed Apr 07 14:21:38 +0000 2021
# 1     606dc3064e60b42720327e05  Wed Apr 07 14:14:37 +0000 2021
# 2     606dc3064e60b42720327e0b  Wed Apr 07 13:58:33 +0000 2021
# 3     606dc3064e60b42720327e19  Wed Apr 07 13:36:49 +0000 2021
# 4     606dc3064e60b42720327e1d  Wed Apr 07 13:31:26 +0000 2021
# ...                        ...                             ...
# 1934  609914a700d62321fcefa36c  Fri May 07 12:37:23 +0000 2021
# 1935  609914a700d62321fcefa36d  Fri May 07 09:16:45 +0000 2021
# 1936  609914a700d62321fcefa36b  Fri May 07 19:50:54 +0000 2021
# 1937  609914b000d62321fcefa3c4  Mon May 03 07:53:24 +0000 2021
# 1938  609914bb00d62321fcefa416  Tue May 04 11:18:00 +0000 2021
#
#                        id               id_str  \
# 0     1379801545206857728  1379801545206857728
# 1     1379799778385530881  1379799778385530881
# 2     1379795736754331649  1379795736754331649
# 3     1379790268145229826  1379790268145229826
# 4     1379788910910312450  1379788910910312450
# ...                   ...                  ...
# 1934  1390646946826792960  1390646946826792960
# 1935  1390596456734765059  1390596456734765059
# 1936  1390756045744660487  1390756045744660487
# 1937  1389125929415368707  1389125929415368707
# 1938  1389539803700547589  1389539803700547589
#
#                                               full_text  truncated  \
# 0     RT @cstrackproject: Read this article to find ...      False
# 1     RT @rescueareef: Citizen science at work 🚧 \nO...      False
# 2     Our April newsletter went out last week!  Chec...      False
# 3     RT @cstrackproject: Read this article to find ...      False
# 4     @katefickas @NASA_Landsat @LadiesOfLandsat @US...      False
# ...                                                 ...        ...
# 1934  RT @Cos4Cloud: 📩Haven't you read the last @EuC...      False
# 1935  RT @Cos4Cloud: 📩Haven't you read the last @EuC...      False
# 1936  RT @Cos4Cloud: 📩Haven't you read the last @EuC...      False
# 1937  RT @nektarios_f: 📣 The #STEM-HLE21 is inviting...      False
# 1938  Our @OrsolyaRMolnar will present"#SciArt-build...      False
#
#      display_text_range                                           entities  \
# 0              [0, 140]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 1              [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2              [0, 271]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3              [0, 140]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 4             [64, 304]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...                 ...                                                ...
# 1934           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1935           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1936           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1937           [0, 142]  {'hashtags': [{'text': 'STEM', 'indices': [23,...
# 1938           [0, 284]  {'hashtags': [{'text': 'SciArt', 'indices': [3...
#
#                                                metadata  \
# 0     {'iso_language_code': 'en', 'result_type': 're...
# 1     {'iso_language_code': 'en', 'result_type': 're...
# 2     {'iso_language_code': 'en', 'result_type': 're...
# 3     {'iso_language_code': 'en', 'result_type': 're...
# 4     {'iso_language_code': 'en', 'result_type': 're...
# ...                                                 ...
# 1934  {'iso_language_code': 'en', 'result_type': 're...
# 1935  {'iso_language_code': 'en', 'result_type': 're...
# 1936  {'iso_language_code': 'en', 'result_type': 're...
# 1937  {'iso_language_code': 'en', 'result_type': 're...
# 1938  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                  source  ... quoted_status_id  \
# 0     <a href="https://mobile.twitter.com" rel="nofo...  ...              NaN
# 1     <a href="http://twitter.com/download/iphone" r...  ...              NaN
# 2     <a href="https://mobile.twitter.com" rel="nofo...  ...              NaN
# 3     <a href="https://about.twitter.com/products/tw...  ...              NaN
# 4     <a href="https://mobile.twitter.com" rel="nofo...  ...              NaN
# ...                                                 ...  ...              ...
# 1934  <a href="http://twitter.com/download/android" ...  ...              NaN
# 1935  <a href="https://mobile.twitter.com" rel="nofo...  ...              NaN
# 1936  <a href="http://twitter.com/download/android" ...  ...              NaN
# 1937  <a href="https://mobile.twitter.com" rel="nofo...  ...              NaN
# 1938  <a href="https://mobile.twitter.com" rel="nofo...  ...              NaN
#
#      quoted_status_id_str retweet_count favorite_count favorited retweeted  \
# 0                     NaN             4              0     False     False
# 1                     NaN             1              0     False     False
# 2                     NaN             0              0     False     False
# 3                     NaN             4              0     False     False
# 4                     NaN             0              1     False     False
# ...                   ...           ...            ...       ...       ...
# 1934                  NaN             3              0     False     False
# 1935                  NaN             3              0     False     False
# 1936                  NaN             3              0     False     False
# 1937                  NaN             5              0     False     False
# 1938                  NaN             2              6     False     False
#
#      lang quoted_status possibly_sensitive  \
# 0      en           NaN                NaN
# 1      en           NaN                NaN
# 2      en           NaN              False
# 3      en           NaN                NaN
# 4      en           NaN                NaN
# ...   ...           ...                ...
# 1934   en           NaN                NaN
# 1935   en           NaN                NaN
# 1936   en           NaN                NaN
# 1937   en           NaN                NaN
# 1938   en           NaN              False
#
#                                       extended_entities
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1934                                                NaN
# 1935                                                NaN
# 1936                                                NaN
# 1937                                                NaN
# 1938  {'media': [{'id': '1389174159939309571', 'id_s...
#
# [1939 rows x 32 columns]

# %% [markdown]
# Check that all tweets are in English

# %%
data = data[data['lang'] == 'en']

# %% [markdown]
# Delete tweets that are outside the desired range of dates

# %%
for i in range(0, len(data)):   
    item = data.iloc[i]
    
    if(int(item['created_at'][-4:])) < int(2021):
        data.drop([i],  inplace = True)

# %% [markdown]
# ### Treat the data to extract conclusions

# %% [markdown]
# Store for each tweet in the database: the text, the user, the number of retweets, the number of likes and the date.

# %%
tweets = []     # array for the text
users = []      # array for the user data
retweets = []   # array for the number of retweets
likes = []      # array for the number of likes
dates = []      # array for the dates of the tweets

for i in range(0, len(data)):
    
    item = data.iloc[i]    # store JSON object

    text =item['full_text']
    tweets.append(text.split())
    
    user = item['user']
    users.append(user)
        
    retweet = item['retweet_count']
    retweets.append(retweet)
    
    like = item['favorite_count']
    likes.append(like)
    
    date = item['created_at']
    dates.append(date)

# %%
# Fucntion to convert from the written month to the month in numbers
def convert_month(month):
    if month == 'Jan':
        month = 1
    elif month == 'Feb':
        month = 2
    elif month == 'Mar':
        month = 3
    elif month == 'Apr':
        month = 4
    elif month == 'May':
        month = 5
    elif month == 'Jun':
        month = 6
    elif month == 'Jul':
        month = 7
    elif month == 'Aug':
        month = 8
    elif month == 'Sep':
        month = 9
    elif month == 'Oct':
        month = 10
    elif month == 'Nov':
        month = 11
    elif month == 'Dec':
        month = 12
    return month

# %% [markdown]
# Search for the date of the first tweet and the last tweet published in our database.

# %%
find_date = []
for date in dates:
    year = date[-4:]
    month = date[4:7]
    month = convert_month(str(month))
    day = date[8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    find_date.append(pd.Timestamp(date))
    
max_date = max(find_date)
min_date = min(find_date)

print("The first tweet was published at ", min_date)
print("The last tweet was published at ", max_date)
# Out:
# The first tweet was published at  2021-03-30 00:00:00
# The last tweet was published at  2021-05-10 00:00:00

# %% [markdown]
# Number of tweets in the database.

# %%
print("From", min_date, " untill", max_date, len(data),"tweets have been published.")
# Out:
# From 2021-03-30 00:00:00  untill 2021-05-10 00:00:00 1934 tweets have been published.

# %% [markdown]
# Most common words between the tweets.

# %%
tweets_arr = []
words_arr = []
non_interesting_words = ["in", "and", "RT", "a", "of", "what", "is", "he", "she", "already", "yet", "no", "science", "Science", 
                         "yes", "lot", "you", "Us", "citizen", "the", "are", "one", "to", "in", "Citizen", "for", "our", "on", 
                         "with", "this", "from", "can", "#CitizenScience", "that", "your", "about", "The", "-", "science.", 
                         "have", "we", "I", "has", "We", "at", "as", "be", "by", "not", "It’s", "out", "an", "us", "will", 
                         "get", "all", "it", "A", "In", "This", "do", "or", "how", "They", "but", "they", "my", "into", "So",
                         "If", "their", "Our", "up", "That's", "so", "now"]
for t in tweets:
    for i in t:
        tweets_arr.append(i)
        if (i.startswith(('#','@')) == False):
            words_arr.append(i)

for word in non_interesting_words:
    words_arr = [val for val in words_arr if val != word]

from collections import Counter 
Counter = Counter(words_arr) 
  
most_occur = Counter.most_common(100) 

print("The most common words are: \n", most_occur)
# Out:
# The most common words are:
#  [('students', 1068), ('make', 905), ('ways', 888), ('difference', 857), ('Earth:', 855), ('♻️Reduce,', 855), ('Reuse,', 855), ('Recycle', 855), ('🔬@DoNASAScience', 855), ('Tips', 854), ('contrib…', 852), ('more', 237), ('schools', 223), ('air', 200), ('without', 182), ('scie…', 181), ('4', 180), ('3', 179), ('running', 179), ('times', 178), ('COVID-19', 177), ('"Quebec', 176), ('purifiers', 176), ('cases,', 176), ('says', 176), ('dad', 176), ('count"', 176), ('&amp;', 153), ('Read', 150), ('student', 120), ('help', 112), ('through', 98), ('reading', 84), ('book', 81), ('count', 79), ('Each', 73), ('off', 72), ('17', 72), ('books', 72), ('8am-4:30pm.', 72), ('connects', 72), ('bird', 72), ('project', 69), ('video', 69), ('backyard', 66), ('school', 65), ('Share', 65), ('kicks', 62), ('runs', 62), ('Monday', 62), ('26th.', 62), ('data', 61), ('work', 56), ('📢', 56), ('read', 56), ('also', 52), ('familie…', 52), ('University', 47), ('new', 45), ('find', 44), ('How', 44), ('online', 42), ('guide', 41), ('Are', 41), ('Suzie', 40), ('Check', 39), ('research', 39), ('MSc', 39), ('part', 38), ('using', 38), ('involved', 37), ('April', 34), ('science,', 34), ('learn', 34), ('connections', 34), ('looking', 33), ('interested', 33), ('article', 32), ('some', 30), ('project!…', 30), ('teacher', 29), ('like', 27), ('Join', 27), ('great', 27), ('Education', 26), ("It's", 26), ("I'm", 26), ('last', 25), ('understand', 25), ('been', 25), ('full', 25), ('be…', 25), ('context', 25), ('very', 24), ('launched', 24), ('take', 24), ('professor', 24), ('Simpson', 24), ('NOAA', 23), ('better', 23)]

# %% [markdown]
# Extract the number of occurrences of each word in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Word', 'Number of occurrences'])
df_most_occur.to_csv("words_ENG_EDU.csv")

# %% [markdown]
# Most common hashtags mentioned between the tweets.

# %%
hashtags = []
for word in tweets_arr:
    if word[0] == '#':
        hashtags.append(word)

from collections import Counter
Counter = Counter(hashtags)   
most_occur = Counter.most_common(40) 

print("The most common hashtags are: \n",most_occur)
# Out:
# The most common hashtags are:
#  [('#CitizenScience', 120), ('#EarthDay', 69), ('#citizenscience', 44), ('#citizenscience?', 28), ('#libraries', 14), ('#CitSci', 13), ('#MeetAndFly', 13), ('#Spain', 11), ('#Germany', 11), ('#Ukraine', 11), ('#France', 11), ('#citsci', 10), ('#citizenscience.', 10), ('#CitSciMonth', 9), ('#STEM-HLE21', 9), ('#MTM21', 9), ('#BiBBreathes', 9), ('#CitizenScience!', 9), ("#tick's", 9), ('#OpenScience', 8), ('#science', 8), ('#research', 7), ('#CitizenScienceMonth', 7), ('#EarthDay2021', 7), ('#CitizenScienceDay', 7), ('#K12', 7), ('#Africa', 7), ('#Conservation', 7), ('#SciComm', 6), ('#MelanogasterCTF', 6), ('#OpenData', 5), ('#SDGs', 5), ('#education', 5), ('#Scientix', 5), ('#Austral…', 5), ('#WhereWhereWedgie', 5), ('#CitizenScienceMonth!', 4), ('#COVID19', 4), ('#CitizenScience.', 4), ('#citizenscience,', 4)]

# %% [markdown]
# Extract the number of occurrences of each hashtag in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Hashtag', 'Number of mentions'])
df_most_occur.to_csv("hashtags_ENG_EDU.csv")

# %% [markdown]
# Most common accounts mentioned between the tweets.

# %%
accounts = []
for word in tweets_arr:
    if word[0] == '@':
        accounts.append(word)

from collections import Counter
Counter = Counter(accounts)
most_occur = Counter.most_common(40) 

print("The most common mentioned accounts are: \n",most_occur)
# Out:
# The most common mentioned accounts are:
#  [('@NASA_Astronauts', 855), ('@NASA:', 852), ('@jljcolorado:', 175), ('@UN', 72), ('@brittney_beck:', 61), ('@outdoor_ed:', 52), ('@SDGoals', 38), ('@DICE_Kent', 37), ('@SDGoals.', 34), ('@DrDavidLRoberts:', 34), ('@SciStarter:', 30), ('@noaaocean:', 22), ('@StreetScienceCo?', 21), ('@BackofenLab:', 20), ('@Telegraph', 16), ('@STEAMColleen:', 15), ('@LCATMon:', 15), ('@cstrackproject:', 14), ('@wrdsb', 14), ('@an_dre_a_', 13), ('@the_zooniverse', 13), ('@Mozziebites:', 13), ('@umsi:', 11), ('@Bat_Watch:', 10), ('@scientix_eu:', 8), ('@_breakinggood:', 8), ('@drrosiemc:', 8), ('@NCRWR…', 8), ('@VirusesTickCVR:', 8), ('@Joseph_JBell:', 8), ('@SciStarter', 7), ('@Team_eBird:', 7), ('@UMiamiRSMAS', 6), ('@ECIUniversities:', 6), ('@UCLpress:', 6), ('@canairq.', 6), ('@TropicalBiology:', 6), ('@RachelP_SEI,', 5), ('@CosmosMagazine:', 5), ('@iste:', 5)]

# %% [markdown]
# Extract the number of occurrences of each account in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Account', 'Number of mentions'])
df_most_occur.to_csv("accounts_ENG_EDU.csv")

# %% [markdown]
# Find the average and the maximum number of likes and retweets between the tweets.

# %%
print("The maximum number of retweets is: ", max(retweets))
print("The average number of retweets is: ", int(np.mean(retweets)))
print("\nThe maximum number of likes is: ", max(likes))
print("The average number of likes is: ", int(np.mean(likes)))
# Out:
# The maximum number of retweets is:  931
# The average number of retweets is:  431
#
# The maximum number of likes is:  3785
# The average number of likes is:  3

# %% [markdown]
# Most retweeted tweets

# %%
print("The most retweeted tweets are: \n")
data.nlargest(20, ['retweet_count'])['full_text']
# Out:
# The most retweeted tweets are:
# 236    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 239    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 350    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 428    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 433    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 439    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 440    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 443    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 449    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 451    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 452    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 454    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 455    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 457    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 458    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 459    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 462    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 463    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 469    RT @NASA: Tips from @NASA_Astronauts on ways s...
# 470    RT @NASA: Tips from @NASA_Astronauts on ways s...
# Name: full_text, dtype: object

# %% [markdown]
# Most common source types.

# %%
src_data = data[data['extended_entities'].notna() == True]

src_type = []
for i in src_data.index:
    num_src = len(src_data.loc[i]['extended_entities']['media'])
    for n in range(0, num_src):
        src_type.append(src_data.loc[i]['extended_entities']['media'][n]['type'])

from collections import Counter 
Counter = Counter(src_type)   
most_occur = Counter.most_common(20) 

print("The most common source types are: \n", most_occur)
# Out:
# The most common source types are:
#  [('photo', 202), ('video', 10), ('animated_gif', 3)]

# %% [markdown]
# Extract the number of occurrences of each source type in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Source', 'Number of occurrences'])
df_most_occur.to_csv("sources_ENG_EDU.csv")

# %% [markdown]
# ## Analysis of the users interacting in Twitter about CS

# %% [markdown]
# Number of users interacting in CS.

# %%
user_ids = []
for u in users:
    if u['id'] not in user_ids:
        user_ids.append(u['id'])
print("There are ", len(user_ids), "active users.")
# Out:
# There are  1732 active users.

# %% [markdown]
# Most active users between the tweets.

# %%
user_names = []
for u in users:
    user_names.append(u['screen_name'])

from collections import Counter
Counter = Counter(user_names)   
most_occur = Counter.most_common(20) 
    
print("The most active users are: \n", most_occur)
# Out:
# The most active users are:
#  [('SciStarter', 19), ('brittney_beck', 19), ('csubted', 18), ('CitSciMonth', 9), ('jillfnugent', 9), ('JOshotame', 8), ('cstrackproject', 7), ('WWStiernLibrary', 7), ('OpenSciTalk', 5), ('scientix_eu', 5), ('OSUPickawayEXT', 5), ('femtech_', 5), ('scicheer', 4), ('CitieSHealthEU', 4), ('CSUBakersfield', 4), ('outdoor_ed', 4), ('UniKentSAC', 4), ('ALIANational', 4), ('UCLpress', 4), ('LIBEReurope', 3)]

# %% [markdown]
# Extract the number of times each user interacts in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['User', 'Number of interactions'])
df_most_occur.to_csv("users_ENG_EDU.csv")

# %% [markdown]
# Location, number of followers, number of statuses and number of likes of users

# %%
user_locations = []
user_followers = []
user_status = []
user_favorites = []
for u in users:
    user_locations.append(u['location'])
    user_followers.append([u['screen_name'],u['followers_count']])
    user_status.append([u['screen_name'],u['statuses_count']])
    user_favorites.append([u['screen_name'],u['favourites_count']])

# %% [markdown]
# Most common locations of published tweets

# %%
user_locations = filter(None, user_locations)
from collections import Counter
Counter = Counter(user_locations)   
most_occur = Counter.most_common(20) 

# Compute the total number of active users
total = 0
for i in range(0,20):
    total += most_occur[i][1]

# Percentages are added to each active users
for i in range(0,20):
    most_occur[i]= most_occur[i]+((most_occur[i][1]*100/total),)
    
print("The most common user's locations are: \n", most_occur)
# Out:
# The most common user's locations are:
#  [('Bakersfield, CA', 31, 14.285714285714286), ('Global', 27, 12.442396313364055), ('she/her', 19, 8.755760368663594), ('Washington, DC', 18, 8.294930875576037), ('Earth', 11, 5.0691244239631335), ('United Kingdom', 10, 4.608294930875576), ('North Texas, USA', 9, 4.147465437788019), ('México', 9, 4.147465437788019), ('São Paulo, Brasil', 8, 3.686635944700461), ('Australia', 8, 3.686635944700461), ('Kitchener, Ontario', 8, 3.686635944700461), ('wonderland', 8, 3.686635944700461), ('Philadelphia, PA', 7, 3.225806451612903), ('France', 7, 3.225806451612903), ('Toronto, Ontario', 7, 3.225806451612903), ('Los Angeles, CA', 6, 2.7649769585253456), ('Barcelona', 6, 2.7649769585253456), ('Canada', 6, 2.7649769585253456), ('Brasil', 6, 2.7649769585253456), ('Cambridge, Ontario', 6, 2.7649769585253456)]

# %% [markdown]
# Extract the number of tweets for each localization in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Localitzation', '# users active', '%'])
df_most_occur.to_csv("localitzations_ENG_EDU.csv")

# %%
print("The users with more followers are: \n", sorted(user_followers,key = lambda x: x[1])[::-1])
# Out:
# The users with more followers are:
#  [['NASA', 46048899], ['NASAEarth', 2133291], ['staronline', 1676016], ['ntvuganda', 1183941], ['NASA_Astronauts', 1147255], ['WIONews', 316035], ['noaaocean', 187995], ['NatGeoEducation', 182271], ['NatGeoEducation', 181037], ['iste', 179934], ['EU_H2020', 138864], ['TrackingSM', 120389], ['DailyMendesLife', 118267], ['ShawnMendesBRA', 110832], ['TomasMolinaB', 94581], ['RoyalBCMuseum', 92262], ['BirdLife_News', 83063], ['sanctuaries', 75757], ['openscience', 70472], ['wrdsb', 68547], ['FrontiersIn', 65520], ['FrontiersIn', 65520], ['jljcolorado', 62712], ['SDGoals', 57123], ['SDGoals', 57123], ['SDGoals', 57123], ['EmceeSLIM', 57014], ['JSMBrandShop', 55871], ['ShawnUpdatesSA', 53596],
gram', 8027], ['GLOBEProgram', 7973], ['LIBEReurope', 7938], ['LIBEReurope', 7938], ['LIBEReurope', 7938], ['NorthCarolinaEE', 7868], ['NorthCarolinaEE', 7868], ['carlyziter', 7779], ['UMiamiRSMAS', 7672], ['AmPhilSociety', 7410], ['DrJohnFa', 7346], ['Boston1775', 7264], ['FestofNature', 7260], ['Rosario_Strano', 7216], ['CSUBakersfield', 7174], ['litterati', 7172], ['CSUBakersfield', 7162], ['CSUBakersfield', 7162], ['CSUBakersfie ...

# %%
print("The users with more statuses are: \n", sorted(user_status,key = lambda x: x[1])[::-1])
# Out:
# The users with more statuses are:
#  [['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['femtech_', 1190142], ['SerendipitySays', 1054914], ['AndreasAndy3131', 973370], ['DebDarkPetal', 953078], ['givemepie360', 840544], ['KarlaCamilaLove', 789717], ['FamousPixs', 696327], ['MastaOfMp3s', 673138], ['AminDuim_', 653625], ['EmceeSLIM', 614071], ['Jinxthelynx', 596573], ['adekleine', 567682], ['camilasjonas', 558995], ['prameshjain12', 480271], ['aziegler', 479057], ['PaulPaul49', 465876], ['Mr_Spock', 454280], ['jjdebenedictis', 447518], ['staronline', 403282], ['dropoutnation', 382089], ['JamiiJe', 378816], ['Daniella23031', 371065], ['FleurAvr', 368498], ['Watchdogsniffer', 366266], ['ebscbwi', 349547], ['MajorMassSpec', 338495], ['CarolinneNasci2', 328408], ['ltsonlysteph', 327014], ['diogene2607', 310803], ['NoreenTranceCat', 307497], ['LelHulagirl101', 294348], ['eternalXM99ffa', 289610], ['tonov3_vanvi', 288302], ['sunrisewithmila', 278888], ['Boston1775', 271797], ['StephTheGroupie', 269979], ['LaPorres', 263984], ['ravi2010mary', 259419], ['zetwitty', 232691], ['wonderghostin', 227819], ['nbtscarpenter', 226663], ['hazzawonder', 225509], ['twitaco', 224231], ['lcby', 222183], ['euribem', 220772], ['ntvuganda', 216867], ['hardcandyM', 211829], ['Loli17', 206245], ['jane__eden', 200768], ['SustainTrends', 197041], ['Mickey_skr', 195118], ['h2ofizz', 193002], ['mutualwhys', 191700], ['shawnogase', 191547], ['Fflashies', 186397], ['tmhtlthestars', 176813], ['majaloca', 174924], ['lmjshxwn', 174875], ['BieberKylizzleP', 171611], ['mixpelirroja', 171560], ['WIONews', 167009], ['_Aware_Citizen', 166592], ['BotFemale', 165154], ['BotFemale', 165154], ['Rdene915', 164823], ['sandymmv', 161176], ['H4rryftSh4wn', 159698], ['fatimakadimi', 159319], ['LadyofWildernes', 150456], ['wonderugge', 149779], ['shwnmatters', 148876], ['mayarin0502', 147409], ['BobbyBroad', 147086], ['Indra68', 142464], ['larry411', 140201], ['camilafanrick03', 138586], ['TrubbellAtMill', 137968], ['_open_science_', 137483], ['_open_science_', 136943], ['_open_science_', 136943], ['Rosario_Strano', 136885], ['Vikkik88', 135238], ['peteblackman', 131178], ['nzalogo', 131123], ['AtchaJohn', 130331], ['hnkimma', 130259], ['ppoHeisenberg', 128753], ['rawining', 126957], ['Kittyween', 126549], ['AmlieMendes1', 126324], ['reall