# %% [markdown]
# # Analysis of Cos4Cloud Event  Twitter data

# %% [markdown]
# Imports

# %%
import json
import pandas as pd
import numpy as np
from math import isnan
import pymongo
from pymongo import MongoClient
import json

# %% [markdown]
# ### Read data from MongoDB database

# %%
class Scraper:
    def __init__(self):
        
        #Mongodb connection
        self.conn = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                                #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')

        #Mongodb database and repository
        db = self.conn.Stucom

        #Collections
        self.CAT =  db.CAT 
    
    def visualize_values(self): 

        # take the values
        values = self.CAT.find() 
        
        # go through the values of the object "pymongo"
        for i in values: 
            print(i)



if __name__ == "__main__":

    scraper = Scraper()
    scraper.visualize_values()

# %%
# Get the database
client = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                            
                     #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true")

db = client["Events"]
col = db["Cos4Cloud"]
data = pd.DataFrame(list(col.find()))

# %% [markdown]
# Visualization of the data

# %%
data
# Out:
#                          _id                      created_at  \
# 0   606dd0bd4e60b42720328f26  Wed Apr 07 11:31:17 +0000 2021
# 1   606dd0bd4e60b42720328f27  Wed Apr 07 11:31:05 +0000 2021
# 2   606dd0bd4e60b42720328f28  Wed Apr 07 11:22:03 +0000 2021
# 3   606dd0bd4e60b42720328f29  Wed Apr 07 08:49:29 +0000 2021
# 4   606dd0bd4e60b42720328f2a  Wed Apr 07 08:32:48 +0000 2021
# 5   606dd0bd4e60b42720328f2b  Wed Apr 07 08:30:23 +0000 2021
# 6   606dd0bd4e60b42720328f2c  Wed Apr 07 08:30:05 +0000 2021
# 7   606dd0bd4e60b42720328f2d  Tue Apr 06 11:05:48 +0000 2021
# 8   606dd0bd4e60b42720328f2e  Tue Apr 06 10:52:15 +0000 2021
# 9   606dd0bd4e60b42720328f2f  Tue Apr 06 08:44:15 +0000 2021
# 10  606dd0bd4e60b42720328f30  Tue Apr 06 08:41:47 +0000 2021
# 11  606dd0bd4e60b42720328f31  Tue Apr 06 05:42:33 +0000 2021
# 12  606dd0bd4e60b42720328f32  Mon Apr 05 08:50:10 +0000 2021
# 13  606dd0bd4e60b42720328f33  Thu Apr 01 23:52:19 +0000 2021
# 14  606dd0bd4e60b42720328f34  Thu Apr 01 13:51:38 +0000 2021
# 15  606dd0bd4e60b42720328f35  Thu Apr 01 07:05:16 +0000 2021
# 16  606dd0bd4e60b42720328f36  Thu Apr 01 06:39:00 +0000 2021
# 17  606dd0bd4e60b42720328f37  Thu Apr 01 06:38:47 +0000 2021
# 18  606dd0bd4e60b42720328f38  Wed Mar 31 20:30:43 +0000 2021
# 19  606dd0bd4e60b42720328f39  Wed Mar 31 12:40:30 +0000 2021
# 20  606dd0bd4e60b42720328f3a  Wed Mar 31 12:28:59 +0000 2021
# 21  606dd0bd4e60b42720328f3b  Wed Mar 31 11:48:14 +0000 2021
# 22  606dd0bd4e60b42720328f3c  Wed Mar 31 11:38:40 +0000 2021
# 23  606dd0bd4e60b42720328f3d  Wed Mar 31 10:38:23 +0000 2021
# 24  606dd0bd4e60b42720328f3e  Wed Mar 31 10:01:22 +0000 2021
# 25  606dd0bd4e60b42720328f3f  Wed Mar 31 09:40:56 +0000 2021
# 26  606dd0bd4e60b42720328f40  Wed Mar 31 09:13:35 +0000 2021
# 27  606dd0bd4e60b42720328f41  Wed Mar 31 09:08:16 +0000 2021
# 28  606dd0bd4e60b42720328f42  Wed Mar 31 09:08:10 +0000 2021
# 29  606dd0bd4e60b42720328f43  Wed Mar 31 09:08:02 +0000 2021
# 30  606dd0bd4e60b42720328f44  Wed Mar 31 08:09:05 +0000 2021
# 31  606dd0bd4e60b42720328f45  Wed Mar 31 08:00:48 +0000 2021
# 32  606dd0bd4e60b42720328f46  Wed Mar 31 08:00:47 +0000 2021
# 33  606dd0bd4e60b42720328f47  Wed Mar 31 08:00:46 +0000 2021
# 34  606dd0bd4e60b42720328f48  Wed Mar 31 08:00:44 +0000 2021
# 35  606dd0bd4e60b42720328f49  Wed Mar 31 08:00:41 +0000 2021
# 36  606dd0bd4e60b42720328f4a  Wed Mar 31 08:00:39 +0000 2021
# 37  606dd0bd4e60b42720328f4b  Tue Mar 30 15:02:26 +0000 2021
# 38  606dd0bd4e60b42720328f4c  Tue Mar 30 14:18:58 +0000 2021
#
#                      id               id_str  \
# 0   1379758673564725250  1379758673564725250
# 1   1379758623895781376  1379758623895781376
# 2   1379756351581208577  1379756351581208577
# 3   1379717958268772353  1379717958268772353
# 4   1379713756805132288  1379713756805132288
# 5   1379713149155217408  1379713149155217408
# 6   1379713075562094593  1379713075562094593
# 7   1379389873753296896  1379389873753296896
# 8   1379386465310945280  1379386465310945280
# 9   1379354252565446657  1379354252565446657
# 10  1379353633276489729  1379353633276489729
# 11  1379308527202803712  1379308527202803712
# 12  1378993352394280960  1378993352394280960
# 13  1377770836954783744  1377770836954783744
# 14  1377619667804635143  1377619667804635143
# 15  1377517402427158528  1377517402427158528
# 16  1377510790723407874  1377510790723407874
# 17  1377510738667929600  1377510738667929600
# 18  1377357714171383809  1377357714171383809
# 19  1377239378112737281  1377239378112737281
# 20  1377236479139799043  1377236479139799043
# 21  1377226225400356866  1377226225400356866
# 22  1377223816422768643  1377223816422768643
# 23  1377208647571357700  1377208647571357700
# 24  1377199332684931078  1377199332684931078
# 25  1377194189386088451  1377194189386088451
# 26  1377187308751839233  1377187308751839233
# 27  1377185970450096135  1377185970450096135
# 28  1377185943984037889  1377185943984037889
# 29  1377185909469184008  1377185909469184008
# 30  1377171075029553157  1377171075029553157
# 31  1377168990108143616  1377168990108143616
# 32  1377168984563326980  1377168984563326980
# 33  1377168980692008968  1377168980692008968
# 34  1377168971682615298  1377168971682615298
# 35  1377168960513171457  1377168960513171457
# 36  1377168953655521281  1377168953655521281
# 37  1376912711880151047  1376912711880151047
# 38  1376901771348508673  1376901771348508673
#
#                                             full_text  truncated  \
# 0   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 1   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 2   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 3   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 4   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 5   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 6   Join #LifeCLEF, a yearly event to boost resear...      False
# 7   RT @SciencefChange: 🤔Did you miss the webinar:...      False
# 8   🤔Did you miss the webinar: 'Introducing @Cos4C...      False
# 9   RT @Cos4Cloud: How #Artportalen, a citizen obs...      False
# 10  How #Artportalen, a citizen observatory manage...      False
# 11  RT @canairq: #Respiraton2021 - Bootcamp 1 http...      False
# 12  RT @canairq: #Respiratón2021 🫁 🌎 Te invitamos ...      False
# 13  RT @WeObserveEU: 📢 For the people that did not...      False
# 14  RT @ICMCSIC: 🦀🐡🐙Ets un fanàtic de la biologia ...      False
# 15  RT @Cos4Cloud: What ideas do you have to help ...      False
# 16  RT @Cos4Cloud: What ideas do you have to help ...      False
# 17  RT @Cos4Cloud: Do you want to know more? Don't...      False
# 18  RT @ICMCSIC: 🦀🐡🐙Ets un fanàtic de la biologia ...      False
# 19  RT @Cos4Cloud: What ideas do you have to help ...      False
# 20  RT @Cos4Cloud: What ideas do you have to help ...      False
# 21  RT @EnvironmEdLab: 📌Διαδικτυακή επιμορφωτική η...      False
# 22  RT @EnvironmEdLab: 📌Διαδικτυακή επιμορφωτική η...      False
# 23  📌Διαδικτυακή επιμορφωτική ημερίδα: «Τα φαρμακε...      False
# 24  RT @Cos4Cloud: Do you want to know more? Don't...      False
# 25  RT @Cos4Cloud: Imagine that citizens can direc...      False
# 26  RT @Cos4Cloud: Do you want to know more? Don't...      False
# 27  RT @Cos4Cloud: Authorities and governmental ag...      False
# 28  RT @Cos4Cloud: But, how come Artportalen has g...      False
# 29  RT @Cos4Cloud: Do you want to know more? Don't...      False
# 30  RT @Cos4Cloud: Imagine that citizens can direc...      False
# 31  Do you want to know more? Don't miss this grea...      False
# 32  We're happy to have such an outstanding citize...      False
# 33  But, how come Artportalen has got so many obse...      False
# 34  Authorities and governmental agencies consider...      False
# 35  Artportalen, is a citizen observatory managed ...      False
# 36  Imagine that citizens can directly influence t...      False
# 37  RT @Cos4Cloud: What ideas do you have to help ...      False
# 38  What ideas do you have to help citizens reduce...      False
#
#    display_text_range                                           entities  \
# 0            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 1            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 2            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 3            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 4            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 5            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 6            [0, 268]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 7            [0, 139]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 8            [0, 245]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 9            [0, 140]  {'hashtags': [{'text': 'Artportalen', 'indices...
# 10           [0, 209]  {'hashtags': [{'text': 'Artportalen', 'indices...
# 11           [0, 110]  {'hashtags': [{'text': 'Respiraton2021', 'indi...
# 12           [0, 139]  {'hashtags': [{'text': 'Respiratón2021', 'indi...
# 13           [0, 140]  {'hashtags': [{'text': 'Webinar', 'indices': [...
# 14           [0, 140]  {'hashtags': [{'text': 'BioMARató', 'indices':...
# 15           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 16           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 17           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 18           [0, 140]  {'hashtags': [{'text': 'BioMARató', 'indices':...
# 19           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 20           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 21           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 22           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 23           [0, 273]  {'hashtags': [{'text': 'MedicinalAromaticPlant...
# 24           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 25           [0, 140]  {'hashtags': [{'text': 'biodiversity', 'indice...
# 26           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 27           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 28           [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 29           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 30           [0, 140]  {'hashtags': [{'text': 'biodiversity', 'indice...
# 31           [0, 242]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 32           [0, 213]  {'hashtags': [{'text': 'COS4Bio', 'indices': [...
# 33           [0, 274]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 34           [0, 256]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 35           [0, 267]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 36           [0, 277]  {'hashtags': [{'text': 'biodiversity', 'indice...
# 37           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 38           [0, 274]  {'hashtags': [{'text': 'Respiratón', 'indices'...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'en', 'result_type': 're...
# 4   {'iso_language_code': 'en', 'result_type': 're...
# 5   {'iso_language_code': 'en', 'result_type': 're...
# 6   {'iso_language_code': 'en', 'result_type': 're...
# 7   {'iso_language_code': 'en', 'result_type': 're...
# 8   {'iso_language_code': 'en', 'result_type': 're...
# 9   {'iso_language_code': 'en', 'result_type': 're...
# 10  {'iso_language_code': 'en', 'result_type': 're...
# 11  {'iso_language_code': 'fr', 'result_type': 're...
# 12  {'iso_language_code': 'es', 'result_type': 're...
# 13  {'iso_language_code': 'en', 'result_type': 're...
# 14  {'result_type': 'recent', 'iso_language_code':...
# 15  {'iso_language_code': 'en', 'result_type': 're...
# 16  {'iso_language_code': 'en', 'result_type': 're...
# 17  {'iso_language_code': 'en', 'result_type': 're...
# 18  {'result_type': 'recent', 'iso_language_code':...
# 19  {'iso_language_code': 'en', 'result_type': 're...
# 20  {'iso_language_code': 'en', 'result_type': 're...
# 21  {'iso_language_code': 'el', 'result_type': 're...
# 22  {'iso_language_code': 'el', 'result_type': 're...
# 23  {'iso_language_code': 'el', 'result_type': 're...
# 24  {'iso_language_code': 'en', 'result_type': 're...
# 25  {'iso_language_code': 'en', 'result_type': 're...
# 26  {'iso_language_code': 'en', 'result_type': 're...
# 27  {'iso_language_code': 'en', 'result_type': 're...
# 28  {'iso_language_code': 'en', 'result_type': 're...
# 29  {'iso_language_code': 'en', 'result_type': 're...
# 30  {'iso_language_code': 'en', 'result_type': 're...
# 31  {'iso_language_code': 'en', 'result_type': 're...
# 32  {'iso_language_code': 'en', 'result_type': 're...
# 33  {'iso_language_code': 'en', 'result_type': 're...
# 34  {'iso_language_code': 'en', 'result_type': 're...
# 35  {'iso_language_code': 'en', 'result_type': 're...
# 36  {'iso_language_code': 'en', 'result_type': 're...
# 37  {'iso_language_code': 'en', 'result_type': 're...
# 38  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                source  ... contributors  \
# 0   <a href="https://hubofco.de" rel="nofollow">hu...  ...         None
# 1   <a href="http://twitter.com/download/iphone" r...  ...         None
# 2   <a href="http://twitter.com/download/android" ...  ...         None
# 3   <a href="http://www.algocentric.ca" rel="nofol...  ...         None
# 4   <a href="https://mm218.dev" rel="nofollow">all...  ...         None
# 5                                                      ...         None
# 6   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 7   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 8   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 9   <a href="https://mm218.dev" rel="nofollow">all...  ...         None
# 10  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 11  <a href="http://twitter.com/download/android" ...  ...         None
# 12  <a href="http://twitter.com/download/android" ...  ...         None
# 13  <a href="http://twitter.com/download/android" ...  ...         None
# 14  <a href="http://twitter.com/download/android" ...  ...         None
# 15  <a href="http://twitter.com/download/android" ...  ...         None
# 16  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 17  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 18  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 19  <a href="http://twitter.com/download/android" ...  ...         None
# 20  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 21  <a href="http://twitter.com/download/android" ...  ...         None
# 22  <a href="http://twitter.com/download/android" ...  ...         None
# 23  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 24  <a href="http://twitter.com/download/iphone" r...  ...         None
# 25  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 26  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 27  <a href="https://www.hootsuite.com" rel="nofol...  ...         None
# 28  <a href="https://www.hootsuite.com" rel="nofol...  ...         None
# 29  <a href="https://www.hootsuite.com" rel="nofol...  ...         None
# 30  <a href="https://mm218.dev" rel="nofollow">all...  ...         None
# 31  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 32  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 33  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 34  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 35  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 36  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 37  <a href="https://www.hootsuite.com" rel="nofol...  ...         None
# 38  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
#
#                                      retweeted_status is_quote_status  \
# 0   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 1   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 2   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 3   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 4   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 5   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 6                                                 NaN           False
# 7   {'created_at': 'Tue Apr 06 10:52:15 +0000 2021...           False
# 8                                                 NaN           False
# 9   {'created_at': 'Tue Apr 06 08:41:47 +0000 2021...           False
# 10                                                NaN           False
# 11  {'created_at': 'Mon Apr 05 22:36:54 +0000 2021...           False
# 12  {'created_at': 'Fri Mar 19 21:06:51 +0000 2021...           False
# 13  {'created_at': 'Thu Apr 01 14:04:01 +0000 2021...           False
# 14  {'created_at': 'Mon Mar 29 08:01:19 +0000 2021...           False
# 15  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 16  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 17  {'created_at': 'Wed Mar 31 08:00:48 +0000 2021...           False
# 18  {'created_at': 'Mon Mar 29 08:01:19 +0000 2021...           False
# 19  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 20  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 21  {'created_at': 'Wed Mar 31 10:38:23 +0000 2021...           False
# 22  {'created_at': 'Wed Mar 31 10:38:23 +0000 2021...           False
# 23                                                NaN           False
# 24  {'created_at': 'Wed Mar 31 08:00:48 +0000 2021...           False
# 25  {'created_at': 'Wed Mar 31 08:00:39 +0000 2021...           False
# 26  {'created_at': 'Wed Mar 31 08:00:48 +0000 2021...           False
# 27  {'created_at': 'Wed Mar 31 08:00:44 +0000 2021...           False
# 28  {'created_at': 'Wed Mar 31 08:00:46 +0000 2021...           False
# 29  {'created_at': 'Wed Mar 31 08:00:48 +0000 2021...           False
# 30  {'created_at': 'Wed Mar 31 08:00:39 +0000 2021...           False
# 31                                                NaN           False
# 32                                                NaN           False
# 33                                                NaN           False
# 34                                                NaN           False
# 35                                                NaN           False
# 36                                                NaN           False
# 37  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 38                                                NaN           False
#
#    retweet_count favorite_count favorited retweeted lang  \
# 0              6              0     False     False   en
# 1              6              0     False     False   en
# 2              6              0     False     False   en
# 3              6              0     False     False   en
# 4              6              0     False     False   en
# 5              6              0     False     False   en
# 6              6              4     False     False   en
# 7              1              0     False     False   en
# 8              1              2     False     False   en
# 9              1              0     False     False   en
# 10             1              3     False     False   en
# 11             6              0     False     False   fr
# 12            23              0     False     False   es
# 13             7              0     False     False   en
# 14            15              0     False     False   ca
# 15             5              0     False     False   en
# 16             5              0     False     False   en
# 17             4              0     False     False   en
# 18            15              0     False     False   ca
# 19             5              0     False     False   en
# 20             5              0     False     False   en
# 21             2              0     False     False   el
# 22             2              0     False     False   el
# 23             2              1     False     False   el
# 24             4              0     False     False   en
# 25             2              0     False     False   en
# 26             4              0     False     False   en
# 27             1              0     False     False   en
# 28             1              0     False     False   en
# 29             4              0     False     False   en
# 30             2              0     False     False   en
# 31             4              6     False     False   en
# 32             0              1     False     False   en
# 33             1              1     False     False   en
# 34             1              1     False     False   en
# 35             0              0     False     False   en
# 36             2              0     False     False   en
# 37             5              0     False     False   en
# 38             5             10     False     False   en
#
#                                     extended_entities possibly_sensitive
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# 5                                                 NaN                NaN
# 6   {'media': [{'id': '1379712864676626433', 'id_s...              False
# 7                                                 NaN                NaN
# 8   {'media': [{'id': '1379381516762030082', 'id_s...              False
# 9                                                 NaN                NaN
# 10  {'media': [{'id': '1379352685825101824', 'id_s...              False
# 11  {'media': [{'id': '1379199733072334848', 'id_s...              False
# 12                                                NaN                NaN
# 13                                                NaN                NaN
# 14                                                NaN                NaN
# 15                                                NaN                NaN
# 16                                                NaN                NaN
# 17                                                NaN                NaN
# 18                                                NaN                NaN
# 19                                                NaN                NaN
# 20                                                NaN                NaN
# 21                                                NaN                NaN
# 22                                                NaN                NaN
# 23  {'media': [{'id': '1377208195190558724', 'id_s...              False
# 24                                                NaN                NaN
# 25                                                NaN                NaN
# 26                                                NaN                NaN
# 27                                                NaN                NaN
# 28                                                NaN                NaN
# 29                                                NaN                NaN
# 30                                                NaN                NaN
# 31  {'media': [{'id': '1377168436241915904', 'id_s...              False
# 32                                                NaN                NaN
# 33  {'media': [{'id': '1377168115985883138', 'id_s...              False
# 34  {'media': [{'id': '1377168071501049856', 'id_s...              False
# 35  {'media': [{'id': '1377168012004847616', 'id_s...              False
# 36  {'media': [{'id': '1377167887316619268', 'id_s...              False
# 37                                                NaN                NaN
# 38  {'media': [{'id': '1376901387737563139', 'id_s...              False
#
# [39 rows x 29 columns]

# %% [markdown]
# ### Quit outliers

# %% [markdown]
# Delete repeated tweets.

# %%
data = data.drop_duplicates(subset=['id'])
data = data.reset_index(drop=True)
data
# Out:
#                          _id                      created_at  \
# 0   606dd0bd4e60b42720328f26  Wed Apr 07 11:31:17 +0000 2021
# 1   606dd0bd4e60b42720328f27  Wed Apr 07 11:31:05 +0000 2021
# 2   606dd0bd4e60b42720328f28  Wed Apr 07 11:22:03 +0000 2021
# 3   606dd0bd4e60b42720328f29  Wed Apr 07 08:49:29 +0000 2021
# 4   606dd0bd4e60b42720328f2a  Wed Apr 07 08:32:48 +0000 2021
# 5   606dd0bd4e60b42720328f2b  Wed Apr 07 08:30:23 +0000 2021
# 6   606dd0bd4e60b42720328f2c  Wed Apr 07 08:30:05 +0000 2021
# 7   606dd0bd4e60b42720328f2d  Tue Apr 06 11:05:48 +0000 2021
# 8   606dd0bd4e60b42720328f2e  Tue Apr 06 10:52:15 +0000 2021
# 9   606dd0bd4e60b42720328f2f  Tue Apr 06 08:44:15 +0000 2021
# 10  606dd0bd4e60b42720328f30  Tue Apr 06 08:41:47 +0000 2021
# 11  606dd0bd4e60b42720328f31  Tue Apr 06 05:42:33 +0000 2021
# 12  606dd0bd4e60b42720328f32  Mon Apr 05 08:50:10 +0000 2021
# 13  606dd0bd4e60b42720328f33  Thu Apr 01 23:52:19 +0000 2021
# 14  606dd0bd4e60b42720328f34  Thu Apr 01 13:51:38 +0000 2021
# 15  606dd0bd4e60b42720328f35  Thu Apr 01 07:05:16 +0000 2021
# 16  606dd0bd4e60b42720328f36  Thu Apr 01 06:39:00 +0000 2021
# 17  606dd0bd4e60b42720328f37  Thu Apr 01 06:38:47 +0000 2021
# 18  606dd0bd4e60b42720328f38  Wed Mar 31 20:30:43 +0000 2021
# 19  606dd0bd4e60b42720328f39  Wed Mar 31 12:40:30 +0000 2021
# 20  606dd0bd4e60b42720328f3a  Wed Mar 31 12:28:59 +0000 2021
# 21  606dd0bd4e60b42720328f3b  Wed Mar 31 11:48:14 +0000 2021
# 22  606dd0bd4e60b42720328f3c  Wed Mar 31 11:38:40 +0000 2021
# 23  606dd0bd4e60b42720328f3d  Wed Mar 31 10:38:23 +0000 2021
# 24  606dd0bd4e60b42720328f3e  Wed Mar 31 10:01:22 +0000 2021
# 25  606dd0bd4e60b42720328f3f  Wed Mar 31 09:40:56 +0000 2021
# 26  606dd0bd4e60b42720328f40  Wed Mar 31 09:13:35 +0000 2021
# 27  606dd0bd4e60b42720328f41  Wed Mar 31 09:08:16 +0000 2021
# 28  606dd0bd4e60b42720328f42  Wed Mar 31 09:08:10 +0000 2021
# 29  606dd0bd4e60b42720328f43  Wed Mar 31 09:08:02 +0000 2021
# 30  606dd0bd4e60b42720328f44  Wed Mar 31 08:09:05 +0000 2021
# 31  606dd0bd4e60b42720328f45  Wed Mar 31 08:00:48 +0000 2021
# 32  606dd0bd4e60b42720328f46  Wed Mar 31 08:00:47 +0000 2021
# 33  606dd0bd4e60b42720328f47  Wed Mar 31 08:00:46 +0000 2021
# 34  606dd0bd4e60b42720328f48  Wed Mar 31 08:00:44 +0000 2021
# 35  606dd0bd4e60b42720328f49  Wed Mar 31 08:00:41 +0000 2021
# 36  606dd0bd4e60b42720328f4a  Wed Mar 31 08:00:39 +0000 2021
# 37  606dd0bd4e60b42720328f4b  Tue Mar 30 15:02:26 +0000 2021
# 38  606dd0bd4e60b42720328f4c  Tue Mar 30 14:18:58 +0000 2021
#
#                      id               id_str  \
# 0   1379758673564725250  1379758673564725250
# 1   1379758623895781376  1379758623895781376
# 2   1379756351581208577  1379756351581208577
# 3   1379717958268772353  1379717958268772353
# 4   1379713756805132288  1379713756805132288
# 5   1379713149155217408  1379713149155217408
# 6   1379713075562094593  1379713075562094593
# 7   1379389873753296896  1379389873753296896
# 8   1379386465310945280  1379386465310945280
# 9   1379354252565446657  1379354252565446657
# 10  1379353633276489729  1379353633276489729
# 11  1379308527202803712  1379308527202803712
# 12  1378993352394280960  1378993352394280960
# 13  1377770836954783744  1377770836954783744
# 14  1377619667804635143  1377619667804635143
# 15  1377517402427158528  1377517402427158528
# 16  1377510790723407874  1377510790723407874
# 17  1377510738667929600  1377510738667929600
# 18  1377357714171383809  1377357714171383809
# 19  1377239378112737281  1377239378112737281
# 20  1377236479139799043  1377236479139799043
# 21  1377226225400356866  1377226225400356866
# 22  1377223816422768643  1377223816422768643
# 23  1377208647571357700  1377208647571357700
# 24  1377199332684931078  1377199332684931078
# 25  1377194189386088451  1377194189386088451
# 26  1377187308751839233  1377187308751839233
# 27  1377185970450096135  1377185970450096135
# 28  1377185943984037889  1377185943984037889
# 29  1377185909469184008  1377185909469184008
# 30  1377171075029553157  1377171075029553157
# 31  1377168990108143616  1377168990108143616
# 32  1377168984563326980  1377168984563326980
# 33  1377168980692008968  1377168980692008968
# 34  1377168971682615298  1377168971682615298
# 35  1377168960513171457  1377168960513171457
# 36  1377168953655521281  1377168953655521281
# 37  1376912711880151047  1376912711880151047
# 38  1376901771348508673  1376901771348508673
#
#                                             full_text  truncated  \
# 0   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 1   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 2   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 3   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 4   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 5   RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...      False
# 6   Join #LifeCLEF, a yearly event to boost resear...      False
# 7   RT @SciencefChange: 🤔Did you miss the webinar:...      False
# 8   🤔Did you miss the webinar: 'Introducing @Cos4C...      False
# 9   RT @Cos4Cloud: How #Artportalen, a citizen obs...      False
# 10  How #Artportalen, a citizen observatory manage...      False
# 11  RT @canairq: #Respiraton2021 - Bootcamp 1 http...      False
# 12  RT @canairq: #Respiratón2021 🫁 🌎 Te invitamos ...      False
# 13  RT @WeObserveEU: 📢 For the people that did not...      False
# 14  RT @ICMCSIC: 🦀🐡🐙Ets un fanàtic de la biologia ...      False
# 15  RT @Cos4Cloud: What ideas do you have to help ...      False
# 16  RT @Cos4Cloud: What ideas do you have to help ...      False
# 17  RT @Cos4Cloud: Do you want to know more? Don't...      False
# 18  RT @ICMCSIC: 🦀🐡🐙Ets un fanàtic de la biologia ...      False
# 19  RT @Cos4Cloud: What ideas do you have to help ...      False
# 20  RT @Cos4Cloud: What ideas do you have to help ...      False
# 21  RT @EnvironmEdLab: 📌Διαδικτυακή επιμορφωτική η...      False
# 22  RT @EnvironmEdLab: 📌Διαδικτυακή επιμορφωτική η...      False
# 23  📌Διαδικτυακή επιμορφωτική ημερίδα: «Τα φαρμακε...      False
# 24  RT @Cos4Cloud: Do you want to know more? Don't...      False
# 25  RT @Cos4Cloud: Imagine that citizens can direc...      False
# 26  RT @Cos4Cloud: Do you want to know more? Don't...      False
# 27  RT @Cos4Cloud: Authorities and governmental ag...      False
# 28  RT @Cos4Cloud: But, how come Artportalen has g...      False
# 29  RT @Cos4Cloud: Do you want to know more? Don't...      False
# 30  RT @Cos4Cloud: Imagine that citizens can direc...      False
# 31  Do you want to know more? Don't miss this grea...      False
# 32  We're happy to have such an outstanding citize...      False
# 33  But, how come Artportalen has got so many obse...      False
# 34  Authorities and governmental agencies consider...      False
# 35  Artportalen, is a citizen observatory managed ...      False
# 36  Imagine that citizens can directly influence t...      False
# 37  RT @Cos4Cloud: What ideas do you have to help ...      False
# 38  What ideas do you have to help citizens reduce...      False
#
#    display_text_range                                           entities  \
# 0            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 1            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 2            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 3            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 4            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 5            [0, 140]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 6            [0, 268]  {'hashtags': [{'text': 'LifeCLEF', 'indices': ...
# 7            [0, 139]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 8            [0, 245]  {'hashtags': [{'text': 'CitizenScience', 'indi...
# 9            [0, 140]  {'hashtags': [{'text': 'Artportalen', 'indices...
# 10           [0, 209]  {'hashtags': [{'text': 'Artportalen', 'indices...
# 11           [0, 110]  {'hashtags': [{'text': 'Respiraton2021', 'indi...
# 12           [0, 139]  {'hashtags': [{'text': 'Respiratón2021', 'indi...
# 13           [0, 140]  {'hashtags': [{'text': 'Webinar', 'indices': [...
# 14           [0, 140]  {'hashtags': [{'text': 'BioMARató', 'indices':...
# 15           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 16           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 17           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 18           [0, 140]  {'hashtags': [{'text': 'BioMARató', 'indices':...
# 19           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 20           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 21           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 22           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 23           [0, 273]  {'hashtags': [{'text': 'MedicinalAromaticPlant...
# 24           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 25           [0, 140]  {'hashtags': [{'text': 'biodiversity', 'indice...
# 26           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 27           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 28           [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 29           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 30           [0, 140]  {'hashtags': [{'text': 'biodiversity', 'indice...
# 31           [0, 242]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 32           [0, 213]  {'hashtags': [{'text': 'COS4Bio', 'indices': [...
# 33           [0, 274]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 34           [0, 256]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 35           [0, 267]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 36           [0, 277]  {'hashtags': [{'text': 'biodiversity', 'indice...
# 37           [0, 140]  {'hashtags': [{'text': 'Respiratón', 'indices'...
# 38           [0, 274]  {'hashtags': [{'text': 'Respiratón', 'indices'...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'en', 'result_type': 're...
# 4   {'iso_language_code': 'en', 'result_type': 're...
# 5   {'iso_language_code': 'en', 'result_type': 're...
# 6   {'iso_language_code': 'en', 'result_type': 're...
# 7   {'iso_language_code': 'en', 'result_type': 're...
# 8   {'iso_language_code': 'en', 'result_type': 're...
# 9   {'iso_language_code': 'en', 'result_type': 're...
# 10  {'iso_language_code': 'en', 'result_type': 're...
# 11  {'iso_language_code': 'fr', 'result_type': 're...
# 12  {'iso_language_code': 'es', 'result_type': 're...
# 13  {'iso_language_code': 'en', 'result_type': 're...
# 14  {'result_type': 'recent', 'iso_language_code':...
# 15  {'iso_language_code': 'en', 'result_type': 're...
# 16  {'iso_language_code': 'en', 'result_type': 're...
# 17  {'iso_language_code': 'en', 'result_type': 're...
# 18  {'result_type': 'recent', 'iso_language_code':...
# 19  {'iso_language_code': 'en', 'result_type': 're...
# 20  {'iso_language_code': 'en', 'result_type': 're...
# 21  {'iso_language_code': 'el', 'result_type': 're...
# 22  {'iso_language_code': 'el', 'result_type': 're...
# 23  {'iso_language_code': 'el', 'result_type': 're...
# 24  {'iso_language_code': 'en', 'result_type': 're...
# 25  {'iso_language_code': 'en', 'result_type': 're...
# 26  {'iso_language_code': 'en', 'result_type': 're...
# 27  {'iso_language_code': 'en', 'result_type': 're...
# 28  {'iso_language_code': 'en', 'result_type': 're...
# 29  {'iso_language_code': 'en', 'result_type': 're...
# 30  {'iso_language_code': 'en', 'result_type': 're...
# 31  {'iso_language_code': 'en', 'result_type': 're...
# 32  {'iso_language_code': 'en', 'result_type': 're...
# 33  {'iso_language_code': 'en', 'result_type': 're...
# 34  {'iso_language_code': 'en', 'result_type': 're...
# 35  {'iso_language_code': 'en', 'result_type': 're...
# 36  {'iso_language_code': 'en', 'result_type': 're...
# 37  {'iso_language_code': 'en', 'result_type': 're...
# 38  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                source  ... contributors  \
# 0   <a href="https://hubofco.de" rel="nofollow">hu...  ...         None
# 1   <a href="http://twitter.com/download/iphone" r...  ...         None
# 2   <a href="http://twitter.com/download/android" ...  ...         None
# 3   <a href="http://www.algocentric.ca" rel="nofol...  ...         None
# 4   <a href="https://mm218.dev" rel="nofollow">all...  ...         None
# 5                                                      ...         None
# 6   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 7   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 8   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 9   <a href="https://mm218.dev" rel="nofollow">all...  ...         None
# 10  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 11  <a href="http://twitter.com/download/android" ...  ...         None
# 12  <a href="http://twitter.com/download/android" ...  ...         None
# 13  <a href="http://twitter.com/download/android" ...  ...         None
# 14  <a href="http://twitter.com/download/android" ...  ...         None
# 15  <a href="http://twitter.com/download/android" ...  ...         None
# 16  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 17  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 18  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 19  <a href="http://twitter.com/download/android" ...  ...         None
# 20  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 21  <a href="http://twitter.com/download/android" ...  ...         None
# 22  <a href="http://twitter.com/download/android" ...  ...         None
# 23  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 24  <a href="http://twitter.com/download/iphone" r...  ...         None
# 25  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 26  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 27  <a href="https://www.hootsuite.com" rel="nofol...  ...         None
# 28  <a href="https://www.hootsuite.com" rel="nofol...  ...         None
# 29  <a href="https://www.hootsuite.com" rel="nofol...  ...         None
# 30  <a href="https://mm218.dev" rel="nofollow">all...  ...         None
# 31  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 32  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 33  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 34  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 35  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 36  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 37  <a href="https://www.hootsuite.com" rel="nofol...  ...         None
# 38  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
#
#                                      retweeted_status is_quote_status  \
# 0   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 1   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 2   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 3   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 4   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 5   {'created_at': 'Wed Apr 07 08:30:05 +0000 2021...           False
# 6                                                 NaN           False
# 7   {'created_at': 'Tue Apr 06 10:52:15 +0000 2021...           False
# 8                                                 NaN           False
# 9   {'created_at': 'Tue Apr 06 08:41:47 +0000 2021...           False
# 10                                                NaN           False
# 11  {'created_at': 'Mon Apr 05 22:36:54 +0000 2021...           False
# 12  {'created_at': 'Fri Mar 19 21:06:51 +0000 2021...           False
# 13  {'created_at': 'Thu Apr 01 14:04:01 +0000 2021...           False
# 14  {'created_at': 'Mon Mar 29 08:01:19 +0000 2021...           False
# 15  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 16  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 17  {'created_at': 'Wed Mar 31 08:00:48 +0000 2021...           False
# 18  {'created_at': 'Mon Mar 29 08:01:19 +0000 2021...           False
# 19  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 20  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 21  {'created_at': 'Wed Mar 31 10:38:23 +0000 2021...           False
# 22  {'created_at': 'Wed Mar 31 10:38:23 +0000 2021...           False
# 23                                                NaN           False
# 24  {'created_at': 'Wed Mar 31 08:00:48 +0000 2021...           False
# 25  {'created_at': 'Wed Mar 31 08:00:39 +0000 2021...           False
# 26  {'created_at': 'Wed Mar 31 08:00:48 +0000 2021...           False
# 27  {'created_at': 'Wed Mar 31 08:00:44 +0000 2021...           False
# 28  {'created_at': 'Wed Mar 31 08:00:46 +0000 2021...           False
# 29  {'created_at': 'Wed Mar 31 08:00:48 +0000 2021...           False
# 30  {'created_at': 'Wed Mar 31 08:00:39 +0000 2021...           False
# 31                                                NaN           False
# 32                                                NaN           False
# 33                                                NaN           False
# 34                                                NaN           False
# 35                                                NaN           False
# 36                                                NaN           False
# 37  {'created_at': 'Tue Mar 30 14:18:58 +0000 2021...           False
# 38                                                NaN           False
#
#    retweet_count favorite_count favorited retweeted lang  \
# 0              6              0     False     False   en
# 1              6              0     False     False   en
# 2              6              0     False     False   en
# 3              6              0     False     False   en
# 4              6              0     False     False   en
# 5              6              0     False     False   en
# 6              6              4     False     False   en
# 7              1              0     False     False   en
# 8              1              2     False     False   en
# 9              1              0     False     False   en
# 10             1              3     False     False   en
# 11             6              0     False     False   fr
# 12            23              0     False     False   es
# 13             7              0     False     False   en
# 14            15              0     False     False   ca
# 15             5              0     False     False   en
# 16             5              0     False     False   en
# 17             4              0     False     False   en
# 18            15              0     False     False   ca
# 19             5              0     False     False   en
# 20             5              0     False     False   en
# 21             2              0     False     False   el
# 22             2              0     False     False   el
# 23             2              1     False     False   el
# 24             4              0     False     False   en
# 25             2              0     False     False   en
# 26             4              0     False     False   en
# 27             1              0     False     False   en
# 28             1              0     False     False   en
# 29             4              0     False     False   en
# 30             2              0     False     False   en
# 31             4              6     False     False   en
# 32             0              1     False     False   en
# 33             1              1     False     False   en
# 34             1              1     False     False   en
# 35             0              0     False     False   en
# 36             2              0     False     False   en
# 37             5              0     False     False   en
# 38             5             10     False     False   en
#
#                                     extended_entities possibly_sensitive
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# 5                                                 NaN                NaN
# 6   {'media': [{'id': '1379712864676626433', 'id_s...              False
# 7                                                 NaN                NaN
# 8   {'media': [{'id': '1379381516762030082', 'id_s...              False
# 9                                                 NaN                NaN
# 10  {'media': [{'id': '1379352685825101824', 'id_s...              False
# 11  {'media': [{'id': '1379199733072334848', 'id_s...              False
# 12                                                NaN                NaN
# 13                                                NaN                NaN
# 14                                                NaN                NaN
# 15                                                NaN                NaN
# 16                                                NaN                NaN
# 17                                                NaN                NaN
# 18                                                NaN                NaN
# 19                                                NaN                NaN
# 20                                                NaN                NaN
# 21                                                NaN                NaN
# 22                                                NaN                NaN
# 23  {'media': [{'id': '1377208195190558724', 'id_s...              False
# 24                                                NaN                NaN
# 25                                                NaN                NaN
# 26                                                NaN                NaN
# 27                                                NaN                NaN
# 28                                                NaN                NaN
# 29                                                NaN                NaN
# 30                                                NaN                NaN
# 31  {'media': [{'id': '1377168436241915904', 'id_s...              False
# 32                                                NaN                NaN
# 33  {'media': [{'id': '1377168115985883138', 'id_s...              False
# 34  {'media': [{'id': '1377168071501049856', 'id_s...              False
# 35  {'media': [{'id': '1377168012004847616', 'id_s...              False
# 36  {'media': [{'id': '1377167887316619268', 'id_s...              False
# 37                                                NaN                NaN
# 38  {'media': [{'id': '1376901387737563139', 'id_s...              False
#
# [39 rows x 29 columns]

# %% [markdown]
# Check that all tweets are in English

# %%
data = data[data['lang'] == 'en']

# %% [markdown]
# Delete tweets that are outside the desired range of dates

# %%
for i in range(0, len(data)):   
    item = data.iloc[i]
    
    if(int(item['created_at'][-4:])) < int(2021):
        data.drop([i],  inplace = True)

# %% [markdown]
# ### Treat the data to extract conclusions

# %% [markdown]
# Store for each tweet in the database: the text, the user, the number of retweets, the number of likes and the date.

# %%
tweets = []     # array for the text
users = []      # array for the user data
retweets = []   # array for the number of retweets
likes = []      # array for the number of likes
dates = []      # array for the dates of the tweets

for i in range(0, len(data)):
    
    item = data.iloc[i]    # store JSON object

    text =item['full_text']
    tweets.append(text.split())
    
    user = item['user']
    users.append(user)
        
    retweet = item['retweet_count']
    retweets.append(retweet)
    
    like = item['favorite_count']
    likes.append(like)
    
    date = item['created_at']
    dates.append(date)

# %%
# Fucntion to convert from the written month to the month in numbers
def convert_month(month):
    if month == 'Jan':
        month = 1
    elif month == 'Feb':
        month = 2
    elif month == 'Mar':
        month = 3
    elif month == 'Apr':
        month = 4
    elif month == 'May':
        month = 5
    elif month == 'Jun':
        month = 6
    elif month == 'Jul':
        month = 7
    elif month == 'Aug':
        month = 8
    elif month == 'Sep':
        month = 9
    elif month == 'Oct':
        month = 10
    elif month == 'Nov':
        month = 11
    elif month == 'Dec':
        month = 12
    return month
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %% [markdown]
# Search for the date of the first tweet and the last tweet published in our database.

# %%
find_date = []
for date in dates:
    year = date[-4:]
    month = date[4:7]
    month = convert_month(str(month))
    day = date[8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    find_date.append(pd.Timestamp(date))
    
max_date = max(find_date)
min_date = min(find_date)

print("The first tweet was published at ", min_date)
print("The last tweet was published at ", max_date)
# Out:
# The first tweet was published at  2021-03-30 00:00:00
# The last tweet was published at  2021-04-07 00:00:00

# %% [markdown]
# Number of tweets in the database.

# %%
print("From", min_date, " untill", max_date, len(data),"tweets have been published.")
# Out:
# From 2021-03-30 00:00:00  untill 2021-04-07 00:00:00 32 tweets have been published.

# %% [markdown]
# Most common words between the tweets.

# %%
tweets_arr = []
words_arr = []
non_interesting_words = ["in", "and", "RT", "a", "of", "what", "is", "he", "she", "already", "yet", "no", "science", "Science", 
                         "yes", "lot", "you", "Us", "citizen", "the", "are", "one", "to", "in", "Citizen", "for", "our", "on", 
                         "with", "this", "from", "can", "#CitizenScience", "that", "your", "about", "The", "-", "science.", 
                         "have", "we", "I", "has", "We", "at", "as", "be", "by", "not", "It’s", "out", "an", "us", "will", 
                         "get", "all", "it", "A", "In", "This", "do", "or", "how", "They", "but", "they", "my", "into", "So",
                         "If", "their", "Our", "up", "That's", "so", "now"]

for t in tweets:
    for i in t:
        tweets_arr.append(i)
        if (i.startswith(('#','@')) == False):
            words_arr.append(i)

for word in non_interesting_words:
    words_arr = [val for val in words_arr if val != word]

from collections import Counter 
Counter = Counter(words_arr) 
  
most_occur = Counter.most_common(100) 

print("The most common words are: \n", most_occur)
# Out:
# The most common words are:
#  [('data', 9), ('help', 9), ('citizens', 9), ('research', 8), ('miss', 8), ('Join', 7), ('yearly', 7), ('event', 7), ('boost', 7), ('through', 7), ('challenges⚙️🌸.', 7), ('air', 7), ('c…', 6), ('What', 6), ('ideas', 6), ('reduce', 6), ('exposure', 6), ('pollutants?', 6), ('😷', 6), ('Participate', 6), ('virtual', 6), ('Artportalen', 6), ('biodiversity', 6), ('environmental', 5), ('Hac…', 5), ('Do', 5), ('want', 5), ('know', 5), ('more?', 5), ("Don't", 5), ('great', 5), ('piece', 5), ('news', 5), ('written', 5), ('team:', 5), ("'Artportalen:", 5), ('success', 5), ('story', 5), ('Some', 5), ('observatory', 4), ('in…', 4), ('observations', 4), ('including', 3), ('managed', 3), ('crucial', 3), ('manage', 3), ('Imagine', 3), ('directly', 3), ('influence', 3), ("government's", 3), ('plans', 3), ('conservation.', 3), ('say', 3), ('conservation', 3), ('Swedish', 3), ('📆Deadline', 2), ('🤔Did', 2), ('webinar:', 2), ("'Introducing", 2), ('benefit', 2), ("community?'", 2), ('Here', 2), ('How', 2), ('became', 2), ('find', 2), ('people', 2), ('that’…', 2), ('Authorities', 2), ('governmental', 2), ('agencies', 2), ('consider', 2), ('primary', 2), ('information', 2), ('source', 2), ('But,', 2), ('come', 2), ('got', 2), ('many', 2), ('users,', 2), ('authorities?🧐', 2), ('management', 2), ('gathered', 2), ('✅It', 2), ('competition', 1), ('opened', 1), ('any', 1), ('interested', 1), ('team,', 1), ('developer,', 1), ('student!!', 1), ('register:', 1), ('16th', 1), ('May', 1), ('2021', 1), ('👉https://t.co/KZsKC73zea', 1), ('https://t.co/tre4BNVWwS', 1), ('have…', 1), ('link', 1), ('recording,', 1), ('presentations', 1)]

# %% [markdown]
# Extract the number of occurrences of each word in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Word', 'Number of occurrences'])
df_most_occur.to_csv("words_Cos4Cloud.csv")

# %% [markdown]
# Most common hashtags mentioned between the tweets.

# %%
hashtags = []
for word in tweets_arr:
    if word[0] == '#':
        hashtags.append(word)

from collections import Counter
Counter = Counter(hashtags)   
most_occur = Counter.most_common(40) 

print("The most common hashtags are: \n",most_occur)
# Out:
# The most common hashtags are:
#  [('#biodiversity', 12), ('#LifeCLEF,', 7), ('#machinelearning', 7), ('#Respiratón,', 6), ('#CitizenScience', 2), ('#Artportalen,', 2), ('#Webinar...', 1), ('#COS4Bio', 1), ('#citizenscience', 1)]

# %% [markdown]
# Extract the number of occurrences of each hashtag in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Hashtag', 'Number of mentions'])
df_most_occur.to_csv("hashtags_Cos4Cloud.csv")

# %% [markdown]
# Most common accounts mentioned between the tweets.

# %%
accounts = []
for word in tweets_arr:
    if word[0] == '@':
        accounts.append(word)

from collections import Counter
Counter = Counter(accounts)
most_occur = Counter.most_common(40) 

print("The most common mentioned accounts are: \n",most_occur)
# Out:
# The most common mentioned accounts are:
#  [('@Cos4Cloud:', 22), ('@_SLU', 5), ('@_SLU,', 3), ('@SciencefChange:', 1), ('@WeObserveEU:', 1), ('@WeObserveEU', 1), ('@BineoConsulting', 1), ('@TrebolaOrg', 1), ('@canairq', 1)]

# %% [markdown]
# Extract the number of occurrences of each account in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Account', 'Number of mentions'])
df_most_occur.to_csv("accounts_Cos4Cloud.csv")

# %% [markdown]
# Find the average and the maximum number of likes and retweets between the tweets.

# %%
print("The maximum number of retweets is: ", max(retweets))
print("The average number of retweets is: ", int(np.mean(retweets)))
print("\nThe maximum number of likes is: ", max(likes))
print("The average number of likes is: ", int(np.mean(likes)))
# Out:
# The maximum number of retweets is:  7
# The average number of retweets is:  3
#
# The maximum number of likes is:  10
# The average number of likes is:  0

# %% [markdown]
# Most retweeted tweets

# %%
print("The most retweeted tweets are: \n")
data.nlargest(20, ['retweet_count'])['full_text']
# Out:
# The most retweeted tweets are:
# 13    RT @WeObserveEU: 📢 For the people that did not...
# 0     RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...
# 1     RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...
# 2     RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...
# 3     RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...
# 4     RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...
# 5     RT @Cos4Cloud: Join #LifeCLEF, a yearly event ...
# 6     Join #LifeCLEF, a yearly event to boost resear...
# 15    RT @Cos4Cloud: What ideas do you have to help ...
# 16    RT @Cos4Cloud: What ideas do you have to help ...
# 19    RT @Cos4Cloud: What ideas do you have to help ...
# 20    RT @Cos4Cloud: What ideas do you have to help ...
# 37    RT @Cos4Cloud: What ideas do you have to help ...
# 38    What ideas do you have to help citizens reduce...
# 17    RT @Cos4Cloud: Do you want to know more? Don't...
# 24    RT @Cos4Cloud: Do you want to know more? Don't...
# 26    RT @Cos4Cloud: Do you want to know more? Don't...
# 29    RT @Cos4Cloud: Do you want to know more? Don't...
# 31    Do you want to know more? Don't miss this grea...
# 25    RT @Cos4Cloud: Imagine that citizens can direc...
# Name: full_text, dtype: object

# %% [markdown]
# Most common source types.

# %%
src_data = data[data['extended_entities'].notna() == True]

src_type = []
for i in src_data.index:
    num_src = len(src_data.loc[i]['extended_entities']['media'])
    for n in range(0, num_src):
        src_type.append(src_data.loc[i]['extended_entities']['media'][n]['type'])

from collections import Counter 
Counter = Counter(src_type)   
most_occur = Counter.most_common(20) 

print("The most common source types are: \n", most_occur)
# Out:
# The most common source types are:
#  [('photo', 9)]

# %% [markdown]
# Extract the number of occurrences of each source type in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Source', 'Number of occurrences'])
df_most_occur.to_csv("sources_Cos4Cloud.csv")

# %% [markdown]
# ## Analysis of the users interacting in Twitter about CS

# %% [markdown]
# Number of users interacting in CS.

# %%
user_ids = []
for u in users:
    if u['id'] not in user_ids:
        user_ids.append(u['id'])
print("There are ", len(user_ids), "active users.")
# Out:
# There are  16 active users.

# %% [markdown]
# Most active users between the tweets.

# %%
user_names = []
for u in users:
    user_names.append(u['screen_name'])

from collections import Counter
Counter = Counter(user_names)   
most_occur = Counter.most_common(20) 
    
print("The most active users are: \n", most_occur)
# Out:
# The most active users are:
#  [('Cos4Cloud', 11), ('kmiou', 4), ('ecology_tweets', 3), ('WeObserveEU', 2), ('hubofml', 1), ('marijnvdv78', 1), ('PlantNetProject', 1), ('Algocentric', 1), ('trendsinAI', 1), ('SciencefChange', 1), ('CitieSHealthEU', 1), ('danielbernalb', 1), ('canairq', 1), ('iSpotnature', 1), ('joanma747', 1), ('EuCitSci', 1)]

# %% [markdown]
# Extract the number of times each user interacts in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['User', 'Number of interactions'])
df_most_occur.to_csv("users_Cos4Cloud.csv")

# %% [markdown]
# Location, number of followers, number of statuses and number of likes of users

# %%
user_locations = []
user_followers = []
user_status = []
user_favorites = []
for u in users:
    user_locations.append(u['location'])

# %% [markdown]
# Most common locations of published tweets

# %%
user_locations = filter(None, user_locations)
from collections import Counter
Counter = Counter(user_locations)   
most_occur = Counter.most_common(20) 
    
print("The most common user's locations are: \n", most_occur)
# Out:
# The most common user's locations are:
#  [('Milton Keynes, UK', 4), ('everywhere and everywhen', 3), ('Germany ', 1), ('Languedoc-Roussillon, France', 1), ('Toronto, Ontario', 1), ('Barcelona', 1), ('Barcelona, Espanya', 1), ('Bogotá', 1), ('Bogotá, D.C., Colombia', 1), ('the world of wildlife', 1), ('UAB, Barcelona, Spain', 1), ('Europe', 1)]

# %% [markdown]
# Extract the number of tweets for each localization in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Localitzation', '# users active'])
df_most_occur.to_csv("localitzations_Cos4Cloud.csv")
