# %% [markdown]
# # Analysis of CATALAN  Twitter data

# %% [markdown]
# Imports

# %%
import json
import pandas as pd
import numpy as np
from math import isnan
import pymongo
from pymongo import MongoClient
import json

# %% [markdown]
# ### Read data from MongoDB database

# %%
class Scraper:
    def __init__(self):
        
        #Mongodb connection
        self.conn = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                                #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')

        #Mongodb database and repository
        db = self.conn.Stucom

        #Collections
        self.CAT =  db.CAT 
    
    def visualize_values(self): 

        # take the values
        values = self.CAT.find() 
        
        # go through the values of the object "pymongo"
        for i in values: 
            print(i)



if __name__ == "__main__":

    scraper = Scraper()
    scraper.visualize_values()

# %%
# Get the database
client = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                            
                     #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true")

db = client["CAT"]
col = db["ciencia ciutadana"]
data = pd.DataFrame(list(col.find()))

# %% [markdown]
# Visualization of the data

# %%
data
# Out:
#                           _id                      created_at  \
# 0    6037cc67ee0a6e2f74656259  Thu Feb 25 08:36:50 +0000 2021
# 1    6037cc67ee0a6e2f7465625a  Thu Feb 25 05:50:37 +0000 2021
# 2    6037cc67ee0a6e2f7465625b  Wed Feb 24 21:47:06 +0000 2021
# 3    6037cc67ee0a6e2f7465625c  Wed Feb 24 20:49:38 +0000 2021
# 4    6037cc67ee0a6e2f7465625d  Wed Feb 24 13:31:46 +0000 2021
# ..                        ...                             ...
# 439  608873033c972623d0aa691b  Tue Apr 27 14:16:01 +0000 2021
# 440  608873033c972623d0aa691d  Tue Apr 27 14:05:24 +0000 2021
# 441  608873033c972623d0aa6922  Thu Apr 22 07:32:42 +0000 2021
# 442  608873033c972623d0aa691e  Sun Apr 25 21:03:32 +0000 2021
# 443  608873033c972623d0aa6917  Tue Apr 27 14:43:27 +0000 2021
#
#                       id               id_str  \
# 0    1364856872923242498  1364856872923242498
# 1    1364815041854332929  1364815041854332929
# 2    1364693361253318659  1364693361253318659
# 3    1364678897112145928  1364678897112145928
# 4    1364568703745077254  1364568703745077254
# ..                   ...                  ...
# 439  1387047889969451009  1387047889969451009
# 440  1387045218516553731  1387045218516553731
# 441  1385134451026444288  1385134451026444288
# 442  1386425666631987201  1386425666631987201
# 443  1387054791726149634  1387054791726149634
#
#                                              full_text  truncated  \
# 0    Lectura de dijous: Ornitho i la ciència ciutad...      False
# 1    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# 2    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# 3    RT @Leni_ElenaF: Disfrutar mentre fas ciencia ...      False
# 4    RT @Ratpenats_Cat: https://t.co/phMqlUb0FL\n**...      False
# ..                                                 ...        ...
# 439  Gracias por ayudarnos en la difusión de la pla...      False
# 440  The European citizen science platform @EUCitSc...      False
# 441  RT @Ecsite: Happy #EarthDay2021! Every year, a...      False
# 442  RT @CitSciMonth: @EUCitSciProject @marziuk Lat...      False
# 443  RT @CitieSHealthEU: The European citizen scien...      False
#
#     display_text_range                                           entities  \
# 0             [0, 257]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3             [0, 118]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                 ...                                                ...
# 439           [0, 102]  {'hashtags': [{'text': 'cienciaciudadana', 'in...
# 440           [0, 127]  {'hashtags': [{'text': 'CitSci', 'indices': [1...
# 441           [0, 140]  {'hashtags': [{'text': 'EarthDay2021', 'indice...
# 442           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 443           [0, 140]  {'hashtags': [{'text': 'CitSci', 'indices': [1...
#
#                                               metadata  \
# 0    {'result_type': 'recent', 'iso_language_code':...
# 1    {'result_type': 'recent', 'iso_language_code':...
# 2    {'result_type': 'recent', 'iso_language_code':...
# 3    {'result_type': 'recent', 'iso_language_code':...
# 4    {'result_type': 'recent', 'iso_language_code':...
# ..                                                 ...
# 439  {'iso_language_code': 'es', 'result_type': 're...
# 440  {'iso_language_code': 'en', 'result_type': 're...
# 441  {'iso_language_code': 'en', 'result_type': 're...
# 442  {'iso_language_code': 'en', 'result_type': 're...
# 443  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                 source  ... favorite_count  \
# 0    <a href="https://mobile.twitter.com" rel="nofo...  ...              2
# 1    <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 2    <a href="http://twitter.com/download/android" ...  ...              0
# 3    <a href="http://twitter.com/download/android" ...  ...              0
# 4    <a href="https://www.hootsuite.com" rel="nofol...  ...              0
# ..                                                 ...  ...            ...
# 439  <a href="https://mobile.twitter.com" rel="nofo...  ...              4
# 440  <a href="https://mobile.twitter.com" rel="nofo...  ...              9
# 441  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 442  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 443  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
#
#     favorited retweeted possibly_sensitive lang  \
# 0       False     False              False   ca
# 1       False     False              False   ca
# 2       False     False              False   ca
# 3       False     False              False   ca
# 4       False     False              False   ca
# ..        ...       ...                ...  ...
# 439     False     False              False   es
# 440     False     False              False   en
# 441     False     False                NaN   en
# 442     False     False                NaN   en
# 443     False     False              False   en
#
#                                       retweeted_status  \
# 0                                                  NaN
# 1    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# 2    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# 3    {'created_at': 'Mon Feb 22 20:54:18 +0000 2021...
# 4    {'created_at': 'Tue Feb 23 11:07:44 +0000 2021...
# ..                                                 ...
# 439                                                NaN
# 440                                                NaN
# 441  {'created_at': 'Thu Apr 22 07:00:08 +0000 2021...
# 442  {'created_at': 'Wed Jan 22 22:20:25 +0000 2020...
# 443  {'created_at': 'Tue Apr 27 14:05:24 +0000 2021...
#
#                                      extended_entities     quoted_status_id  \
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3    {'media': [{'id': '1363955294989123586', 'id_s...                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 439                                                NaN  1387045218516553731
# 440  {'media': [{'id': '1387045099775750162', 'id_s...                  NaN
# 441                                                NaN                  NaN
# 442                                                NaN                  NaN
# 443                                                NaN                  NaN
#
#     quoted_status_id_str                                      quoted_status
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ..                   ...                                                ...
# 439  1387045218516553731  {'created_at': 'Tue Apr 27 14:05:24 +0000 2021...
# 440                  NaN                                                NaN
# 441                  NaN                                                NaN
# 442                  NaN                                                NaN
# 443                  NaN                                                NaN
#
# [444 rows x 32 columns]

# %% [markdown]
# ### Filter Education Tweets

# %%
edu_words = ['Lectura','#CiènciaCiutadanaiEducació','Educació', 'STEM', 'STEAM', 'escola', 'escoles', 'Escola', 
             'Escoles', 'ESO', 'institut' , 'Institut', 'Instituts', 'instituts', 'alumnes', 'estudiants',
             'universitat', 'Universitat', 'universitats', 'Universitats', 'Ensenyar', 'ensenyar', 'educar'
             'professor', 'professors', 'recursos educatius', 'guia didàctica', 'unitat didàctica', 'guia']
drop_arr = []
for i in range(0, len(data)):

    item = data.iloc[i]
    text =item['full_text']

    words = 0
    for word in edu_words:
        if word in text.split():
            words = words + 1
    if words == 0:
        drop_arr.append(i)

data = data.drop(drop_arr)  
    
data.reset_index()
data
# Out:
#                           _id                      created_at  \
# 0    6037cc67ee0a6e2f74656259  Thu Feb 25 08:36:50 +0000 2021
# 117  608872ce3c972623d0aa67ec  Mon Apr 26 14:39:10 +0000 2021
# 163  608872ce3c972623d0aa685a  Mon Apr 19 16:15:06 +0000 2021
# 174  608872ce3c972623d0aa6859  Mon Apr 19 16:15:16 +0000 2021
# 261  608872dd3c972623d0aa68a2  Mon Apr 19 22:19:17 +0000 2021
# 281  608872dd3c972623d0aa6872  Mon Apr 26 11:28:05 +0000 2021
# 312  608872dd3c972623d0aa68a5  Mon Apr 19 20:54:44 +0000 2021
# 315  608872dd3c972623d0aa68a8  Mon Apr 19 18:10:44 +0000 2021
# 344  608872e83c972623d0aa68f6  Mon Apr 19 18:10:44 +0000 2021
# 366  608872e83c972623d0aa68f0  Mon Apr 19 22:19:17 +0000 2021
# 369  608872e83c972623d0aa68c0  Mon Apr 26 11:28:05 +0000 2021
# 379  608872e83c972623d0aa68f3  Mon Apr 19 20:54:44 +0000 2021
# 418  608872fe3c972623d0aa6906  Mon Apr 26 11:28:05 +0000 2021
#
#                       id               id_str  \
# 0    1364856872923242498  1364856872923242498
# 117  1386691325853147137  1386691325853147137
# 163  1384178754478477319  1384178754478477319
# 174  1384178797713379334  1384178797713379334
# 261  1384270404382986248  1384270404382986248
# 281  1386643240762359814  1386643240762359814
# 312  1384249127924494338  1384249127924494338
# 315  1384207853804613637  1384207853804613637
# 344  1384207853804613637  1384207853804613637
# 366  1384270404382986248  1384270404382986248
# 369  1386643240762359814  1386643240762359814
# 379  1384249127924494338  1384249127924494338
# 418  1386643240762359814  1386643240762359814
#
#                                              full_text  truncated  \
# 0    Lectura de dijous: Ornitho i la ciència ciutad...      False
# 117  Després de tres cursos, acaba oficialment el #...      False
# 163  RT @celia_ginjaume: Aquesta setmana, alumnes d...      False
# 174  RT @santgervasicoop: 📣 Els alumnes de #4tESO q...      False
# 261  RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...      False
# 281  A 1r d'ESO participem en el programa @Mosquito...      False
# 312  RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...      False
# 315  👏🏻👏🏻 Cada dia més escoles participen del #Pesc...      False
# 344  👏🏻👏🏻 Cada dia més escoles participen del #Pesc...      False
# 366  RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...      False
# 369  A 1r d'ESO participem en el programa @Mosquito...      False
# 379  RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...      False
# 418  A 1r d'ESO participem en el programa @Mosquito...      False
#
#     display_text_range                                           entities  \
# 0             [0, 257]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 117           [0, 268]  {'hashtags': [{'text': 'ProjecteAtenció', 'ind...
# 163           [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 174           [0, 140]  {'hashtags': [{'text': '4tESO', 'indices': [38...
# 261           [0, 140]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 281           [0, 205]  {'hashtags': [{'text': 'CiènciaCiutadanaiEduca...
# 312           [0, 140]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 315           [0, 208]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 344           [0, 208]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 366           [0, 140]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 369           [0, 205]  {'hashtags': [{'text': 'CiènciaCiutadanaiEduca...
# 379           [0, 140]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 418           [0, 205]  {'hashtags': [{'text': 'CiènciaCiutadanaiEduca...
#
#                                               metadata  \
# 0    {'result_type': 'recent', 'iso_language_code':...
# 117  {'result_type': 'recent', 'iso_language_code':...
# 163  {'result_type': 'recent', 'iso_language_code':...
# 174  {'result_type': 'recent', 'iso_language_code':...
# 261  {'result_type': 'recent', 'iso_language_code':...
# 281  {'result_type': 'recent', 'iso_language_code':...
# 312  {'result_type': 'recent', 'iso_language_code':...
# 315  {'result_type': 'recent', 'iso_language_code':...
# 344  {'result_type': 'recent', 'iso_language_code':...
# 366  {'result_type': 'recent', 'iso_language_code':...
# 369  {'result_type': 'recent', 'iso_language_code':...
# 379  {'result_type': 'recent', 'iso_language_code':...
# 418  {'result_type': 'recent', 'iso_language_code':...
#
#                                                 source  ... favorite_count  \
# 0    <a href="https://mobile.twitter.com" rel="nofo...  ...              2
# 117  <a href="https://mobile.twitter.com" rel="nofo...  ...             16
# 163  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 174  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 261  <a href="http://twitter.com/download/android" ...  ...              0
# 281  <a href="https://mobile.twitter.com" rel="nofo...  ...              9
# 312  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 315  <a href="http://twitter.com/download/android" ...  ...              8
# 344  <a href="http://twitter.com/download/android" ...  ...              8
# 366  <a href="http://twitter.com/download/android" ...  ...              0
# 369  <a href="https://mobile.twitter.com" rel="nofo...  ...              9
# 379  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 418  <a href="https://mobile.twitter.com" rel="nofo...  ...              9
#
#     favorited retweeted possibly_sensitive lang  \
# 0       False     False              False   ca
# 117     False     False              False   ca
# 163     False     False                NaN   ca
# 174     False     False                NaN   ca
# 261     False     False                NaN   ca
# 281     False     False               True   ca
# 312     False     False                NaN   ca
# 315     False     False              False   ca
# 344     False     False              False   ca
# 366     False     False                NaN   ca
# 369     False     False               True   ca
# 379     False     False                NaN   ca
# 418     False     False               True   ca
#
#                                       retweeted_status  \
# 0                                                  NaN
# 117                                                NaN
# 163  {'created_at': 'Fri Apr 16 18:44:00 +0000 2021...
# 174  {'created_at': 'Fri Apr 16 07:27:11 +0000 2021...
# 261  {'created_at': 'Mon Apr 19 18:10:44 +0000 2021...
# 281                                                NaN
# 312  {'created_at': 'Mon Apr 19 18:10:44 +0000 2021...
# 315                                                NaN
# 344                                                NaN
# 366  {'created_at': 'Mon Apr 19 18:10:44 +0000 2021...
# 369                                                NaN
# 379  {'created_at': 'Mon Apr 19 18:10:44 +0000 2021...
# 418                                                NaN
#
#                                      extended_entities     quoted_status_id  \
# 0                                                  NaN                  NaN
# 117  {'media': [{'id': '1386691161377710082', 'id_s...                  NaN
# 163                                                NaN                  NaN
# 174                                                NaN                  NaN
# 261                                                NaN  1384193654705725451
# 281  {'media': [{'id': '1386643172835614726', 'id_s...                  NaN
# 312                                                NaN  1384193654705725451
# 315                                                NaN  1384193654705725451
# 344                                                NaN  1384193654705725451
# 366                                                NaN  1384193654705725451
# 369  {'media': [{'id': '1386643172835614726', 'id_s...                  NaN
# 379                                                NaN  1384193654705725451
# 418  {'media': [{'id': '1386643172835614726', 'id_s...                  NaN
#
#     quoted_status_id_str                                      quoted_status
# 0                    NaN                                                NaN
# 117                  NaN                                                NaN
# 163                  NaN                                                NaN
# 174                  NaN                                                NaN
# 261  1384193654705725451                                                NaN
# 281                  NaN                                                NaN
# 312  1384193654705725451                                                NaN
# 315  1384193654705725451  {'created_at': 'Mon Apr 19 17:14:19 +0000 2021...
# 344  1384193654705725451  {'created_at': 'Mon Apr 19 17:14:19 +0000 2021...
# 366  1384193654705725451                                                NaN
# 369                  NaN                                                NaN
# 379  1384193654705725451                                                NaN
# 418                  NaN                                                NaN
#
# [13 rows x 32 columns]

# %% [markdown]
# ### Quit outliers

# %% [markdown]
# Delete repeated tweets.

# %%
data = data.drop_duplicates(subset=['id'])
data = data.reset_index(drop=True)
data
# Out:
#                         _id                      created_at  \
# 0  6037cc67ee0a6e2f74656259  Thu Feb 25 08:36:50 +0000 2021
# 1  608872ce3c972623d0aa67ec  Mon Apr 26 14:39:10 +0000 2021
# 2  608872ce3c972623d0aa685a  Mon Apr 19 16:15:06 +0000 2021
# 3  608872ce3c972623d0aa6859  Mon Apr 19 16:15:16 +0000 2021
# 4  608872dd3c972623d0aa68a2  Mon Apr 19 22:19:17 +0000 2021
# 5  608872dd3c972623d0aa6872  Mon Apr 26 11:28:05 +0000 2021
# 6  608872dd3c972623d0aa68a5  Mon Apr 19 20:54:44 +0000 2021
# 7  608872dd3c972623d0aa68a8  Mon Apr 19 18:10:44 +0000 2021
#
#                     id               id_str  \
# 0  1364856872923242498  1364856872923242498
# 1  1386691325853147137  1386691325853147137
# 2  1384178754478477319  1384178754478477319
# 3  1384178797713379334  1384178797713379334
# 4  1384270404382986248  1384270404382986248
# 5  1386643240762359814  1386643240762359814
# 6  1384249127924494338  1384249127924494338
# 7  1384207853804613637  1384207853804613637
#
#                                            full_text  truncated  \
# 0  Lectura de dijous: Ornitho i la ciència ciutad...      False
# 1  Després de tres cursos, acaba oficialment el #...      False
# 2  RT @celia_ginjaume: Aquesta setmana, alumnes d...      False
# 3  RT @santgervasicoop: 📣 Els alumnes de #4tESO q...      False
# 4  RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...      False
# 5  A 1r d'ESO participem en el programa @Mosquito...      False
# 6  RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...      False
# 7  👏🏻👏🏻 Cada dia més escoles participen del #Pesc...      False
#
#   display_text_range                                           entities  \
# 0           [0, 257]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 268]  {'hashtags': [{'text': 'ProjecteAtenció', 'ind...
# 2           [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3           [0, 140]  {'hashtags': [{'text': '4tESO', 'indices': [38...
# 4           [0, 140]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 5           [0, 205]  {'hashtags': [{'text': 'CiènciaCiutadanaiEduca...
# 6           [0, 140]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 7           [0, 208]  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
#
#                                             metadata  \
# 0  {'result_type': 'recent', 'iso_language_code':...
# 1  {'result_type': 'recent', 'iso_language_code':...
# 2  {'result_type': 'recent', 'iso_language_code':...
# 3  {'result_type': 'recent', 'iso_language_code':...
# 4  {'result_type': 'recent', 'iso_language_code':...
# 5  {'result_type': 'recent', 'iso_language_code':...
# 6  {'result_type': 'recent', 'iso_language_code':...
# 7  {'result_type': 'recent', 'iso_language_code':...
#
#                                               source  ... favorite_count  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...  ...              2
# 1  <a href="https://mobile.twitter.com" rel="nofo...  ...             16
# 2  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 3  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 4  <a href="http://twitter.com/download/android" ...  ...              0
# 5  <a href="https://mobile.twitter.com" rel="nofo...  ...              9
# 6  <a href="https://mobile.twitter.com" rel="nofo...  ...              0
# 7  <a href="http://twitter.com/download/android" ...  ...              8
#
#   favorited retweeted possibly_sensitive lang  \
# 0     False     False              False   ca
# 1     False     False              False   ca
# 2     False     False                NaN   ca
# 3     False     False                NaN   ca
# 4     False     False                NaN   ca
# 5     False     False               True   ca
# 6     False     False                NaN   ca
# 7     False     False              False   ca
#
#                                     retweeted_status  \
# 0                                                NaN
# 1                                                NaN
# 2  {'created_at': 'Fri Apr 16 18:44:00 +0000 2021...
# 3  {'created_at': 'Fri Apr 16 07:27:11 +0000 2021...
# 4  {'created_at': 'Mon Apr 19 18:10:44 +0000 2021...
# 5                                                NaN
# 6  {'created_at': 'Mon Apr 19 18:10:44 +0000 2021...
# 7                                                NaN
#
#                                    extended_entities     quoted_status_id  \
# 0                                                NaN                  NaN
# 1  {'media': [{'id': '1386691161377710082', 'id_s...                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN  1384193654705725451
# 5  {'media': [{'id': '1386643172835614726', 'id_s...                  NaN
# 6                                                NaN  1384193654705725451
# 7                                                NaN  1384193654705725451
#
#   quoted_status_id_str                                      quoted_status
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4  1384193654705725451                                                NaN
# 5                  NaN                                                NaN
# 6  1384193654705725451                                                NaN
# 7  1384193654705725451  {'created_at': 'Mon Apr 19 17:14:19 +0000 2021...
#
# [8 rows x 32 columns]

# %% [markdown]
# Check that all tweets are in Catalan

# %%
data = data[data['lang'] == 'ca']

# %% [markdown]
# Delete tweets that are outside the desired range of dates

# %%
for i in range(0, len(data)):   
    item = data.iloc[i]
    
    if(int(item['created_at'][-4:])) < int(2021):
        data.drop([i],  inplace = True)

# %% [markdown]
# ### Treat the data to extract conclusions

# %% [markdown]
# Store for each tweet in the database: the text, the user, the number of retweets, the number of likes and the date.

# %%
tweets = []     # array for the text
users = []      # array for the user data
retweets = []   # array for the number of retweets
likes = []      # array for the number of likes
dates = []      # array for the dates of the tweets

for i in range(0, len(data)):
    
    item = data.iloc[i]    # store JSON object

    text =item['full_text']
    tweets.append(text.split())
    
    user = item['user']
    users.append(user)
        
    retweet = item['retweet_count']
    retweets.append(retweet)
    
    like = item['favorite_count']
    likes.append(like)
    
    date = item['created_at']
    dates.append(date)

# %%
# Fucntion to convert from the written month to the month in numbers
def convert_month(month):
    if month == 'Jan':
        month = 1
    elif month == 'Feb':
        month = 2
    elif month == 'Mar':
        month = 3
    elif month == 'Apr':
        month = 4
    elif month == 'May':
        month = 5
    elif month == 'Jun':
        month = 6
    elif month == 'Jul':
        month = 7
    elif month == 'Aug':
        month = 8
    elif month == 'Sep':
        month = 9
    elif month == 'Oct':
        month = 10
    elif month == 'Nov':
        month = 11
    elif month == 'Dec':
        month = 12
    return month

# %% [markdown]
# Search for the date of the first tweet and the last tweet published in our database.

# %%
find_date = []
for date in dates:
    year = date[-4:]
    month = date[4:7]
    month = convert_month(str(month))
    day = date[8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    find_date.append(pd.Timestamp(date))
    
max_date = max(find_date)
min_date = min(find_date)

print("The first tweet was published at ", min_date)
print("The last tweet was published at ", max_date)
# Out:
# The first tweet was published at  2021-02-25 00:00:00
# The last tweet was published at  2021-04-26 00:00:00

# %% [markdown]
# Number of tweets in the database.

# %%
print("From", min_date, " untill", max_date, len(data),"tweets have been published.")
# Out:
# From 2021-02-25 00:00:00  untill 2021-04-26 00:00:00 8 tweets have been published.

# %% [markdown]
# Most common words between the tweets.

# %%
tweets_arr = []
words_arr = []
non_interesting_words = ["A", "de", "i", "RT", "a", "que", "el", "la", "en", "ja", "Ja", "del", "al", "ciència", "Ciència", 
                         "molts", "vosaltres", "heu", "Us", "ciutadana", "els", "es", "les", "un", "través", "s'està", "El", 
                         "on", "estem", "us", "és", "I", "amb", "aquest", "per", "ciutadana,", "par…", ",", "una", "La",'ha', 
                         'han', 'Es', "-", "Si", "et", "des", "dels", "uns"]

for t in tweets:
    for i in t:
        tweets_arr.append(i)
        if (i.startswith(('#','@')) == False):
            words_arr.append(i)

for word in non_interesting_words:
    words_arr = [val for val in words_arr if val != word]

from collections import Counter 
Counter = Counter(words_arr) 
  
most_occur = Counter.most_common(100) 

print("The most common words are: \n", most_occur)
# Out:
# The most common words are:
#  [('més', 4), ('projecte', 4), ('hem', 3), ('alumnes', 3), ('👏🏻👏🏻', 3), ('Cada', 3), ('dia', 3), ('escoles', 3), ('participen', 3), ('Poc', 3), ('poc', 3), ('va', 3), ('estenent', 3), ('participem', 2), ('Lectura', 1), ('dijous:', 1), ('Ornitho', 1), ('ciutadana.', 1), ('ara', 1), ("s'inicia", 1), ('repunt', 1), ('primaveral,', 1), ('ornitho', 1), ('converteix', 1), ('plataforma', 1), ('molt', 1), ('útil', 1), ('compartir', 1), ('informació', 1), ('fauna', 1), ('temps', 1), ('real', 1), ('🦋🐦🐸🐰🦎🐠🦅', 1), ('Entra-hi', 1), ('descobreix-ho!', 1), ('https://t.co/kJM1dFqDUX', 1), ('Després', 1), ('tres', 1), ('cursos,', 1), ('acaba', 1), ('oficialment', 1), ('on,', 1), ('mà', 1), ("d'@ISGLOBALorg", 1), ('suport', 1), ('pogut', 1), ('involucrar', 1), ('2000', 1), ('sobre', 1), ('contaminació', 1), ('atmosfèrica', 1), ('atenció', 1), ('.👉Va', 1), ('fil!', 1), ('🧵(1/9)', 1), ('https://t.co/0nsoAHFfOh', 1), ('Aquesta', 1), ('setmana,', 1), ('2n', 1), ('d’ESO', 1), ('l’Institut', 1), ('Celrà,', 1), ('anat', 1), ('riu', 1), ('prendre', 1), ('mostres', 1), ('perquè', 1), ('el…', 1), ('📣', 1), ('Els', 1), ('estudien', 1), ('modalitat', 1), ('científica', 1), ('van', 1), ('realitzar', 1), ('setmana', 1), ('passada', 1), ('mostreig', 1), ('tram', 1), ('d…', 1), ('1r', 1), ("d'ESO", 1), ('programa', 1), ('sessió', 1), ('laboratori', 1), ('observat', 1), ('mosquits', 1), ('adults,', 1), ('fase', 1), ('larva', 1), ('pupa.', 1), ('https://t.co/5QJT3pf7FK', 1), ('ens', 1), ('ajuda', 1), ('conèixer', 1), ('millor', 1), ('paper', 1), ('rius', 1), ('com', 1), ('transportadors', 1)]

# %% [markdown]
# Extract the number of occurrences of each word in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Word', 'Number of occurrences'])
df_most_occur.to_csv("words_CAT_EDU.csv")

# %% [markdown]
# Most common hashtags mentioned between the tweets.

# %%
hashtags = []
for word in tweets_arr:
    if word[0] == '#':
        hashtags.append(word)

from collections import Counter
Counter = Counter(hashtags)   
most_occur = Counter.most_common(40) 

print("The most common hashtags are: \n",most_occur)
# Out:
# The most common hashtags are:
#  [('#PescadorsDePlàstic!', 3), ('#CiènciaCiut…', 2), ('#CiènciaCiutadana', 2), ('#ProjecteAtenció', 1), ('#4tESO', 1), ('#CiènciaCiutadanaiEducació', 1), ('#plàstic.', 1)]

# %% [markdown]
# Extract the number of occurrences of each hashtag in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Hashtag', 'Number of mentions'])
df_most_occur.to_csv("hashtags_CAT_EDU.csv")

# %% [markdown]
# Most common accounts mentioned between the tweets.

# %%
accounts = []
for word in tweets_arr:
    if word[0] == '@':
        accounts.append(word)

from collections import Counter
Counter = Counter(accounts)
most_occur = Counter.most_common(40) 

print("The most common mentioned accounts are: \n",most_occur)
# Out:
# The most common mentioned accounts are:
#  [('@BETA_TechCenter:', 2), ('@RecerCaixa', 1), ('@ACUPcatalunya,', 1), ('@celia_ginjaume:', 1), ('@santgervasicoop:', 1), ('@Mosquito_Alert', 1), ('@cciutadana.', 1)]

# %% [markdown]
# Extract the number of occurrences of each account in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Account', 'Number of mentions'])
df_most_occur.to_csv("accounts_CAT.csv")

# %% [markdown]
# Find the average and the maximum number of likes and retweets between the tweets.

# %%
print("The maximum number of retweets is: ", max(retweets))
print("The average number of retweets is: ", int(np.mean(retweets)))
print("\nThe maximum number of likes is: ", max(likes))
print("The average number of likes is: ", int(np.mean(likes)))
# Out:
# The maximum number of retweets is:  9
# The average number of retweets is:  3
#
# The maximum number of likes is:  16
# The average number of likes is:  4

# %% [markdown]
# Most retweeted tweets

# %%
print("The most retweeted tweets are: \n")
data.nlargest(20, ['retweet_count'])['full_text']
# Out:
# The most retweeted tweets are:
# 1    Després de tres cursos, acaba oficialment el #...
# 2    RT @celia_ginjaume: Aquesta setmana, alumnes d...
# 3    RT @santgervasicoop: 📣 Els alumnes de #4tESO q...
# 4    RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...
# 6    RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...
# 7    👏🏻👏🏻 Cada dia més escoles participen del #Pesc...
# 5    A 1r d'ESO participem en el programa @Mosquito...
# 0    Lectura de dijous: Ornitho i la ciència ciutad...
# Name: full_text, dtype: object

# %% [markdown]
# Most common source types.

# %%
src_data = data[data['extended_entities'].notna() == True]

src_type = []
for i in src_data.index:
    num_src = len(src_data.loc[i]['extended_entities']['media'])
    for n in range(0, num_src):
        src_type.append(src_data.loc[i]['extended_entities']['media'][n]['type'])

from collections import Counter 
Counter = Counter(src_type)   
most_occur = Counter.most_common(20) 

print("The most common source types are: \n", most_occur)
# Out:
# The most common source types are:
#  [('photo', 3)]

# %% [markdown]
# Extract the number of occurrences of each source type in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Source', 'Number of occurrences'])
df_most_occur.to_csv("sources_CAT_EDU.csv")

# %% [markdown]
# ## Analysis of the users interacting in Twitter about CS

# %% [markdown]
# Number of users interacting in CS.

# %%
user_ids = []
for u in users:
    if u['id'] not in user_ids:
        user_ids.append(u['id'])
print("There are ", len(user_ids), "active users.")
# Out:
# There are  7 active users.

# %% [markdown]
# Most active users between the tweets.

# %%
user_names = []
for u in users:
    user_names.append(u['screen_name'])

from collections import Counter
Counter = Counter(user_names)   
most_occur = Counter.most_common(20) 
    
print("The most active users are: \n", most_occur)
# Out:
# The most active users are:
#  [('UDivulga', 2), ('CenmaIEA', 1), ('CrecimUab', 1), ('lollop78', 1), ('iesalzina', 1), ('CarmenAngona', 1), ('BETA_TechCenter', 1)]

# %% [markdown]
# Extract the number of times each user interacts in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['User', 'Number of interactions'])
df_most_occur.to_csv("users_CAT_EDU.csv")

# %% [markdown]
# Location, number of followers, number of statuses and number of likes of users

# %%
user_locations = []
user_followers = []
user_status = []
user_favorites = []
for u in users:
    user_locations.append(u['location'])
    user_followers.append([u['screen_name'],u['followers_count']])
    user_status.append([u['screen_name'],u['statuses_count']])
    user_favorites.append([u['screen_name'],u['favourites_count']])

# %% [markdown]
# Most common locations of published tweets

# %%
user_locations = filter(None, user_locations)
from collections import Counter
Counter = Counter(user_locations)   
most_occur = Counter.most_common(20) 

# Compute the total number of active users

    
print("The most common user's locations are: \n", most_occur)
# Out:
# [('Vic', 4), ('Sant Julià de Lòria - ANDORRA', 1), ('Universitat Autònoma Barcelona', 1)]
# The most common user's locations are:
#  [('Vic', 4), ('Sant Julià de Lòria - ANDORRA', 1), ('Universitat Autònoma Barcelona', 1)]

# %% [markdown]
# Extract the number of tweets for each localization in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Localitzation', '# users active'])
df_most_occur.to_csv("localitzations_CAT_EDU.csv")

# %%
print("The users with more followers are: \n", sorted(user_followers,key = lambda x: x[1])[::-1])
# Out:
# The users with more followers are:
#  [['UDivulga', 4107], ['UDivulga', 4107], ['BETA_TechCenter', 2149], ['CrecimUab', 1519], ['CenmaIEA', 1227], ['iesalzina', 287], ['lollop78', 260], ['CarmenAngona', 89]]

# %%
print("The users with more statuses are: \n", sorted(user_status,key = lambda x: x[1])[::-1])
# Out:
# The users with more statuses are:
#  [['UDivulga', 31905], ['UDivulga', 31905], ['BETA_TechCenter', 2182], ['iesalzina', 1535], ['CenmaIEA', 1309], ['CrecimUab', 1021], ['CarmenAngona', 665], ['lollop78', 218]]

# %%
print("The users with more likes are: \n", sorted(user_favorites,key = lambda x: x[1])[::-1])
# Out:
# The users with more likes are:
#  [['UDivulga', 49577], ['UDivulga', 49577], ['lollop78', 3166], ['BETA_TechCenter', 3013], ['CarmenAngona', 2293], ['iesalzina', 1013], ['CrecimUab', 669], ['CenmaIEA', 645]]

# %% [markdown]
# ### Check data before and after COVID-19

# %% [markdown]
# Division of the database in before COVID-19 and after COVID-19

# %%
from datetime import datetime
before_covid = pd.DataFrame()
after_covid = pd.DataFrame()
for i in range(0, len(data)):
    item = data.iloc[i]

    year = item['created_at'][-4:]
    month = item['created_at'][4:7]
    month = convert_month(str(month))
    day = item['created_at'][8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    date =  pd.Timestamp(date)

    if(date < pd.Timestamp('2020-3-14')):
        before_covid.append(item)
    else:
        after_covid = after_covid.append(item)

after_covid
# Out:
#                         _id contributors coordinates  \
# 0  6037cc67ee0a6e2f74656259         None        None
# 1  608872ce3c972623d0aa67ec         None        None
# 2  608872ce3c972623d0aa685a         None        None
# 3  608872ce3c972623d0aa6859         None        None
# 4  608872dd3c972623d0aa68a2         None        None
# 5  608872dd3c972623d0aa6872         None        None
# 6  608872dd3c972623d0aa68a5         None        None
# 7  608872dd3c972623d0aa68a8         None        None
#
#                        created_at display_text_range  \
# 0  Thu Feb 25 08:36:50 +0000 2021           [0, 257]
# 1  Mon Apr 26 14:39:10 +0000 2021           [0, 268]
# 2  Mon Apr 19 16:15:06 +0000 2021           [0, 139]
# 3  Mon Apr 19 16:15:16 +0000 2021           [0, 140]
# 4  Mon Apr 19 22:19:17 +0000 2021           [0, 140]
# 5  Mon Apr 26 11:28:05 +0000 2021           [0, 205]
# 6  Mon Apr 19 20:54:44 +0000 2021           [0, 140]
# 7  Mon Apr 19 18:10:44 +0000 2021           [0, 208]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [{'text': 'ProjecteAtenció', 'ind...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [{'text': '4tESO', 'indices': [38...
# 4  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 5  {'hashtags': [{'text': 'CiènciaCiutadanaiEduca...
# 6  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
# 7  {'hashtags': [{'text': 'PescadorsDePlàstic', '...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN             2.0
# 1  {'media': [{'id': '1386691161377710082', 'id_s...            16.0
# 2                                                NaN             0.0
# 3                                                NaN             0.0
# 4                                                NaN             0.0
# 5  {'media': [{'id': '1386643172835614726', 'id_s...             9.0
# 6                                                NaN             0.0
# 7                                                NaN             8.0
#
#    favorited                                          full_text  ...  \
# 0        0.0  Lectura de dijous: Ornitho i la ciència ciutad...  ...
# 1        0.0  Després de tres cursos, acaba oficialment el #...  ...
# 2        0.0  RT @celia_ginjaume: Aquesta setmana, alumnes d...  ...
# 3        0.0  RT @santgervasicoop: 📣 Els alumnes de #4tESO q...  ...
# 4        0.0  RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...  ...
# 5        0.0  A 1r d'ESO participem en el programa @Mosquito...  ...
# 6        0.0  RT @BETA_TechCenter: 👏🏻👏🏻 Cada dia més escoles...  ...
# 7        0.0  👏🏻👏🏻 Cada dia més escoles participen del #Pesc...  ...
#
#   possibly_sensitive                                      quoted_status  \
# 0                0.0                                                NaN
# 1                0.0                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# 5                1.0                                                NaN
# 6                NaN                                                NaN
# 7                0.0  {'created_at': 'Mon Apr 19 17:14:19 +0000 2021...
#
#       quoted_status_id quoted_status_id_str retweet_count retweeted  \
# 0                  NaN                  NaN           0.0       0.0
# 1                  NaN                  NaN           9.0       0.0
# 2                  NaN                  NaN           7.0       0.0
# 3                  NaN                  NaN           4.0       0.0
# 4  1384193654705725451  1384193654705725451           2.0       0.0
# 5                  NaN                  NaN           1.0       0.0
# 6  1384193654705725451  1384193654705725451           2.0       0.0
# 7  1384193654705725451  1384193654705725451           2.0       0.0
#
#                                     retweeted_status  \
# 0                                                NaN
# 1                                                NaN
# 2  {'created_at': 'Fri Apr 16 18:44:00 +0000 2021...
# 3  {'created_at': 'Fri Apr 16 07:27:11 +0000 2021...
# 4  {'created_at': 'Mon Apr 19 18:10:44 +0000 2021...
# 5                                                NaN
# 6  {'created_at': 'Mon Apr 19 18:10:44 +0000 2021...
# 7                                                NaN
#
#                                               source  truncated  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 1  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 2  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 3  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 4  <a href="http://twitter.com/download/android" ...        0.0
# 5  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 6  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 7  <a href="http://twitter.com/download/android" ...        0.0
#
#                                                 user
# 0  {'id': 2829700163, 'id_str': '2829700163', 'na...
# 1  {'id': '722730352683401216', 'id_str': '722730...
# 2  {'id': 394945064, 'id_str': '394945064', 'name...
# 3  {'id': 394945064, 'id_str': '394945064', 'name...
# 4  {'id': 531063980, 'id_str': '531063980', 'name...
# 5  {'id': 379245746, 'id_str': '379245746', 'name...
# 6  {'id': '1098628426406203393', 'id_str': '10986...
# 7  {'id': 3084094763, 'id_str': '3084094763', 'na...
#
# [8 rows x 32 columns]
