# %% [markdown]
# # Analysis of RíosCiudadanos Event  Twitter data

# %% [markdown]
# Imports

# %%
import json
import pandas as pd
import numpy as np
from math import isnan
import pymongo
from pymongo import MongoClient
import json

# %% [markdown]
# ### Read data from MongoDB database

# %%
class Scraper:
    def __init__(self):
        
        #Mongodb connection
        self.conn = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                                #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')

        #Mongodb database and repository
        db = self.conn.Stucom

        #Collections
        self.CAT =  db.CAT 
    
    def visualize_values(self): 

        # take the values
        values = self.CAT.find() 
        
        # go through the values of the object "pymongo"
        for i in values: 
            print(i)



if __name__ == "__main__":

    scraper = Scraper()
    scraper.visualize_values()

# %%
# Get the database
client = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                            
                     #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true")

db = client["Events"]
col = db["RíosCiudadanos"]
data = pd.DataFrame(list(col.find()))

# %% [markdown]
# Visualization of the data

# %%
data
# Out:
#                          _id                      created_at  \
# 0   606dc6324e60b42720328f19  Wed Apr 07 12:45:05 +0000 2021
# 1   606dc6324e60b42720328f1a  Wed Apr 07 12:44:59 +0000 2021
# 2   606dc6324e60b42720328f1b  Wed Apr 07 11:22:01 +0000 2021
# 3   606dc6324e60b42720328f1c  Wed Apr 07 11:16:55 +0000 2021
# 4   606dc6324e60b42720328f1d  Wed Apr 07 09:50:59 +0000 2021
# 5   606dc6324e60b42720328f1e  Wed Apr 07 09:49:14 +0000 2021
# 6   606dc6324e60b42720328f1f  Wed Apr 07 09:18:22 +0000 2021
# 7   606dc6324e60b42720328f20  Wed Apr 07 09:17:59 +0000 2021
# 8   606dc6324e60b42720328f21  Wed Apr 07 09:15:28 +0000 2021
# 9   606dc6324e60b42720328f22  Mon Apr 05 08:52:05 +0000 2021
# 10  606dc6324e60b42720328f23  Mon Apr 05 06:35:53 +0000 2021
# 11  606dc6324e60b42720328f24  Sun Apr 04 16:56:27 +0000 2021
#
#                      id               id_str  \
# 0   1379777246832033794  1379777246832033794
# 1   1379777220755984385  1379777220755984385
# 2   1379756343498792962  1379756343498792962
# 3   1379755058447978500  1379755058447978500
# 4   1379733432876593153  1379733432876593153
# 5   1379732993573597188  1379732993573597188
# 6   1379725224518770696  1379725224518770696
# 7   1379725127504515075  1379725127504515075
# 8   1379724494332387328  1379724494332387328
# 9   1378993836639334402  1378993836639334402
# 10  1378959558454960130  1378959558454960130
# 11  1378753340436312067  1378753340436312067
#
#                                             full_text  truncated  \
# 0   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 1   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 2   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 3   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 4   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 5   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 6   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 7   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 8   🤔¿Conoces el proyecto #RíosCiudadanos? \n👨‍🔬 E...      False
# 9   RT @riosciudadanos: La primavera va llegando a...      False
# 10  RT @riosciudadanos: La primavera va llegando a...      False
# 11  La primavera va llegando a nuestros #rios y pr...      False
#
#    display_text_range                                           entities  \
# 0            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 1            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 2            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 3            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 4            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 5            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 6            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 7            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 8            [0, 230]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 9            [0, 140]  {'hashtags': [{'text': 'rios', 'indices': [56,...
# 10           [0, 140]  {'hashtags': [{'text': 'rios', 'indices': [56,...
# 11           [0, 273]  {'hashtags': [{'text': 'rios', 'indices': [36,...
#
#                                              metadata  \
# 0   {'iso_language_code': 'es', 'result_type': 're...
# 1   {'iso_language_code': 'es', 'result_type': 're...
# 2   {'iso_language_code': 'es', 'result_type': 're...
# 3   {'iso_language_code': 'es', 'result_type': 're...
# 4   {'iso_language_code': 'es', 'result_type': 're...
# 5   {'iso_language_code': 'es', 'result_type': 're...
# 6   {'iso_language_code': 'es', 'result_type': 're...
# 7   {'iso_language_code': 'es', 'result_type': 're...
# 8   {'iso_language_code': 'es', 'result_type': 're...
# 9   {'iso_language_code': 'es', 'result_type': 're...
# 10  {'iso_language_code': 'es', 'result_type': 're...
# 11  {'iso_language_code': 'es', 'result_type': 're...
#
#                                                source  ... contributors  \
# 0   <a href="https://github.com/TwidereProject" re...  ...         None
# 1   <a href="https://github.com/TwidereProject" re...  ...         None
# 2   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 3   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 4   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 5   <a href="http://twitter.com/download/android" ...  ...         None
# 6   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 7   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 8   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 9   <a href="http://twitter.com/download/android" ...  ...         None
# 10  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 11  <a href="https://ifttt.com" rel="nofollow">IFT...  ...         None
#
#                                      retweeted_status is_quote_status  \
# 0   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 1   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 2   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 3   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 4   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 5   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 6   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 7   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 8                                                 NaN           False
# 9   {'created_at': 'Sun Apr 04 16:56:27 +0000 2021...           False
# 10  {'created_at': 'Sun Apr 04 16:56:27 +0000 2021...           False
# 11                                                NaN           False
#
#    retweet_count favorite_count favorited retweeted lang possibly_sensitive  \
# 0              8              0     False     False   es                NaN
# 1              8              0     False     False   es                NaN
# 2              8              0     False     False   es                NaN
# 3              8              0     False     False   es                NaN
# 4              8              0     False     False   es                NaN
# 5              8              0     False     False   es                NaN
# 6              8              0     False     False   es                NaN
# 7              8              0     False     False   es                NaN
# 8              8             10     False     False   es              False
# 9              2              0     False     False   es                NaN
# 10             2              0     False     False   es                NaN
# 11             2              9     False     False   es              False
#
#                                     extended_entities
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'media': [{'id': '1378753338980892675', 'id_s...
#
# [12 rows x 29 columns]

# %% [markdown]
# ### Quit outliers

# %% [markdown]
# Delete repeated tweets.

# %%
data = data.drop_duplicates(subset=['id'])
data = data.reset_index(drop=True)
data
# Out:
#                          _id                      created_at  \
# 0   606dc6324e60b42720328f19  Wed Apr 07 12:45:05 +0000 2021
# 1   606dc6324e60b42720328f1a  Wed Apr 07 12:44:59 +0000 2021
# 2   606dc6324e60b42720328f1b  Wed Apr 07 11:22:01 +0000 2021
# 3   606dc6324e60b42720328f1c  Wed Apr 07 11:16:55 +0000 2021
# 4   606dc6324e60b42720328f1d  Wed Apr 07 09:50:59 +0000 2021
# 5   606dc6324e60b42720328f1e  Wed Apr 07 09:49:14 +0000 2021
# 6   606dc6324e60b42720328f1f  Wed Apr 07 09:18:22 +0000 2021
# 7   606dc6324e60b42720328f20  Wed Apr 07 09:17:59 +0000 2021
# 8   606dc6324e60b42720328f21  Wed Apr 07 09:15:28 +0000 2021
# 9   606dc6324e60b42720328f22  Mon Apr 05 08:52:05 +0000 2021
# 10  606dc6324e60b42720328f23  Mon Apr 05 06:35:53 +0000 2021
# 11  606dc6324e60b42720328f24  Sun Apr 04 16:56:27 +0000 2021
#
#                      id               id_str  \
# 0   1379777246832033794  1379777246832033794
# 1   1379777220755984385  1379777220755984385
# 2   1379756343498792962  1379756343498792962
# 3   1379755058447978500  1379755058447978500
# 4   1379733432876593153  1379733432876593153
# 5   1379732993573597188  1379732993573597188
# 6   1379725224518770696  1379725224518770696
# 7   1379725127504515075  1379725127504515075
# 8   1379724494332387328  1379724494332387328
# 9   1378993836639334402  1378993836639334402
# 10  1378959558454960130  1378959558454960130
# 11  1378753340436312067  1378753340436312067
#
#                                             full_text  truncated  \
# 0   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 1   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 2   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 3   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 4   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 5   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 6   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 7   RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...      False
# 8   🤔¿Conoces el proyecto #RíosCiudadanos? \n👨‍🔬 E...      False
# 9   RT @riosciudadanos: La primavera va llegando a...      False
# 10  RT @riosciudadanos: La primavera va llegando a...      False
# 11  La primavera va llegando a nuestros #rios y pr...      False
#
#    display_text_range                                           entities  \
# 0            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 1            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 2            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 3            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 4            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 5            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 6            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 7            [0, 140]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 8            [0, 230]  {'hashtags': [{'text': 'RíosCiudadanos', 'indi...
# 9            [0, 140]  {'hashtags': [{'text': 'rios', 'indices': [56,...
# 10           [0, 140]  {'hashtags': [{'text': 'rios', 'indices': [56,...
# 11           [0, 273]  {'hashtags': [{'text': 'rios', 'indices': [36,...
#
#                                              metadata  \
# 0   {'iso_language_code': 'es', 'result_type': 're...
# 1   {'iso_language_code': 'es', 'result_type': 're...
# 2   {'iso_language_code': 'es', 'result_type': 're...
# 3   {'iso_language_code': 'es', 'result_type': 're...
# 4   {'iso_language_code': 'es', 'result_type': 're...
# 5   {'iso_language_code': 'es', 'result_type': 're...
# 6   {'iso_language_code': 'es', 'result_type': 're...
# 7   {'iso_language_code': 'es', 'result_type': 're...
# 8   {'iso_language_code': 'es', 'result_type': 're...
# 9   {'iso_language_code': 'es', 'result_type': 're...
# 10  {'iso_language_code': 'es', 'result_type': 're...
# 11  {'iso_language_code': 'es', 'result_type': 're...
#
#                                                source  ... contributors  \
# 0   <a href="https://github.com/TwidereProject" re...  ...         None
# 1   <a href="https://github.com/TwidereProject" re...  ...         None
# 2   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 3   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 4   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 5   <a href="http://twitter.com/download/android" ...  ...         None
# 6   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 7   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 8   <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 9   <a href="http://twitter.com/download/android" ...  ...         None
# 10  <a href="https://mobile.twitter.com" rel="nofo...  ...         None
# 11  <a href="https://ifttt.com" rel="nofollow">IFT...  ...         None
#
#                                      retweeted_status is_quote_status  \
# 0   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 1   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 2   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 3   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 4   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 5   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 6   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 7   {'created_at': 'Wed Apr 07 09:15:28 +0000 2021...           False
# 8                                                 NaN           False
# 9   {'created_at': 'Sun Apr 04 16:56:27 +0000 2021...           False
# 10  {'created_at': 'Sun Apr 04 16:56:27 +0000 2021...           False
# 11                                                NaN           False
#
#    retweet_count favorite_count favorited retweeted lang possibly_sensitive  \
# 0              8              0     False     False   es                NaN
# 1              8              0     False     False   es                NaN
# 2              8              0     False     False   es                NaN
# 3              8              0     False     False   es                NaN
# 4              8              0     False     False   es                NaN
# 5              8              0     False     False   es                NaN
# 6              8              0     False     False   es                NaN
# 7              8              0     False     False   es                NaN
# 8              8             10     False     False   es              False
# 9              2              0     False     False   es                NaN
# 10             2              0     False     False   es                NaN
# 11             2              9     False     False   es              False
#
#                                     extended_entities
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'media': [{'id': '1378753338980892675', 'id_s...
#
# [12 rows x 29 columns]

# %% [markdown]
# Check that all tweets are in Spanish

# %%
data = data[data['lang'] == 'es']

# %% [markdown]
# Delete tweets that are outside the desired range of dates

# %%
for i in range(0, len(data)):   
    item = data.iloc[i]
    
    if(int(item['created_at'][-4:])) < int(2021):
        data.drop([i],  inplace = True)

# %% [markdown]
# ### Treat the data to extract conclusions

# %% [markdown]
# Store for each tweet in the database: the text, the user, the number of retweets, the number of likes and the date.

# %%
tweets = []     # array for the text
users = []      # array for the user data
retweets = []   # array for the number of retweets
likes = []      # array for the number of likes
dates = []      # array for the dates of the tweets

for i in range(0, len(data)):
    
    item = data.iloc[i]    # store JSON object

    text =item['full_text']
    tweets.append(text.split())
    
    user = item['user']
    users.append(user)
        
    retweet = item['retweet_count']
    retweets.append(retweet)
    
    like = item['favorite_count']
    likes.append(like)
    
    date = item['created_at']
    dates.append(date)

# %%
# Fucntion to convert from the written month to the month in numbers
def convert_month(month):
    if month == 'Jan':
        month = 1
    elif month == 'Feb':
        month = 2
    elif month == 'Mar':
        month = 3
    elif month == 'Apr':
        month = 4
    elif month == 'May':
        month = 5
    elif month == 'Jun':
        month = 6
    elif month == 'Jul':
        month = 7
    elif month == 'Aug':
        month = 8
    elif month == 'Sep':
        month = 9
    elif month == 'Oct':
        month = 10
    elif month == 'Nov':
        month = 11
    elif month == 'Dec':
        month = 12
    return month

# %% [markdown]
# Search for the date of the first tweet and the last tweet published in our database.

# %%
find_date = []
for date in dates:
    year = date[-4:]
    month = date[4:7]
    month = convert_month(str(month))
    day = date[8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    find_date.append(pd.Timestamp(date))
    
max_date = max(find_date)
min_date = min(find_date)

print("The first tweet was published at ", min_date)
print("The last tweet was published at ", max_date)
# Out:
# The first tweet was published at  2021-04-04 00:00:00
# The last tweet was published at  2021-04-07 00:00:00

# %% [markdown]
# Number of tweets in the database.

# %%
print("From", min_date, " untill", max_date, len(data),"tweets have been published.")
# Out:
# From 2021-04-04 00:00:00  untill 2021-04-07 00:00:00 12 tweets have been published.

# %% [markdown]
# Most common words between the tweets.

# %%
tweets_arr = []
words_arr = []
non_interesting_words = ['de', "y", "RT", "a", "que", "el", "la", "en", "ya", "Ya", "del", "al", "ciencia", "Ciencia", 
                         "muchoss", "vosotros", "es", "tu", "ciudadana", "los", "las", "una", "un", "para", "con", "La",
                        "por", "sobre", "más", "Ciudadana", "#cienciaciudadana", "El", "#ciencia", "se", "este", "su", "o",
                        "En", "ciudadana", "ciudadana,", "te", "esta", "nos", "son", "sus", "Te", "Y", "Los", "Un", "lo", "e",
                        "DE", "qué", "ha"]

for t in tweets:
    for i in t:
        tweets_arr.append(i)
        if (i.startswith(('#','@')) == False):
            words_arr.append(i)

for word in non_interesting_words:
    words_arr = [val for val in words_arr if val != word]

from collections import Counter 
Counter = Counter(words_arr) 
  
most_occur = Counter.most_common(100) 

print("The most common words are: \n", most_occur)
# Out:
# The most common words are:
#  [('proyecto', 10), ('🤔¿Conoces', 9), ('👨\u200d🔬', 9), ('investigador', 9), ('estuvo', 9), ('plató', 9), ('c…', 8), ('primavera', 3), ('va', 3), ('llegando', 3), ('nuestros', 3), ('pronto', 3), ('empezaremos', 3), ('muestreo.', 3), ('Esperamos', 3), ('llegar', 3), ('todos', 3), ('rinco…', 2), ('comentando', 1), ('experimentando', 1), ('directo.', 1), ('https://t.co/8kteaYEZAP', 1), ('rincones', 1), ('Foto', 1), ('Río', 1), ('Matarraña,', 1), ('Teruel.', 1), ('https://t.co/Dr33ZnDeS1', 1), ('https://t.co/Jx69wSvFYG', 1)]

# %% [markdown]
# Extract the number of occurrences of each word in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Word', 'Number of occurrences'])
df_most_occur.to_csv("words_RíosCiudadanos.csv")

# %% [markdown]
# Most common hashtags mentioned between the tweets.

# %%
hashtags = []
for word in tweets_arr:
    if word[0] == '#':
        hashtags.append(word)

from collections import Counter
Counter = Counter(hashtags)   
most_occur = Counter.most_common(40) 

print("The most common hashtags are: \n",most_occur)
# Out:
# The most common hashtags are:
#  [('#RíosCiudadanos?', 9), ('#rios', 3), ('#campaña', 3), ('#Aragón', 1), ('#CienciaCiudadana.', 1), ('#RiosCiudadanos', 1), ('#valderrobres', 1)]

# %% [markdown]
# Extract the number of occurrences of each hashtag in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Hashtag', 'Number of mentions'])
df_most_occur.to_csv("hashtags_RíosCiudadanos.csv")

# %% [markdown]
# Most common accounts mentioned between the tweets.

# %%
accounts = []
for word in tweets_arr:
    if word[0] == '@':
        accounts.append(word)

from collections import Counter
Counter = Counter(accounts)
most_occur = Counter.most_common(40) 

print("The most common mentioned accounts are: \n",most_occur)
# Out:
# The most common mentioned accounts are:
#  [('@msevilla00', 9), ('@EstaEsMiTierra_', 9), ('@aragontv', 9), ('@IPE_CSIC:', 8), ('@riosciudadanos:', 2), ('@AragonCsic', 1), ('@riosciudadanos', 1), ('@CSICdivulga', 1), ('@ch_ebro', 1), ('@somosmatarranya', 1)]

# %% [markdown]
# Extract the number of occurrences of each account in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Account', 'Number of mentions'])
df_most_occur.to_csv("accounts_RíosCiudadanos.csv")

# %% [markdown]
# Find the average and the maximum number of likes and retweets between the tweets.

# %%
print("The maximum number of retweets is: ", max(retweets))
print("The average number of retweets is: ", int(np.mean(retweets)))
print("\nThe maximum number of likes is: ", max(likes))
print("The average number of likes is: ", int(np.mean(likes)))
# Out:
# The maximum number of retweets is:  8
# The average number of retweets is:  6
#
# The maximum number of likes is:  10
# The average number of likes is:  1

# %% [markdown]
# Most retweeted tweets

# %%
print("The most retweeted tweets are: \n")
data.nlargest(20, ['retweet_count'])['full_text']
# Out:
# The most retweeted tweets are:
# 0     RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...
# 1     RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...
# 2     RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...
# 3     RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...
# 4     RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...
# 5     RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...
# 6     RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...
# 7     RT @IPE_CSIC: 🤔¿Conoces el proyecto #RíosCiuda...
# 8     🤔¿Conoces el proyecto #RíosCiudadanos? \n👨‍🔬 E...
# 9     RT @riosciudadanos: La primavera va llegando a...
# 10    RT @riosciudadanos: La primavera va llegando a...
# 11    La primavera va llegando a nuestros #rios y pr...
# Name: full_text, dtype: object

# %% [markdown]
# Most common source types.

# %%
src_data = data[data['extended_entities'].notna() == True]

src_type = []
for i in src_data.index:
    num_src = len(src_data.loc[i]['extended_entities']['media'])
    for n in range(0, num_src):
        src_type.append(src_data.loc[i]['extended_entities']['media'][n]['type'])

from collections import Counter 
Counter = Counter(src_type)   
most_occur = Counter.most_common(20) 

print("The most common source types are: \n", most_occur)
# Out:
# The most common source types are:
#  [('photo', 1)]

# %% [markdown]
# Extract the number of occurrences of each source type in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Source', 'Number of occurrences'])
df_most_occur.to_csv("sources_RíosCiudadanos.csv")

# %% [markdown]
# ## Analysis of the users interacting in Twitter about CS

# %% [markdown]
# Number of users interacting in CS.

# %%
user_ids = []
for u in users:
    if u['id'] not in user_ids:
        user_ids.append(u['id'])
print("There are ", len(user_ids), "active users.")
# Out:
# There are  10 active users.

# %% [markdown]
# Most active users between the tweets.

# %%
user_names = []
for u in users:
    user_names.append(u['screen_name'])

from collections import Counter
Counter = Counter(user_names)   
most_occur = Counter.most_common(20) 
    
print("The most active users are: \n", most_occur)
# Out:
# The most active users are:
#  [('riosciudadanos', 2), ('IPE_CSIC', 2), ('msevilla00', 1), ('bolivur', 1), ('IberMag', 1), ('EstaEsMiTierra_', 1), ('AragonCsic', 1), ('CSICdivulga', 1), ('apetijo', 1), ('GeografosAragon', 1)]

# %% [markdown]
# Extract the number of times each user interacts in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['User', 'Number of interactions'])
df_most_occur.to_csv("users_RíosCiudadanos.csv")

# %% [markdown]
# Location, number of followers, number of statuses and number of likes of users

# %%
user_locations = []
user_followers = []
user_status = []
user_favorites = []
for u in users:
    user_locations.append(u['location'])

# %% [markdown]
# Most common locations of published tweets

# %%
user_locations = filter(None, user_locations)
from collections import Counter
Counter = Counter(user_locations)   
most_occur = Counter.most_common(10) 
    
print("The most common user's locations are: \n", most_occur)
# Out:
# The most common user's locations are:
#  [('Aragón', 3), ('Zaragoza, Spain', 1), ('Zaragoza', 1), ('Zaragoza, Aragón', 1)]

# %% [markdown]
# Extract the number of tweets for each localization in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Localitzation', '# users active'])
df_most_occur.to_csv("localitzations_RíosCiudadanos.csv")
