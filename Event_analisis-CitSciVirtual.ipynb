# %% [markdown]
# # Analysis of CitSciVirtual Event  Twitter data

# %% [markdown]
# Imports

# %%
import json
import pandas as pd
import numpy as np
from math import isnan
import pymongo
from pymongo import MongoClient
import json

# %% [markdown]
# ### Read data from MongoDB database

# %%
class Scraper:
    def __init__(self):
        
        #Mongodb connection
        self.conn = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                                #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')

        #Mongodb database and repository
        db = self.conn.Stucom

        #Collections
        self.CAT =  db.CAT 
    
    def visualize_values(self): 

        # take the values
        values = self.CAT.find() 
        
        # go through the values of the object "pymongo"
        for i in values: 
            print(i)



if __name__ == "__main__":

    scraper = Scraper()
    scraper.visualize_values()

# %%
# Get the database
client = MongoClient('mongodb://coralpc:c0r4l3@cluster0-shard-00-00.f3ikj.mongodb.net:27017,cluster0-shard-00-01.f3ikj.mongodb.net:27017,cluster0-shard-00-02.f3ikj.mongodb.net:27017/CAT?ssl=true&replicaSet=atlas-1394pv-shard-0&authSource=admin&retryWrites=true&w=majority')
                            
                     #mongodb+srv://coralpc:c0r4l3@cluster0.f3ikj.mongodb.net/test?authSource=admin&replicaSet=atlas-1394pv-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true")

db = client["Events"]
col = db["CitSciVirtual"]
data = pd.DataFrame(list(col.find()))

# %% [markdown]
# Visualization of the data

# %%
data
# Out:
#                          _id                      created_at  \
# 0   609928b428f1bb0e684e118d  Mon May 10 07:12:21 +0000 2021
# 1   609928b428f1bb0e684e1188  Mon May 10 10:56:38 +0000 2021
# 2   609928b428f1bb0e684e11aa  Wed May 05 16:13:38 +0000 2021
# 3   609928b428f1bb0e684e119b  Thu May 06 08:42:19 +0000 2021
# 4   609928b428f1bb0e684e1192  Fri May 07 15:15:24 +0000 2021
# ..                       ...                             ...
# 92  609928b428f1bb0e684e11df  Mon May 03 15:02:55 +0000 2021
# 93  609928b428f1bb0e684e11b8  Tue May 04 14:55:40 +0000 2021
# 94  609928b428f1bb0e684e11ba  Tue May 04 14:11:23 +0000 2021
# 95  609928b428f1bb0e684e11d5  Mon May 03 16:35:06 +0000 2021
# 96  609928b428f1bb0e684e11e8  Sun May 02 18:34:01 +0000 2021
#
#                      id               id_str  \
# 0   1391652311345233923  1391652311345233923
# 1   1391708753741897728  1391708753741897728
# 2   1389976593066602498  1389976593066602498
# 3   1390225400777818112  1390225400777818112
# 4   1390686712964255744  1390686712964255744
# ..                  ...                  ...
# 92  1389234018693099521  1389234018693099521
# 93  1389594580262211584  1389594580262211584
# 94  1389583439687467009  1389583439687467009
# 95  1389257218311147536  1389257218311147536
# 96  1388924755890290700  1388924755890290700
#
#                                             full_text  truncated  \
# 0   RT @cstrackproject: The second of three @cstra...      False
# 1   RT @cstrackproject: The second of three @cstra...      False
# 2   Our first workshop at @CitSciVirtual !! 🤩 http...      False
# 3   RT @Ideas_4_Change: Yesterday, @LuciaErrandone...      False
# 4   About to host a bit of an experiment at @CitSc...      False
# ..                                                ...        ...
# 92  RT @CharmelMenzel: Join #CitSciVirtual session...      False
# 93  RT @Cos4Cloud: Are you attending the #CitSciVi...      False
# 94  Coming soon #CitSciVirtual https://t.co/FXiOOg...      False
# 95  RT @FieldKitOrg: Catch a few of our friends an...      False
# 96  Save the date! We'll be presenting at #CitSciV...      False
#
#    display_text_range                                           entities  \
# 0            [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1            [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [0, 41]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3            [0, 144]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 4            [0, 252]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# ..                ...                                                ...
# 92           [0, 144]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 93           [0, 139]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 94            [0, 26]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 95           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 96           [0, 236]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'en', 'result_type': 're...
# 4   {'iso_language_code': 'en', 'result_type': 're...
# ..                                                ...
# 92  {'iso_language_code': 'en', 'result_type': 're...
# 93  {'iso_language_code': 'en', 'result_type': 're...
# 94  {'iso_language_code': 'en', 'result_type': 're...
# 95  {'iso_language_code': 'en', 'result_type': 're...
# 96  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                source  ... retweet_count  \
# 0   <a href="https://opensci.io" rel="nofollow">Op...  ...             4
# 1   <a href="https://mobile.twitter.com" rel="nofo...  ...             4
# 2   <a href="https://mobile.twitter.com" rel="nofo...  ...             1
# 3   <a href="https://mobile.twitter.com" rel="nofo...  ...             5
# 4   <a href="https://mobile.twitter.com" rel="nofo...  ...             0
# ..                                                ...  ...           ...
# 92  <a href="https://mobile.twitter.com" rel="nofo...  ...             4
# 93  <a href="https://mobile.twitter.com" rel="nofo...  ...             4
# 94  <a href="https://mobile.twitter.com" rel="nofo...  ...             0
# 95  <a href="https://mobile.twitter.com" rel="nofo...  ...             6
# 96  <a href="https://buffer.com" rel="nofollow">Bu...  ...             0
#
#    favorite_count favorited retweeted lang     quoted_status_id  \
# 0               0     False     False   en                  NaN
# 1               0     False     False   en                  NaN
# 2               7     False     False   en  1389976102723100679
# 3               0     False     False   en                  NaN
# 4               1     False     False   en                  NaN
# ..            ...       ...       ...  ...                  ...
# 92              0     False     False   en                  NaN
# 93              0     False     False   en                  NaN
# 94              3     False     False   en  1389539803700547589
# 95              0     False     False   en                  NaN
# 96              3     False     False   en                  NaN
#
#    quoted_status_id_str                                      quoted_status  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2   1389976102723100679  {'created_at': 'Wed May 05 16:11:42 +0000 2021...
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ..                  ...                                                ...
# 92                  NaN                                                NaN
# 93                  NaN                                                NaN
# 94  1389539803700547589  {'created_at': 'Tue May 04 11:18:00 +0000 2021...
# 95                  NaN                                                NaN
# 96                  NaN                                                NaN
#
#    possibly_sensitive extended_entities
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2               False               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ..                ...               ...
# 92                NaN               NaN
# 93                NaN               NaN
# 94              False               NaN
# 95                NaN               NaN
# 96              False               NaN
#
# [97 rows x 32 columns]

# %% [markdown]
# ### Quit outliers

# %% [markdown]
# Delete repeated tweets.

# %%
data = data.drop_duplicates(subset=['id'])
data = data.reset_index(drop=True)
data
# Out:
#                          _id                      created_at  \
# 0   609928b428f1bb0e684e118d  Mon May 10 07:12:21 +0000 2021
# 1   609928b428f1bb0e684e1188  Mon May 10 10:56:38 +0000 2021
# 2   609928b428f1bb0e684e11aa  Wed May 05 16:13:38 +0000 2021
# 3   609928b428f1bb0e684e119b  Thu May 06 08:42:19 +0000 2021
# 4   609928b428f1bb0e684e1192  Fri May 07 15:15:24 +0000 2021
# ..                       ...                             ...
# 92  609928b428f1bb0e684e11df  Mon May 03 15:02:55 +0000 2021
# 93  609928b428f1bb0e684e11b8  Tue May 04 14:55:40 +0000 2021
# 94  609928b428f1bb0e684e11ba  Tue May 04 14:11:23 +0000 2021
# 95  609928b428f1bb0e684e11d5  Mon May 03 16:35:06 +0000 2021
# 96  609928b428f1bb0e684e11e8  Sun May 02 18:34:01 +0000 2021
#
#                      id               id_str  \
# 0   1391652311345233923  1391652311345233923
# 1   1391708753741897728  1391708753741897728
# 2   1389976593066602498  1389976593066602498
# 3   1390225400777818112  1390225400777818112
# 4   1390686712964255744  1390686712964255744
# ..                  ...                  ...
# 92  1389234018693099521  1389234018693099521
# 93  1389594580262211584  1389594580262211584
# 94  1389583439687467009  1389583439687467009
# 95  1389257218311147536  1389257218311147536
# 96  1388924755890290700  1388924755890290700
#
#                                             full_text  truncated  \
# 0   RT @cstrackproject: The second of three @cstra...      False
# 1   RT @cstrackproject: The second of three @cstra...      False
# 2   Our first workshop at @CitSciVirtual !! 🤩 http...      False
# 3   RT @Ideas_4_Change: Yesterday, @LuciaErrandone...      False
# 4   About to host a bit of an experiment at @CitSc...      False
# ..                                                ...        ...
# 92  RT @CharmelMenzel: Join #CitSciVirtual session...      False
# 93  RT @Cos4Cloud: Are you attending the #CitSciVi...      False
# 94  Coming soon #CitSciVirtual https://t.co/FXiOOg...      False
# 95  RT @FieldKitOrg: Catch a few of our friends an...      False
# 96  Save the date! We'll be presenting at #CitSciV...      False
#
#    display_text_range                                           entities  \
# 0            [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1            [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [0, 41]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3            [0, 144]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 4            [0, 252]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# ..                ...                                                ...
# 92           [0, 144]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 93           [0, 139]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 94            [0, 26]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
# 95           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 96           [0, 236]  {'hashtags': [{'text': 'CitSciVirtual', 'indic...
#
#                                              metadata  \
# 0   {'iso_language_code': 'en', 'result_type': 're...
# 1   {'iso_language_code': 'en', 'result_type': 're...
# 2   {'iso_language_code': 'en', 'result_type': 're...
# 3   {'iso_language_code': 'en', 'result_type': 're...
# 4   {'iso_language_code': 'en', 'result_type': 're...
# ..                                                ...
# 92  {'iso_language_code': 'en', 'result_type': 're...
# 93  {'iso_language_code': 'en', 'result_type': 're...
# 94  {'iso_language_code': 'en', 'result_type': 're...
# 95  {'iso_language_code': 'en', 'result_type': 're...
# 96  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                source  ... retweet_count  \
# 0   <a href="https://opensci.io" rel="nofollow">Op...  ...             4
# 1   <a href="https://mobile.twitter.com" rel="nofo...  ...             4
# 2   <a href="https://mobile.twitter.com" rel="nofo...  ...             1
# 3   <a href="https://mobile.twitter.com" rel="nofo...  ...             5
# 4   <a href="https://mobile.twitter.com" rel="nofo...  ...             0
# ..                                                ...  ...           ...
# 92  <a href="https://mobile.twitter.com" rel="nofo...  ...             4
# 93  <a href="https://mobile.twitter.com" rel="nofo...  ...             4
# 94  <a href="https://mobile.twitter.com" rel="nofo...  ...             0
# 95  <a href="https://mobile.twitter.com" rel="nofo...  ...             6
# 96  <a href="https://buffer.com" rel="nofollow">Bu...  ...             0
#
#    favorite_count favorited retweeted lang     quoted_status_id  \
# 0               0     False     False   en                  NaN
# 1               0     False     False   en                  NaN
# 2               7     False     False   en  1389976102723100679
# 3               0     False     False   en                  NaN
# 4               1     False     False   en                  NaN
# ..            ...       ...       ...  ...                  ...
# 92              0     False     False   en                  NaN
# 93              0     False     False   en                  NaN
# 94              3     False     False   en  1389539803700547589
# 95              0     False     False   en                  NaN
# 96              3     False     False   en                  NaN
#
#    quoted_status_id_str                                      quoted_status  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2   1389976102723100679  {'created_at': 'Wed May 05 16:11:42 +0000 2021...
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ..                  ...                                                ...
# 92                  NaN                                                NaN
# 93                  NaN                                                NaN
# 94  1389539803700547589  {'created_at': 'Tue May 04 11:18:00 +0000 2021...
# 95                  NaN                                                NaN
# 96                  NaN                                                NaN
#
#    possibly_sensitive extended_entities
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2               False               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ..                ...               ...
# 92                NaN               NaN
# 93                NaN               NaN
# 94              False               NaN
# 95                NaN               NaN
# 96              False               NaN
#
# [97 rows x 32 columns]

# %% [markdown]
# Check that all tweets are in English

# %%
data = data[data['lang'] == 'en']

# %% [markdown]
# Delete tweets that are outside the desired range of dates

# %%
for i in range(0, len(data)):   
    item = data.iloc[i]
    
    if(int(item['created_at'][-4:])) < int(2021):
        data.drop([i],  inplace = True)

# %% [markdown]
# ### Treat the data to extract conclusions

# %% [markdown]
# Store for each tweet in the database: the text, the user, the number of retweets, the number of likes and the date.

# %%
tweets = []     # array for the text
users = []      # array for the user data
retweets = []   # array for the number of retweets
likes = []      # array for the number of likes
dates = []      # array for the dates of the tweets

for i in range(0, len(data)):
    
    item = data.iloc[i]    # store JSON object

    text =item['full_text']
    tweets.append(text.split())
    
    user = item['user']
    users.append(user)
        
    retweet = item['retweet_count']
    retweets.append(retweet)
    
    like = item['favorite_count']
    likes.append(like)
    
    date = item['created_at']
    dates.append(date)

# %%
# Fucntion to convert from the written month to the month in numbers
def convert_month(month):
    if month == 'Jan':
        month = 1
    elif month == 'Feb':
        month = 2
    elif month == 'Mar':
        month = 3
    elif month == 'Apr':
        month = 4
    elif month == 'May':
        month = 5
    elif month == 'Jun':
        month = 6
    elif month == 'Jul':
        month = 7
    elif month == 'Aug':
        month = 8
    elif month == 'Sep':
        month = 9
    elif month == 'Oct':
        month = 10
    elif month == 'Nov':
        month = 11
    elif month == 'Dec':
        month = 12
    return month

# %% [markdown]
# Search for the date of the first tweet and the last tweet published in our database.

# %%
find_date = []
for date in dates:
    year = date[-4:]
    month = date[4:7]
    month = convert_month(str(month))
    day = date[8:10]
    date = str(str(year)+'-'+str(month)+'-'+str(day))
    find_date.append(pd.Timestamp(date))
    
max_date = max(find_date)
min_date = min(find_date)

print("The first tweet was published at ", min_date)
print("The last tweet was published at ", max_date)
# Out:
# The first tweet was published at  2021-05-02 00:00:00
# The last tweet was published at  2021-05-10 00:00:00

# %% [markdown]
# Number of tweets in the database.

# %%
print("From", min_date, " untill", max_date, len(data),"tweets have been published.")
# Out:
# From 2021-05-02 00:00:00  untill 2021-05-10 00:00:00 90 tweets have been published.

# %% [markdown]
# Most common words between the tweets.

# %%
tweets_arr = []
words_arr = []
non_interesting_words = ["in", "and", "RT", "a", "of", "what", "is", "he", "she", "already", "yet", "no", "science", "Science", 
                         "yes", "lot", "you", "Us", "citizen", "the", "are", "one", "to", "in", "Citizen", "for", "our", "on", 
                         "with", "this", "from", "can", "#CitizenScience", "that", "your", "about", "The", "-", "science.", 
                         "have", "we", "I", "has", "We", "at", "as", "be", "by", "not", "It’s", "out", "an", "us", "will", 
                         "get", "all", "it", "A", "In", "This", "do", "or", "how", "They", "but", "they", "my", "into", "So",
                         "If", "their", "Our", "up", "That's", "so", "now"]

for t in tweets:
    for i in t:
        tweets_arr.append(i)
        if (i.startswith(('#','@')) == False):
            words_arr.append(i)

for word in non_interesting_words:
    words_arr = [val for val in words_arr if val != word]

from collections import Counter 
Counter = Counter(words_arr) 
  
most_occur = Counter.most_common(100) 

print("The most common words are: \n", most_occur)
# Out:
# The most common words are:
#  [('&amp;', 20), ('information', 15), ('join', 15), ('Join', 14), ('workshop', 13), ('own', 11), ('exploring', 10), ('conference', 10), ('place', 10), ('tomorrow', 9), ('part', 9), ('live', 9), ('community', 9), ('May', 9), ('event', 8), ('Open', 8), ('three', 7), ('workshops', 7), ('used', 7), ('organised', 7), ('taking', 7), ('was', 7), ('Check', 7), ('Catch', 7), ('few', 7), ('friends', 7), ('"Open', 7), ('Tools', 7), ('Collaborative', 7), ('Science:', 7), ('Value', 7), ('Yesterday,', 6), ('presented', 6), ('toolkit', 6), ('Looking', 6), ('poster', 6), ('today!', 6), ('Then', 6), ('Hardwar…', 6), ('relevant', 6), ('CS', 6), ('second', 5), ('tools', 5), ('analyze', 5), ('by…', 5), ('Data', 5), ('Book', 5), ('session', 5), ('her', 5), ('present', 5), ('CitSciVirtul', 5), ('Pre-event', 5), ('https://t.co/GakGkBXGwK', 5), ('hope', 5), ('Sci…', 5), ('Are', 5), ('attending', 5), ('organized', 5), ('🌏', 5), ('next', 5), ('activity', 5), ('first', 4), ('!!', 4), ('when', 4), ("she'll", 4), ('‘Anti-racist', 4), ('science’', 4), ('6th', 4), ('May,', 4), ('learning', 4), ('forward', 4), ('between', 4), ('start', 4), ('scientific', 4), ('now!', 4), ('week!', 4), ('fellow', 4), ('work', 4), ('emerging', 4), ('infectious', 4), ('diseases', 4), ('Remember', 4), ("'Test…", 4), ('Thur.', 4), ('6,', 4), ('3pm', 4), ('US', 4), ('EDT', 4), ('engage', 4), ('panelists', 4), ('many', 3), ('who', 3), ('Da…', 3), ('3-4.30p…', 3), ('(ET)', 3), ('more', 3), ('new', 3), ('excited', 3), ('ET', 3), ('present"#SciArt-building', 3)]

# %% [markdown]
# Extract the number of occurrences of each word in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Word', 'Number of occurrences'])
df_most_occur.to_csv("words_CitSciVirtual.csv")
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %% [markdown]
# Most common hashtags mentioned between the tweets.

# %%
hashtags = []
for word in tweets_arr:
    if word[0] == '#':
        hashtags.append(word)

from collections import Counter
Counter = Counter(hashtags)   
most_occur = Counter.most_common(40) 

print("The most common hashtags are: \n",most_occur)
# Out:
# The most common hashtags are:
#  [('#CitSciVirtual', 39), ('#CitizenScience', 7), ('#citizenscience', 6), ('#CitSciVirtual!', 6), ('#CitSciVirtual,', 5), ('#codesign', 5), ('#Cos4Bio', 5), ('#c…', 4), ("#DataStream's", 4), ('#SDGs', 2), ('#CitSciVirtual!…', 2), ('#database', 2), ('#CS', 2), ('#StoryMap', 2), ('#engage', 2), ('#Citsci', 1), ('#H2020', 1), ('#OpenScience', 1), ('#strategies', 1), ('#AirPol:', 1), ('#citizen-', 1), ('#data."', 1), ('#YouthEngagement', 1), ('#citscivirtual.', 1), ('#citscivirtual', 1), ('#CitSci', 1), ('#sciart', 1), ('#flow', 1), ('#CitizenScience.', 1), ('#MayThe4thBeWithYou', 1), ('#tools', 1)]

# %% [markdown]
# Extract the number of occurrences of each hashtag in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Hashtag', 'Number of mentions'])
df_most_occur.to_csv("hashtags_CitSciVirtual.csv")

# %% [markdown]
# Most common accounts mentioned between the tweets.

# %%
accounts = []
for word in tweets_arr:
    if word[0] == '@':
        accounts.append(word)

from collections import Counter
Counter = Counter(accounts)
most_occur = Counter.most_common(40) 

print("The most common mentioned accounts are: \n",most_occur)
# Out:
# The most common mentioned accounts are:
#  [('@CitSciAssoc', 19), ('@cstrackproject:', 11), ('@cstrackproject', 7), ('@LuciaErrandonea', 7), ('@OrsolyaRMolnar', 7), ('@shahselbe', 7), ('@Ideas_4_Change:', 6), ('@ValeSbriz', 6), ('@CitieSHealthEU', 6), ('@FieldKitOrg:', 6), ('@KLIAustria:', 5), ('@CitSciAssoc.', 5), ('@CitSciAssoc:', 5), ('@CitSciAssoc??', 5), ('@CitSciVirtual', 4), ('@mary_kruk', 4), ('@LEARN_CitSci:', 4), ('@Cos4Cloud:', 4), ('@CharmelMenzel:', 4), ('@AudbonSociety,', 4), ('@FieldMuseum', 4), ('@NHSeaG…', 4), ('@CitSci', 3), ('@DataStreamH2O:', 3), ('@NHM_CitSci', 2), ('@UCDavisCCS', 2), ('@ASU', 2), ('@SciStarter', 2), ('@Esri', 2), ('@CharmelMenzel', 2), ('@gena_fernandes:', 2), ('@ValeSbriz,', 2), ('@bubblyplasma', 2), ('@littlelocket', 1), ('@herodotouc', 1), ('@scicheer:', 1), ('@GISandScience:', 1), ('@josep…', 1), ('@UNDP', 1), ('@ciberimaginario:', 1)]

# %% [markdown]
# Extract the number of occurrences of each account in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Account', 'Number of mentions'])
df_most_occur.to_csv("accounts_CitSciVirtual.csv")

# %% [markdown]
# Find the average and the maximum number of likes and retweets between the tweets.

# %%
print("The maximum number of retweets is: ", max(retweets))
print("The average number of retweets is: ", int(np.mean(retweets)))
print("\nThe maximum number of likes is: ", max(likes))
print("The average number of likes is: ", int(np.mean(likes)))
# Out:
# The maximum number of retweets is:  10
# The average number of retweets is:  2
#
# The maximum number of likes is:  18
# The average number of likes is:  1

# %% [markdown]
# Most retweeted tweets

# %%
print("The most retweeted tweets are: \n")
data.nlargest(20, ['retweet_count'])['full_text']
# Out:
# The most retweeted tweets are:
# 39    RT @cstrackproject: 📢Save the date!!📢\n\nThis ...
# 68    RT @cstrackproject: 📢Save the date!!📢\n\nThis ...
# 48    Catch a few of our friends and our own @shahse...
# 50    RT @CitSciAssoc: Check out our CitSciVirtul Pr...
# 52    RT @FieldKitOrg: Catch a few of our friends an...
# 56    RT @CitSciAssoc: Check out our CitSciVirtul Pr...
# 59    RT @FieldKitOrg: Catch a few of our friends an...
# 62    RT @CitSciAssoc: Check out our CitSciVirtul Pr...
# 63    RT @FieldKitOrg: Catch a few of our friends an...
# 65    RT @CitSciAssoc: Check out our CitSciVirtul Pr...
# 78    RT @CitSciAssoc: Check out our CitSciVirtul Pr...
# 79    RT @FieldKitOrg: Catch a few of our friends an...
# 90    RT @FieldKitOrg: Catch a few of our friends an...
# 95    RT @FieldKitOrg: Catch a few of our friends an...
# 3     RT @Ideas_4_Change: Yesterday, @LuciaErrandone...
# 16    RT @Ideas_4_Change: Yesterday, @LuciaErrandone...
# 17    RT @Ideas_4_Change: Yesterday, @LuciaErrandone...
# 24    Yesterday, @LuciaErrandonea &amp; @ValeSbriz p...
# 31    RT @Ideas_4_Change: Yesterday, @LuciaErrandone...
# 36    RT @Ideas_4_Change: Yesterday, @LuciaErrandone...
# Name: full_text, dtype: object

# %% [markdown]
# Most common source types.

# %%
src_data = data[data['extended_entities'].notna() == True]

src_type = []
for i in src_data.index:
    num_src = len(src_data.loc[i]['extended_entities']['media'])
    for n in range(0, num_src):
        src_type.append(src_data.loc[i]['extended_entities']['media'][n]['type'])

from collections import Counter 
Counter = Counter(src_type)   
most_occur = Counter.most_common(20) 

print("The most common source types are: \n", most_occur)
# Out:
# The most common source types are:
#  [('photo', 8), ('animated_gif', 3), ('video', 1)]

# %% [markdown]
# Extract the number of occurrences of each source type in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Source', 'Number of occurrences'])
df_most_occur.to_csv("sources_CitSciVirtual.csv")

# %% [markdown]
# ## Analysis of the users interacting in Twitter about CS

# %% [markdown]
# Number of users interacting in CS.

# %%
user_ids = []
for u in users:
    if u['id'] not in user_ids:
        user_ids.append(u['id'])
print("There are ", len(user_ids), "active users.")
# Out:
# There are  68 active users.

# %% [markdown]
# Most active users between the tweets.

# %%
user_names = []
for u in users:
    user_names.append(u['screen_name'])

from collections import Counter
Counter = Counter(user_names)   
most_occur = Counter.most_common(20) 
    
print("The most active users are: \n", most_occur)
# Out:
# The most active users are:
#  [('cstrackproject', 7), ('gena_fernandes', 4), ('miryci', 3), ('CitieSHealthEU', 3), ('AlisonCawood', 3), ('ciberimaginario', 2), ('Rick_Hall', 2), ('LEARN_CitSci', 2), ('Ideas_4_Change', 2), ('KLIAustria', 2), ('OrsolyaRMolnar', 2), ('GISandScience', 2), ('OpenSciTalk', 1), ('javicreus', 1), ('atlwaternetwork', 1), ('aristeidoum', 1), ('SpaceGeographer', 1), ('SciStarter', 1), ('debatinginnovat', 1), ('Portela_Man', 1)]

# %% [markdown]
# Extract the number of times each user interacts in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['User', 'Number of interactions'])
df_most_occur.to_csv("users_CitSciVirtual.csv")

# %% [markdown]
# Location, number of followers, number of statuses and number of likes of users

# %%
user_locations = []
user_followers = []
user_status = []
user_favorites = []
for u in users:
    user_locations.append(u['location'])

# %% [markdown]
# Most common locations of published tweets

# %%
user_locations = filter(None, user_locations)
from collections import Counter
Counter = Counter(user_locations)   
most_occur = Counter.most_common(20) 

print("The most common user's locations are: \n", most_occur)
# Out:
# The most common user's locations are:
#  [('Barcelona', 4, 11.428571428571429), ('Portugal', 4, 11.428571428571429), ('Barcelona, Espanya', 3, 8.571428571428571), ('Madrid, Spain', 2, 5.714285714285714), ('52.983189,-1.205796', 2, 5.714285714285714), ('Barcelona, Spain', 2, 5.714285714285714), ('Klosterneuburg, Austria', 2, 5.714285714285714), ('Washington, DC', 2, 5.714285714285714), ('Vienna, Austria', 2, 5.714285714285714), ('Redlands, CA USA', 2, 5.714285714285714), ('Nova Scotia ', 1, 2.857142857142857), ('United Kingdom', 1, 2.857142857142857), ('London, England', 1, 2.857142857142857), ('Global', 1, 2.857142857142857), ('Paris', 1, 2.857142857142857), ('Toronto, Ontario', 1, 2.857142857142857), ('USA', 1, 2.857142857142857), ('Copenhagen, Denmark', 1, 2.857142857142857), ('Canada', 1, 2.857142857142857), ('Brasil', 1, 2.857142857142857)]

# %% [markdown]
# Extract the number of tweets for each localization in a file in format csv to be able to create the visualizations.

# %%
df_most_occur = pd.DataFrame(most_occur, columns = ['Localitzation', '# users active'])
df_most_occur.to_csv("localitzations_CitSciVirtual.csv")
